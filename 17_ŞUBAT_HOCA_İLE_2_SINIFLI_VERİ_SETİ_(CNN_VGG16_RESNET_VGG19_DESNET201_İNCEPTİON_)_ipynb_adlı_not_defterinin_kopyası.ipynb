# %% [markdown]
# <a href="https://colab.research.google.com/github/Pervinsr/-Letter-Changes/blob/main/17_%C5%9EUBAT_HOCA_%C4%B0LE_2_SINIFLI_VER%C4%B0_SET%C4%B0_(CNN_VGG16_RESNET_VGG19_DESNET201_%C4%B0NCEPT%C4%B0ON_)_ipynb_adl%C4%B1_not_defterinin_kopyas%C4%B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# veri seti : dataset_deneme r

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Kütüphaneler

# %%
import tensorflow as tf
import gc
from tensorflow import keras
import keras
from keras import backend as k
tf.keras.optimizers.Adam()
tf.keras.optimizers.SGD()
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import random
import shutil
import cv2
import os
from datetime import datetime
# %load_ext tensorboard
from google.colab import drive
import matplotlib
from sklearn.metrics import roc_auc_score, roc_curve


#%% roc ROC auc AUC Roc
import numpy as np
import matplotlib.pyplot as plt
from itertools import cycle

from sklearn import svm, datasets
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
from scipy import interp
from sklearn.metrics import roc_auc_score  


import tensorflow as tf
inputs = tf.keras.Input(shape=(3,))
x = tf.keras.layers.Dense(4, activation=tf.nn.relu)(inputs)
outputs = tf.keras.layers.Dense(5, activation=tf.nn.softmax)(x)
model = tf.keras.Model(inputs=inputs, outputs=outputs)


from tensorflow.python.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint,TensorBoard,TerminateOnNaN, LearningRateScheduler
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, TerminateOnNaN
from tensorflow.keras import regularizers
from tensorflow.keras import backend as K
from sklearn.metrics import precision_recall_curve,  plot_precision_recall_curve,  classification_report,  confusion_matrix, roc_auc_score, roc_curve, auc
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split, StratifiedKFold, RepeatedStratifiedKFold
from imutils import paths


from google.colab import drive
import matplotlib
from sklearn.metrics import roc_auc_score, roc_curve
import os
import cv2
import skimage
from tensorflow.python.keras.callbacks import ModelCheckpoint, EarlyStopping
import os 
import zipfile 
import tensorflow as tf 
from tensorflow.keras.preprocessing.image import ImageDataGenerator 
from tensorflow.keras import layers 
from tensorflow.keras import Model 
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet import ResNet152
from tensorflow.keras.applications import EfficientNetB0,EfficientNetB1,EfficientNetB2,EfficientNetB3,EfficientNetB4,EfficientNetB5,EfficientNetB6,EfficientNetB7
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.applications import Xception
from tensorflow.keras.applications import NASNetMobile
from tensorflow.keras.applications import MobileNetV2
import random
from skimage import filters
from tensorflow.keras.utils import to_categorical
import os
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns

def isCheck_Klasor(path):    
    if not os.path.isdir(path):
        os.mkdir( path, 755 );


import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPooling2D,GlobalAveragePooling2D
from keras.layers import Activation, Dropout, BatchNormalization, Flatten, Dense, AvgPool2D,MaxPool2D
from keras.models import Sequential, Model
from keras.applications.vgg16 import VGG16, preprocess_input
import tensorflow as tf

import os
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import glob
import matplotlib.image as mpimg
# %matplotlib inline
import plotly.offline as py
import plotly.express as px

# %% [markdown]
# # Veri Seti Ön işlem

# %%
from google.colab import drive
import matplotlib
from sklearn.metrics import roc_auc_score, roc_curve
import os
import cv2

#%% roc ROC auc AUC Roc
import numpy as np
import matplotlib.pyplot as plt
from itertools import cycle

from sklearn import svm, datasets
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
from scipy import interp
from sklearn.metrics import roc_auc_score   

from PIL import Image
import requests
import numpy as np

def isCheck_Klasor(path):    
    if not os.path.isdir(path):
        os.mkdir( path, 755 );


#Drive bağlama
drive.mount('/content/drive')
anaKlasor =  "/content/drive/MyDrive/tez/"

#Verisetim
anaKlasor2=anaKlasor+'dataset_deneme/'
altKlasorler =  os.listdir(anaKlasor2)


targets=[]
for index, altKlasor in enumerate(altKlasorler):
  if altKlasor not in targets:
    targets.append(altKlasor)

print (targets)
np.save(anaKlasor+'/features/targets.npy',targets)   # x ve y kaydettim 



X,y=[],[]

for index, altKlasor in enumerate(altKlasorler):

    cikis=targets.index(altKlasor)
    
    path1=anaKlasor2+'/'+altKlasor+'/'

    imagelist=os.listdir(path1)
    
    for i,file_name in enumerate(imagelist):

       #print (path1+'/'+file_name)        
        
        img = cv2.imread(os.path.join(anaKlasor2,altKlasor,file_name))
        img = cv2.resize(img,(224,224))
        img=np.array(img)
        X.append(img)
        y.append(cikis)
        #print (i,"/",len(imagelist),"->",altKlasor,altKlasorler,"->",img.shape)


X=np.array(X)

path=anaKlasor+"/features/"
isCheck_Klasor(path)

np.save(path+"/X.npy",X)
np.save(path+"/y.npy",y)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ['COVID', 'non-COVID']

# %%
# !pip install imutils
# !pip install image-classifiers==1.0.0b1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for image-classifiers: filename=image_classifiers-1.0.0b1-py3-none-any.whl size=19968 sha256=949bb59008c3ce17d63f5ca9c0221a343e0da6f05fb9320dfd932d637dfb351b
#   Stored in directory: /root/.cache/pip/wheels/59/ee/99/bdd974449ed4653c3c2e37d600817c9da816057dfa43c67878
# Successfully built image-classifiers
# ...

# %%
# dataset_deneme klasörünü gerçek veri setindeki görüntülerin hepsi yer almıyor. Az bir kısmını aktardım.
anaKlasor =  "/content/drive/MyDrive/tez/dataset_deneme"
print(anaKlasor)
print(os.listdir(anaKlasor))




df = pd.DataFrame(columns =['class', 'directory'])  # sınıf ve dizin kısmı
df
# Out:
# /content/drive/MyDrive/tez/dataset_deneme
# ['COVID', 'non-COVID']
# Empty DataFrame
# Columns: [class, directory]
# Index: []

# %%
import os
for dirpath, dirnames, filenames in os.walk('../content/drive/MyDrive/tez/dataset_deneme/COVID'):
    for filename in filenames:
        df.loc[-1] = ["COVID", ('COVID/' + filename)] 
        df.index = df.index + 1 
        df = df.sort_index() 
for dirpath, dirnames, filenames in os.walk('../content/drive/MyDrive/tez/dataset_deneme/non-COVID'):
    for filename in filenames:
        df.loc[-1] = ["non-COVID", ('non-COVID/' + filename)] 
        df.index = df.index + 1 
        df = df.sort_index()

# %%
df.head()
# Out:
#        class                       directory
# 0  non-COVID  non-COVID/Non-Covid (1143).png
# 1  non-COVID  non-COVID/Non-Covid (1203).png
# 2  non-COVID  non-COVID/Non-Covid (1138).png
# 3  non-COVID  non-COVID/Non-Covid (1205).png
# 4  non-COVID   non-COVID/Non-Covid (104).png

# %%
#sınıf ve dizinlerini listeleme
df
# Out:
#           class                       directory
# 0     non-COVID  non-COVID/Non-Covid (1143).png
# 1     non-COVID  non-COVID/Non-Covid (1203).png
# 2     non-COVID  non-COVID/Non-Covid (1138).png
# 3     non-COVID  non-COVID/Non-Covid (1205).png
# 4     non-COVID   non-COVID/Non-Covid (104).png
# ...         ...                             ...
# 2476      COVID           COVID/Covid (151).png
# 2477      COVID           COVID/Covid (221).png
# 2478      COVID           COVID/Covid (266).png
# 2479      COVID           COVID/Covid (156).png
# 2480      COVID          COVID/Covid (1233).png
#
# [2481 rows x 2 columns]

# %%
y = df['class']
X = df['directory']

#kaç tane oldukları
y.value_counts()
# Out:
# COVID        1252
# non-COVID    1229
# Name: class, dtype: int64

# %%
X.value_counts()
# Out:
# non-COVID/Non-Covid (1143).png    1
# COVID/Covid (825).png             1
# COVID/Covid (756).png             1
# COVID/Covid (782).png             1
# COVID/Covid (798).png             1
#                                  ..
# non-COVID/Non-Covid (370).png     1
# non-COVID/Non-Covid (373).png     1
# non-COVID/Non-Covid (380).png     1
# non-COVID/Non-Covid (420).png     1
# COVID/Covid (1233).png            1
# Name: directory, Length: 2481, dtype: int64

# %%
#box plot and counting the lables
df=pd.DataFrame(targets,columns=['labels'])
sns.countplot(df['labels'])
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
#COVID Image
COVID_images = []
for img_path in glob.glob(anaKlasor + '/COVID/*'):
    COVID_images.append(mpimg.imread(img_path))

fig = plt.figure()
fig.suptitle('COVID Image')
plt.imshow(COVID_images[0], cmap='gray')
plt.savefig("/content/drive/MyDrive/tez/saveimage/COVIDimage.png")    #klasöre kaydettim

#non-COVID Image
nonCOVID_images = []
for img_path in glob.glob(anaKlasor + '/non-COVID/*'):
   nonCOVID_images.append(mpimg.imread(img_path))
fig = plt.figure()
fig.suptitle('nonCOVID Image')
plt.imshow(nonCOVID_images[0], cmap='gray')
plt.savefig("/content/drive/MyDrive/tez/saveimage/non-COVID_image.png")

# %% [markdown]
# **VGG16**

# %%
Image_Width = 224
Image_Height = 224
Cannels = 3

INPUT_SHAPE = (Image_Width, Image_Height, Cannels)
NB_CLASSES = 2
EPOCHS = 100
BATCH_SIZE = 32

# %%
from sklearn.model_selection import train_test_split
import numpy as np
import seaborn as sns
X_train, X_test, Y_train, Y_test = train_test_split(X, y, stratify=y, test_size=0.20, random_state=7)

# %%
print('Öğrenme verisinin boyutları (Gözlem, öznitelik) = ' + str(np.shape(X_train)))
print('Sınama verisinin boyutları (Gözlem, öznitelik) = ' + str(np.shape(X_test)))
# Out:
# Öğrenme verisinin boyutları (Gözlem, öznitelik) = (1984,)
# Sınama verisinin boyutları (Gözlem, öznitelik) = (497,)

# %%
#sns.scatterplot(x = X, y = y)

# %%
Y_train.value_counts()
# Out:
# COVID        1001
# non-COVID     983
# Name: class, dtype: int64

# %%
Y_test.value_counts()
# Out:
# COVID        251
# non-COVID    246
# Name: class, dtype: int64

# %%
#encode labels as integer
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder() #labelencoder used to normalize labels
labels=le.fit_transform(targets) #also be used to transform non-numerical labels to numerical labels
labels=to_categorical(labels)

print(le.classes_)
print(labels[0])
# Out:
# ['COVID' 'non-COVID']
# [1. 0.]

# %%
X_train=np.array(X_train)
X_test=np.array(X_test)
Y_train=np.array(Y_train)
Y_test=np.array(Y_test)

print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (1984,)
# (497,)
# (1984,)
# (497,)

# %% [markdown]
# ### ResNet Model Eğitimi ve Testi

# %%
#    resnet_model
import tensorflow as tf
from keras.models import Sequential
from keras.layers import GlobalAveragePooling2D
from keras.applications import ResNet50

#4096 ekle 
resnet_model = ResNet50(input_shape=INPUT_SHAPE,include_top=False,weights='imagenet')
resnet_model.summary()
resnet_model = tf.keras.Sequential([
        resnet_model,
        GlobalAveragePooling2D(),
        Dense(512, activation="relu"),
        BatchNormalization(),
        Dropout(0.6),
        Dense(128, activation="relu"),
        BatchNormalization(),
        Dropout(0.4),
        Dense(64,activation="relu"),
        BatchNormalization(),
        Dropout(0.3),
        Dense(2,activation="softmax") #bu kısımdaki 3 sayısı sizin almak istediğiniz sonuc sayısı.yani covid, zatüre ve normal 3 adet olduğu için 3
    ])

#Modelimizi derlemek
resnet_model.compile(loss='binary_crossentropy',optimizer='rmsprop',metrics=['accuracy'])


from tensorflow.keras.utils import plot_model
#plot_model(model, to_file='model1.png')
plot_model(resnet_model, to_file="/content/drive/MyDrive/tez/saveimage/modelresnet50.png")

import numpy as np
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from google.colab import drive
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPClassifier
from google.colab import drive
import matplotlib
import os
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
from keras.optimizers import Adam
import numpy as np
from numpy import argmax
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import scipy.misc
from keras.layers import Concatenate, Dense, LSTM, Input, concatenate
from keras import backend as K
from skimage.transform import resize
import os
from keras.models import load_model
from keras.utils import np_utils
import joblib
from keras.layers import Flatten
from keras.models import Model
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import pandas as pd
from  sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
from xgboost import XGBClassifier
from sklearn import svm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.neural_network import MLPClassifier
from keras.models import Model
from keras.layers import Input,Reshape
from keras.layers import Dense, Conv2D, Flatten
from keras.layers import Input, LSTM, Bidirectional, Conv1D
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Embedding
from keras.models import Sequential
from keras.utils import to_categorical
from keras.layers import Flatten
from keras.models import Model
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from keras.layers import Input, LSTM, Dense,Bidirectional 
from keras.models import Model
from sklearn.metrics import  confusion_matrix,classification_report
import pickle
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_classif

def isCheck_Klasor(path):    
    if not os.path.isdir(path):
        os.mkdir( path, 755 );

Image_Width = 224
Image_Height = 224
Cannels = 3

INPUT_SHAPE = (Image_Width, Image_Height, Cannels)
NB_CLASSES = 2
EPOCHS =100
BATCH_SIZE =32


#PLOT 
def plot_ciz_acc_loss(history,fold_index,etiket):
    
    # list all data in history
    print(history.history.keys())
    # summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.savefig(anaKlasor+"/acc_loss_graphs/"+etiket+"_acc_fold_value="+str(fold_index)+".png")
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.savefig(anaKlasor+"/acc_loss_graphs/"+etiket+"_loss_fold_value="+str(fold_index)+".png")
    plt.show()


#Confusion matrix
def cm_analysis(y_train, y_pred, labels, ymap=None, figsize=(10,10)):
    
    """
    Generate matrix plot of confusion matrix with pretty annotations.
    The plot image is saved to disk.
    args: 
      y_true:    true label of the data, with shape (nsamples,)
      y_pred:    prediction of the data, with shape (nsamples,)
      filename:  filename of figure file to save
      labels:    string array, name the order of class labels in the confusion matrix.
                 use `clf.classes_` if using scikit-learn models.
                 with shape (nclass,).
      ymap:      dict: any -> string, length == nclass.
                 if not None, map the labels & ys to more understandable strings.
                 Caution: original y_true, y_pred and labels must align.
      figsize:   the size of the figure plotted.
    """
    labels=[0,1]
    if ymap is not None:
        y_pred = [ymap[yi] for yi in y_pred]
        y_train = [ymap[yi] for yi in y_train]
        labels= [ymap[yi] for yi in labels]
        
    cm = confusion_matrix(y_train, y_preds, labels=labels)
    cm_sum = np.sum(cm, axis=1, keepdims=True)
    cm_perc = cm / cm_sum.astype(float) * 100
    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            c = cm[i, j]
            p = cm_perc[i, j]
            if i == j:
                s = cm_sum[i]
                annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
            elif c == 0:
                annot[i, j] = ''
            else:
                annot[i, j] = '%.1f%%\n%d' % (p, c)
    cm = pd.DataFrame(cm, index=labels, columns=labels)
    cm.index.name = 'Actual'
    cm.columns.name = 'Predicted'
    fig, ax = plt.subplots(figsize=figsize)
    sns.heatmap(cm, annot=annot, fmt='', ax=ax)
    plt.savefig(filename)
    plt.show()

anaKlasor =  "/content/drive/MyDrive/tez/"
path=anaKlasor+"/features/"
X=np.load(path+"/X.npy")
y=np.load(path+"/y.npy")
X_train, X_test, Y_train, Y_test = train_test_split(X, y, stratify=y, test_size=0.20, random_state=42)
Y_train=to_categorical(Y_train)

resnet_model.compile(loss='binary_crossentropy',optimizer='rmsprop',metrics=['accuracy'])
etiket="ResNet50"
#eğitimi başlat
history = resnet_model.fit( X_train, Y_train,  validation_split=0.2,epochs = EPOCHS,verbose=1)

# GRAFİK ÇİZİLSİN
plot_ciz_acc_loss(history,"Hold-out",etiket)

"""
Y_train_preds=resnet_model.predict(X_train)   #tahmin
print (etiket," modelinin sonuçları:",Y_train_preds)

y_preds=np.argmax(Y_train_preds,axis=1)
acc=round(accuracy_score(Y_train, y_preds),3)
print ("Acc "+etiket+"-"+etiket+ " score:",acc*100)
cm_analysis(Y_train, y_preds, targets, figsize=(5,5))


Y_test_preds=resnet_model.predict(X_test)   #tahmin
print (etiket," modelinin sonuçları:",Y_test_preds)

y_preds=np.argmax(Y_test_preds,axis=1)
acc=round(accuracy_score(Y_test, y_preds),3)
print ("Acc "+etiket+"-"+etiket+ " score:",acc*100)
cm_analysis(Y_test, y_preds, targets, figsize=(5,5))

"""


resnet_model.save('../content/drive/MyDrive/tez/models/model_'+etiket+'.h5')

targets=np.load("../content/drive/MyDrive/tez/features/targets.npy")
print (targets)
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_5 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_5[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 112, 112, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
# ...

# %%
###
Y_train_preds=resnet_model.predict(X_train)   #tahmin
print (etiket," modelinin sonuçları:",Y_train_preds)

# %%
##
Y_test_preds=resnet_model.predict(X_test)   #tahmin
print (etiket," modelinin sonuçları:",Y_test_preds)

# %%
Y_train_preds=resnet_model.predict(X_train)   #tahmin
print (etiket," modelinin sonuçları:",Y_train_preds)

y_preds=np.argmax(Y_train_preds,axis=1)
Y_train_preds=np.argmax(Y_train_preds,axis=1)

acc=round(accuracy_score(Y_train, y_preds),3)
print ("Acc "+etiket+"-"+etiket+ " score:",acc*100)
cm_analysis(Y_train, y_preds, targets, figsize=(5,5))
# Out:
# 62/62 [==============================] - 6s 89ms/step
# ResNet50  modelinin sonuçları: [[2.7019419e-06 9.9999726e-01]
#  [9.9998915e-01 1.0881077e-05]
#  [9.9954212e-01 4.5785832e-04]
#  ...
#  [3.1113676e-09 1.0000000e+00]
#  [1.9156218e-10 1.0000000e+00]
#  [6.2696631e-10 1.0000000e+00]]
# Acc ResNet50-ResNet50 score: 82.69999999999999

# %%
####

Y_test_preds=resnet_model.predict(X_test)   #tahmin
print (etiket," modelinin sonuçları:",Y_test_preds)

y_preds=np.argmax(Y_test_preds,axis=1)
Y_test_preds=np.argmax(Y_test_preds,axis=1)

acc=round(accuracy_score(Y_test, y_preds),3)
print ("Acc "+etiket+"-"+etiket+ " score:",acc*100)
cm_analysis(Y_test, y_preds, targets, figsize=(5,5))
# Out:
# 16/16 [==============================] - 1s 90ms/step
# ResNet50  modelinin sonuçları: [[1.57128078e-11 1.00000000e+00]
#  [2.70590365e-01 7.29409695e-01]
#  [9.40864331e-11 1.00000000e+00]
#  [2.30618982e-10 1.00000000e+00]
#  [9.99989986e-01 1.00142852e-05]
#  [2.80209296e-08 1.00000000e+00]
#  [2.42772469e-09 1.00000000e+00]
#  [1.00000000e+00 4.22911803e-08]
#  [1.53266111e-08 1.00000000e+00]
#  [9.99999881e-01 7.78140219e-08]
#  [8.24251112e-10 1.00000000e+00]
#  [4.83746987e-10 1.00000000e+00]
#  [2.97647268e-10 1.00000000e+00]
#  [9.99999881e-01 1.20337631e-07]
#  [2.42358477e-12 1.00000000e+00]
#  [1.23753221e-08 1.00000000e+00]
#  [8.66546158e-12 1.00000000e+00]
#  [1.00000000e+00 6.15924511e-09]
#  [1.07399734e-09 1.00000000e+00]
#  [1.25845318e-07 9.99999881e-01]
#  [1.91985947e-08 1.00000000e+00]
#  [4.64787959e-08 1.00000000e+00]
#  [2.70185719e-05 9.99972939e-01]
#  [2.67723262e-01 7.32276738e-01]
#  [1.12867764e-10 1.00000000e+00]
#  [5.79035040e-12 1.00000000e+00]
# ...

# %%
# EKLENDİ 
print("training_accuracy :", history.history['accuracy'][-1])
print("validation_accuracy :", history.history['val_accuracy'][-1])
# Out:
# training_accuracy : 0.996219277381897
# validation_accuracy : 0.7934508919715881

# %%
#EKLENDİ 


#classification report on train
predIdxs = resnet_model.predict (X_train, batch_size=64)
predIdxs = np.argmax(predIdxs, axis=1)
print(classification_report(Y_train.argmax(axis=1), predIdxs, target_names=le.classes_, digits=3))
# Out:
# 31/31 [==============================] - 8s 181ms/step
#               precision    recall  f1-score   support
#
#        COVID      1.000     0.656     0.793      1001
#    non-COVID      0.741     1.000     0.851       983
#
#     accuracy                          0.827      1984
#    macro avg      0.870     0.828     0.822      1984
# weighted avg      0.872     0.827     0.822      1984

# %%
#heatmap
df_cm=pd.DataFrame(confusionmatrix, columns=le.classes_, index=le.classes_)
df_cm.index.name='Actual'
df_cm.columns.name='Predicted'
plt.figure(figsize=(5,5))
sns.heatmap(df_cm/np.sum(df_cm), fmt='.2%', annot=True, annot_kws={'size':16})
plt.savefig(filename)
plt.savefig("/content/drive/MyDrive/tez/saveimage/resnet50confusionmatrix.png")
plt.show()

# %% [markdown]
# ### VGG16 Model Eğitimi ve Testi

# %%
#    vgg16_model
import tensorflow as tf
from keras.models import Sequential
from keras.layers import GlobalAveragePooling2D
from keras.applications import VGG16

vgg16_model = VGG16(input_shape=(224,224,3),include_top=False,weights='imagenet')

vgg16_model.summary()

vgg16_model = tf.keras.Sequential([
        vgg16_model,
        GlobalAveragePooling2D(),
        Dense(512, activation="relu"),
        BatchNormalization(),
        Dropout(0.6),
        Dense(128, activation="relu"),
        BatchNormalization(),
        Dropout(0.4),
        Dense(64,activation="relu"),
        BatchNormalization(),
        Dropout(0.3),
        Dense(2,activation="softmax")
    ])

"""
vgg16_model = tf.keras.Sequential([
        vgg16_model,
        Dense(4096, activation="relu"),
        Dense(4096, activation="relu"),
        Dense(2,activation="softmax")
    ])
"""
# Out:
# ...
# 58889256/58889256 [==============================] - 1s 0us/step
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
# ...

# %%
#Modelimizi derlemek
vgg16_model.compile(loss='binary_crossentropy',optimizer='rmsprop',metrics=['accuracy'])


#Ağımızın özeti gösteriliyor
vgg16_model.summary()

from tensorflow.keras.utils import plot_model

#plot_model(model, to_file='model1.png')
plot_model(vgg16_model, to_file="/content/drive/MyDrive/tez/saveimage/modelvgg16.png")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense_2 (Dense)             (None, 512)               262656
#
#  batch_normalization (BatchN  (None, 512)              2048
#  ormalization)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_3 (Dense)             (None, 128)               65664
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  batch_normalization_2 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 2)                 130
#
# ...

# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from google.colab import drive
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPClassifier
from google.colab import drive
import matplotlib
import os
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
from keras.optimizers import Adam
import numpy as np
from numpy import argmax
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import scipy.misc
from keras.layers import Concatenate, Dense, LSTM, Input, concatenate
from keras import backend as K
from skimage.transform import resize
import os
from keras.models import load_model
from keras.utils import np_utils
import joblib
from keras.layers import Flatten
from keras.models import Model
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import pandas as pd
from  sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
from xgboost import XGBClassifier
from sklearn import svm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.neural_network import MLPClassifier
from keras.models import Model
from keras.layers import Input,Reshape
from keras.layers import Dense, Conv2D, Flatten
from keras.layers import Input, LSTM, Bidirectional, Conv1D
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Embedding
from keras.models import Sequential
from keras.utils import to_categorical
from keras.layers import Flatten
from keras.models import Model
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from keras.layers import Input, LSTM, Dense,Bidirectional 
from keras.models import Model
from sklearn.metrics import  confusion_matrix,classification_report
import pickle
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_classif

def isCheck_Klasor(path):    
    if not os.path.isdir(path):
        os.mkdir( path, 755 );

Image_Width = 224
Image_Height = 224
Cannels = 3

INPUT_SHAPE = (Image_Width, Image_Height, Cannels)
NB_CLASSES = 2
EPOCHS =100
BATCH_SIZE =32


#PLOT 
def plot_ciz_acc_loss(history,fold_index,etiket):
    
    # list all data in history
    print(history.history.keys())
    # summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.savefig(anaKlasor+"/acc_loss_graphs/"+etiket+"_acc_fold_value="+str(fold_index)+".png")
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.savefig(anaKlasor+"/acc_loss_graphs/"+etiket+"_loss_fold_value="+str(fold_index)+".png")
    plt.show()


#Confusion matrix
def cm_analysis(y_train, y_pred, labels, ymap=None, figsize=(10,10)):
    
    """
    Generate matrix plot of confusion matrix with pretty annotations.
    The plot image is saved to disk.
    args: 
      y_true:    true label of the data, with shape (nsamples,)
      y_pred:    prediction of the data, with shape (nsamples,)
      filename:  filename of figure file to save
      labels:    string array, name the order of class labels in the confusion matrix.
                 use `clf.classes_` if using scikit-learn models.
                 with shape (nclass,).
      ymap:      dict: any -> string, length == nclass.
                 if not None, map the labels & ys to more understandable strings.
                 Caution: original y_true, y_pred and labels must align.
      figsize:   the size of the figure plotted.
    """
    labels=[0,1]
    if ymap is not None:
        y_pred = [ymap[yi] for yi in y_pred]
        y_train = [ymap[yi] for yi in y_train]
        labels= [ymap[yi] for yi in labels]
        
    cm = confusion_matrix(y_train, y_preds, labels=labels)
    cm_sum = np.sum(cm, axis=1, keepdims=True)
    cm_perc = cm / cm_sum.astype(float) * 100
    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            c = cm[i, j]
            p = cm_perc[i, j]
            if i == j:
                s = cm_sum[i]
                annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
            elif c == 0:
                annot[i, j] = ''
            else:
                annot[i, j] = '%.1f%%\n%d' % (p, c)
    cm = pd.DataFrame(cm, index=labels, columns=labels)
    cm.index.name = 'Actual'
    cm.columns.name = 'Predicted'
    fig, ax = plt.subplots(figsize=figsize)
    sns.heatmap(cm, annot=annot, fmt='', ax=ax)
    #plt.savefig(filename)
    plt.show()


anaKlasor =  "/content/drive/MyDrive/tez/"
path=anaKlasor+"/features/"

X=np.load(path+"/X.npy")
y=np.load(path+"/y.npy")
X_train, X_test, Y_train, Y_test = train_test_split(X, y, stratify=y, test_size=0.20, random_state=42)
Y_train=to_categorical(Y_train)


vgg16_model.compile(loss='binary_crossentropy',optimizer='rmsprop',metrics=['accuracy'])
etiket="VGG16"

for layer in vgg16_model.layers:
  layer.trainable= True
  

#eğitimi başlat
history = vgg16_model.fit( X_train, Y_train,  validation_split=0.2,epochs = EPOCHS,verbose=1)

# GRAFİK ÇİZİLSİN
plot_ciz_acc_loss(history,"Hold-out",etiket)


Y_train_preds=vgg16_model.predict(X_train)   #tahmin
print (etiket," modelinin sonuçları:",Y_train_preds)

y_preds=np.argmax(Y_train_preds,axis=1)
Y_train=np.argmax(Y_train,axis=1)
acc=round(accuracy_score(Y_train, y_preds),3)
print ("Acc "+etiket+"-"+etiket+ " score:",acc*100)
cm_analysis(Y_train, y_preds, targets, figsize=(5,5))


Y_test_preds=vgg16_model.predict(X_test)   #tahmin
print (etiket," modelinin sonuçları:",Y_test_preds)
y_preds=np.argmax(Y_test_preds,axis=1)
acc=round(accuracy_score(Y_test, y_preds),3)
print ("Acc "+etiket+"-"+etiket+ " score:",acc*100)
cm_analysis(Y_test, y_preds, targets, figsize=(5,5))



vgg16_model.save('../content/drive/MyDrive/tez/models/model_'+etiket+'.h5')

targets=np.load("../content/drive/MyDrive/tez/features/targets.npy")
print (targets)
# Out:
# Epoch 1/100
# 50/50 [==============================] - 49s 570ms/step - loss: 0.7975 - accuracy: 0.6005 - val_loss: 22.6947 - val_accuracy: 0.5189
# Epoch 2/100
# 50/50 [==============================] - 24s 475ms/step - loss: 0.6605 - accuracy: 0.6711 - val_loss: 1.0636 - val_accuracy: 0.6297
# Epoch 3/100
# 50/50 [==============================] - 23s 459ms/step - loss: 0.5472 - accuracy: 0.7669 - val_loss: 35.7275 - val_accuracy: 0.5189
# Epoch 4/100
# 50/50 [==============================] - 22s 449ms/step - loss: 0.4780 - accuracy: 0.8116 - val_loss: 4.2098 - val_accuracy: 0.4811
# Epoch 5/100
# 50/50 [==============================] - 22s 450ms/step - loss: 0.4161 - accuracy: 0.8374 - val_loss: 1.7962 - val_accuracy: 0.5945
# Epoch 6/100
# 50/50 [==============================] - 23s 455ms/step - loss: 0.3940 - accuracy: 0.8286 - val_loss: 0.9564 - val_accuracy: 0.7254
# Epoch 7/100
# ...

# %%
etiket="VGG16"
Y_train_preds=vgg16_model.predict(X_train)   #tahmin
print (etiket," Modelinin Sonuçları: ",Y_train_preds)

y_preds=np.argmax(Y_train_preds,axis=1)
Y_train_preds=np.argmax(Y_train_preds,axis=1)

acc=round(accuracy_score(Y_train, y_preds),3)
print ("Acc "+
etiket+"-"+etiket+ " score:",acc*100)
cm_analysis(Y_train, y_preds, targets, figsize=(5,5))
# Out:
# 62/62 [==============================] - 8s 129ms/step
# VGG16  Modelinin Sonuçları:  [[9.9999988e-01 8.4583519e-08]
#  [9.9999988e-01 1.1482917e-07]
#  [1.0000000e+00 1.1416871e-08]
#  ...
#  [9.9999881e-01 1.1740900e-06]
#  [9.9911422e-01 8.8578212e-04]
#  [9.9996483e-01 3.5198005e-05]]
# Acc VGG16-VGG16 score: 95.8

# %%
####
etiket="VGG16"
Y_test_preds=vgg16_model.predict(X_test)   #tahmin
print (etiket," Modelinin Sonuçları:",Y_test_preds)

y_preds=np.argmax(Y_test_preds,axis=1)
Y_test_preds=np.argmax(Y_test_preds,axis=1)

acc=round(accuracy_score(Y_test, y_preds),3)
print ("Acc "+etiket+"-"+etiket+ " score:",acc*100)
cm_analysis(Y_test, y_preds, targets, figsize=(5,5))
# Out:
# 16/16 [==============================] - 2s 137ms/step
# VGG16  Modelinin Sonuçları: [[1.21161633e-03 9.98788416e-01]
#  [1.00000000e+00 4.48837767e-08]
#  [3.02633071e-05 9.99969721e-01]
#  [4.59077796e-07 9.99999523e-01]
#  [9.99999762e-01 1.81147769e-07]
#  [2.05480147e-10 1.00000000e+00]
#  [3.06014083e-02 9.69398558e-01]
#  [9.99986887e-01 1.31576526e-05]
#  [9.99999404e-01 6.50768413e-07]
#  [9.99999881e-01 1.22414420e-07]
#  [2.31948317e-04 9.99768078e-01]
#  [9.99993682e-01 6.31237708e-06]
#  [3.98469638e-05 9.99960184e-01]
#  [9.99999523e-01 5.16225498e-07]
#  [4.07874019e-08 1.00000000e+00]
#  [2.10651308e-02 9.78934824e-01]
#  [4.50213164e-01 5.49786866e-01]
#  [1.00000000e+00 2.34219666e-08]
#  [1.59815130e-07 9.99999881e-01]
#  [1.00000000e+00 2.28388490e-08]
#  [1.42253842e-09 1.00000000e+00]
#  [9.99998808e-01 1.19649803e-06]
#  [1.00000000e+00 3.64066892e-08]
#  [9.77174580e-01 2.28254106e-02]
#  [3.35764781e-07 9.99999642e-01]
#  [2.99407620e-05 9.99970078e-01]
# ...

# %%
# EKLENDİ 
print("training_accuracy :", history.history['accuracy'][-1])
print("validation_accuracy :", history.history['val_accuracy'][-1])
# Out:
# training_accuracy : 0.9911783337593079
# validation_accuracy : 0.8841309547424316

# %%
# EKLENDİİ 
plt.figure(1, figsize = (15, 5))
plt.subplot(1,2,1)
plt.title(" Veriseti 1, VGG16 Modeli Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.plot( history.history["loss"], label = "Training Loss")
plt.plot( history.history["val_loss"], label = "Validation Loss")
plt.grid(True)
plt.legend()

plt.subplot(1,2,2)
plt.title(" Veriseti 1, VGG16 Modeli Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.plot( history.history["accuracy"], label = "Training Accuracy")
plt.plot( history.history["val_accuracy"], label = "Validation Accuracy")
plt.grid(True)
plt.legend()
plt.show()

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
confusionmatrix=confusion_matrix(Y_train.argmax(axis=1), predIdxs)
print(confusionmatrix)
# Out:
# [[997   4]
#  [ 79 904]]

# %%
#EKLENDİ 
#VGG16

#classification report on train
predIdxs = vgg16_model.predict (X_train, batch_size=64)
predIdxs = np.argmax(predIdxs, axis=1)
print(classification_report(Y_train.argmax(axis=1), predIdxs, target_names=le.classes_, digits=3))
# Out:
# 31/31 [==============================] - 7s 239ms/step
#               precision    recall  f1-score   support
#
#        COVID      0.927     0.996     0.960      1001
#    non-COVID      0.996     0.920     0.956       983
#
#     accuracy                          0.958      1984
#    macro avg      0.961     0.958     0.958      1984
# weighted avg      0.961     0.958     0.958      1984

# %%
#heatmap
df_cm=pd.DataFrame(confusionmatrix, columns=le.classes_, index=le.classes_)
df_cm.index.name='Actual'
df_cm.columns.name='Predicted'
plt.figure(figsize=(5,5))
sns.heatmap(df_cm/np.sum(df_cm), fmt='.2%', annot=True, annot_kws={'size':16})
plt.savefig(filename)
plt.savefig("/content/drive/MyDrive/tez/saveimage/vgg16confusionmatrix.png")
plt.show()

# %%
print(X_train.shape, Y_train.shape)
print( X_test.shape, Y_test.shape)
# Out:
# (1984, 224, 224, 3) (1984,)
# (497, 224, 224, 3) (497,)

# %%
print(X_train.shape, X_test.shape, Y_train.shape, Y_test.shape)
# Out:
# (1984, 224, 224, 3) (497, 224, 224, 3) (1984,) (497,)

# %%
# EKLENDİ  hata

#print(classification_report(Y_train, y_preds))

# %%
#print("y test",Y_test)
#print("y train ",Y_train)

# %%
targets=np.load("../content/drive/MyDrive/tez/features/targets.npy")
print (targets)
# Out:
# ['COVID' 'non-COVID']

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Convolution2D 
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
import os
import shutil
from keras.preprocessing.image import ImageDataGenerator

from keras.models import Sequential
from keras.layers import GlobalAveragePooling2D
from keras.preprocessing import image

                   #  RESNET

resnet_model = ResNet50(input_shape=INPUT_SHAPE,include_top=False,weights='imagenet')
resnet_model.summary()
resnet_model = tf.keras.Sequential([
        resnet_model,
        GlobalAveragePooling2D(),
        Dense(512, activation="relu"),
        BatchNormalization(),
        Dropout(0.6),
        Dense(128, activation="relu"),
        BatchNormalization(),
        Dropout(0.4),
        Dense(64,activation="relu"),
        BatchNormalization(),
        Dropout(0.3),
        Dense(2,activation="softmax") #bu kısımdaki 3 sayısı sizin almak istediğiniz sonuc sayısı.yani covid, zatüre ve normal 3 adet olduğu için 3
    ])
# Out:
# ...
# 94765736/94765736 [==============================] - 1s 0us/step
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_4 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_4[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 112, 112, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_relu[0][0]']
#                                 )
#
# ...

# %%
#Modelimizi derlemek
resnet_model.compile(loss='binary_crossentropy',optimizer='rmsprop',metrics=['accuracy'])

#Ağımızın özeti gösteriliyor
resnet_model.summary()

from tensorflow.keras.utils import plot_model
#plot_model(model, to_file='model1.png')
plot_model(resnet_model, to_file="/content/drive/MyDrive/tez/saveimage/modelresnet.png")
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  global_average_pooling2d_1   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  dense_8 (Dense)             (None, 512)               1049088
#
#  batch_normalization_3 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_9 (Dense)             (None, 128)               65664
#
#  batch_normalization_4 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_10 (Dense)            (None, 64)                8256
#
#  batch_normalization_5 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_5 (Dropout)         (None, 64)                0
#
# ...

# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from google.colab import drive
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPClassifier
from google.colab import drive
import matplotlib
import os
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
from keras.optimizers import Adam
import numpy as np
from numpy import argmax
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import scipy.misc
from keras.layers import Concatenate, Dense, LSTM, Input, concatenate
from keras import backend as K
from skimage.transform import resize
import os
from keras.models import load_model
from keras.utils import np_utils
import joblib
from keras.layers import Flatten
from keras.models import Model
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import pandas as pd
from  sklearn.ensemble import GradientBoostingClassifier
#from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
from xgboost import XGBClassifier
from sklearn import svm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.neural_network import MLPClassifier
from keras.models import Model
from keras.layers import Input,Reshape
from keras.layers import Dense, Conv2D, Flatten
from keras.layers import Input, LSTM, Bidirectional, Conv1D
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Embedding
from keras.models import Sequential
from keras.utils import to_categorical
from keras.layers import Flatten
from keras.models import Model
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from keras.layers import Input, LSTM, Dense,Bidirectional 
from keras.models import Model
from sklearn.metrics import  confusion_matrix,classification_report
import pickle
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_classif

def isCheck_Klasor(path):    
    if not os.path.isdir(path):
        os.mkdir( path, 755 );

def plot_ciz_acc_loss(history,fold_index,etiket):
    
    # list all data in history
    print(history.history.keys())
    # summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.savefig(anaKlasor+"/acc_loss_graphs/"+etiket+"resnet_acc_fold_value="+str(fold_index)+".png")
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.savefig(anaKlasor+"/acc_loss_graphs/"+etiket+"_loss_fold_value="+str(fold_index)+".png")
    plt.show()


def cm_analysis(y_train, y_pred, labels, ymap=None, figsize=(10,10)):
    
    """
    Generate matrix plot of confusion matrix with pretty annotations.
    The plot image is saved to disk.
    args: 
      y_true:    true label of the data, with shape (nsamples,)
      y_pred:    prediction of the data, with shape (nsamples,)
      filename:  filename of figure file to save
      labels:    string array, name the order of class labels in the confusion matrix.
                 use `clf.classes_` if using scikit-learn models.
                 with shape (nclass,).
      ymap:      dict: any -> string, length == nclass.
                 if not None, map the labels & ys to more understandable strings.
                 Caution: original y_true, y_pred and labels must align.
      figsize:   the size of the figure plotted.
    """
    labels=[0,1]
    if ymap is not None:
        y_pred = [ymap[yi] for yi in y_pred]
        y_train = [ymap[yi] for yi in y_train]
        labels = [ymap[yi] for yi in labels]
        
    cm = confusion_matrix(y_train, y_pred, labels=labels)
    cm_sum = np.sum(cm, axis=1, keepdims=True)
    cm_perc = cm / cm_sum.astype(float) * 100
    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            c = cm[i, j]
            p = cm_perc[i, j]
            if i == j:
                s = cm_sum[i]
                annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
            elif c == 0:
                annot[i, j] = ''
            else:
                annot[i, j] = '%.1f%%\n%d' % (p, c)
    cm = pd.DataFrame(cm, index=labels, columns=labels)
    cm.index.name = 'Actual'
    cm.columns.name = 'Predicted'
    fig, ax = plt.subplots(figsize=figsize)
    sns.heatmap(cm, annot=annot, fmt='', ax=ax)
    plt.savefig(filename)
    plt.show()

anaKlasor =  "/content/drive/MyDrive/tez/"
path=anaKlasor+"/features/"

X=np.load(path+"/X.npy")
y=np.load(path+"/y.npy")
X_train, X_test, Y_train, Y_test = train_test_split(X, y, stratify=y, test_size=0.20, random_state=42)
Y_train=to_categorical(Y_train)


EPOCHS =100
BATCH_SIZE = 32

resnet_model.compile(loss='binary_crossentropy',optimizer='rmsprop',metrics=['accuracy'])
etiket="ResNet50"
Y_test_preds=resnet_model.predict(X_test)
print (etiket,"MODELİN SONUÇLARI :",Y_test_preds)


#eğitimi başlat
history = resnet_model.fit( X_train, Y_train,  validation_split=0.2,epochs = EPOCHS,verbose=1)


# GRAFİK ÇİZİLSİN
plot_ciz_acc_loss(history,"Hold-out",etiket)


y_preds=np.argmax(Y_test_preds,axis=1)
acc=round(accuracy_score(Y_test, y_preds),3)
print ("Acc : "+etiket+"-"+etiket+ " score:",acc*100)

#KARIŞIKLIK MATRİSİ
cm_analysis(Y_test, y_preds, targets, figsize=(5,5))


resnet_model.save('../content/drive/MyDrive/tez/models/model_'+etiket+'.h5')

targets=np.load("../content/drive/MyDrive/tez/features/targets.npy")
print (targets)
# Out:
# 16/16 [==============================] - 4s 120ms/step
# ResNet50 MODELİN SONUÇLARI : [[0.48560008 0.51439995]
#  [0.47827604 0.521724  ]
#  [0.314021   0.685979  ]
#  [0.24600641 0.7539936 ]
#  [0.5959955  0.40400445]
#  [0.6046416  0.39535838]
#  [0.40492702 0.595073  ]
#  [0.5057302  0.49426973]
#  [0.4722575  0.52774256]
#  [0.30410305 0.6958969 ]
#  [0.45504022 0.5449598 ]
#  [0.44026747 0.55973256]
#  [0.511669   0.48833108]
#  [0.3820567  0.6179433 ]
#  [0.23506841 0.7649316 ]
#  [0.39963353 0.60036653]
#  [0.49634466 0.5036553 ]
#  [0.2964396  0.7035604 ]
#  [0.42439458 0.57560545]
#  [0.19490217 0.8050978 ]
#  [0.5051783  0.49482173]
#  [0.47312084 0.5268792 ]
#  [0.855125   0.14487502]
#  [0.41070682 0.5892931 ]
#  [0.4306424  0.56935763]
#  [0.5423655  0.4576345 ]
#  [0.23282178 0.7671783 ]
#  [0.2981575  0.7018425 ]
#  [0.5027789  0.49722117]
#  [0.53078836 0.46921167]
#  [0.5248276  0.4751724 ]
#  [0.528595   0.47140497]
#  [0.2661945  0.73380554]
# ...

# %%
# EKLENDİ 
print("training_accuracy :", history.history['accuracy'][-1])
print("validation_accuracy :", history.history['val_accuracy'][-1])
# Out:
# training_accuracy : 0.9974794983863831
# validation_accuracy : 0.8589420914649963

# %%
# EKLENDİİ 
plt.figure(1, figsize = (15, 5))
plt.subplot(1,2,1)
plt.title(" Veriseti 1, RESNET50 Modeli Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.plot( history.history["loss"], label = "Training Loss")
plt.plot( history.history["val_loss"], label = "Validation Loss")

plt.grid(True)
plt.legend()

plt.subplot(1,2,2)
plt.title(" Veriseti 1, RESNET50 Modeli Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.plot( history.history["accuracy"], label = "Training Accuracy")
plt.plot( history.history["val_accuracy"], label = "Validation Accuracy")
plt.grid(True)
plt.legend()
plt.show()

# %%
#EKLENDİ 


#classification report on train
predIdxs = resnet_model.predict (X_train, batch_size=64)
predIdxs = np.argmax(predIdxs, axis=1)
print(classification_report(Y_train.argmax(axis=1), predIdxs, target_names=le.classes_, digits=3))
# Out:
# 31/31 [==============================] - 6s 170ms/step
#               precision    recall  f1-score   support
#
#        COVID      0.994     0.787     0.878      1001
#    non-COVID      0.821     0.995     0.900       983
#
#     accuracy                          0.890      1984
#    macro avg      0.907     0.891     0.889      1984
# weighted avg      0.908     0.890     0.889      1984

# %%
print(classification_report(Y_test, y_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.96      0.89       251
#            1       0.95      0.80      0.87       246
#
#     accuracy                           0.88       497
#    macro avg       0.89      0.88      0.88       497
# weighted avg       0.89      0.88      0.88       497

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
confusionmatrix=confusion_matrix(Y_train.argmax(axis=1), predIdxs)
print(confusionmatrix)
# Out:
# [[788 213]
#  [  5 978]]

# %%
#heatmap
df_cm=pd.DataFrame(confusionmatrix, columns=le.classes_, index=le.classes_)
df_cm.index.name='Actual'
df_cm.columns.name='Predicted'
plt.figure(figsize=(5,5))
sns.heatmap(df_cm/np.sum(df_cm), fmt='.2%', annot=True, annot_kws={'size':16})
plt.savefig(filename)
plt.savefig("/content/drive/MyDrive/tez/saveimage/resnet50confusionmatrix.png")
plt.show()

# %%
print(X_train.shape, Y_train.shape)
print( X_test.shape, Y_test.shape)
# Out:
# (1984, 224, 224, 3) (1984, 2)
# (497, 224, 224, 3) (497,)

# %%
print(X_train.shape, X_test.shape, Y_train.shape, Y_test.shape)
# Out:
# (1984, 224, 224, 3) (497, 224, 224, 3) (1984, 2) (497,)

# %%
targets=np.load("../content/drive/MyDrive/tez/features/targets.npy")
print (targets)
# Out:
# ['COVID' 'non-COVID']

# %% [markdown]
# # vgg16 deneme

# %%
#    DENEMEEE 
#vgg16_model

import tensorflow as tf
from keras.models import Sequential
from keras.layers import GlobalAveragePooling2D
from keras.applications import VGG16

vgg16_model = VGG16(input_shape=(224,224,3),include_top=False,weights='imagenet')

vgg16_model.summary()

vgg16_model = tf.keras.Sequential([
        vgg16_model,
        GlobalAveragePooling2D(),
        Dense(512, activation="relu"),
        BatchNormalization(),
        Dropout(0.6),
        Dense(128, activation="relu"),
        BatchNormalization(),
        Dropout(0.4),
        Dense(64,activation="relu"),
        BatchNormalization(),
        Dropout(0.3),
        Dense(2,activation="softmax")
    ])

"""
vgg16_model = tf.keras.Sequential([
        vgg16_model,
        Dense(4096, activation="relu"),
        Dense(4096, activation="relu"),
        Dense(2,activation="softmax")
    ])
"""


#Modelimizi derlemek
vgg16_model.compile(loss='binary_crossentropy',optimizer='rmsprop',metrics=['accuracy'])


#Ağımızın özeti gösteriliyor
vgg16_model.summary()

from tensorflow.keras.utils import plot_model

#plot_model(model, to_file='model1.png')
plot_model(vgg16_model, to_file="/content/drive/MyDrive/tez/saveimage/modelvgg16.png")

# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from google.colab import drive
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPClassifier
from google.colab import drive
import matplotlib
import os
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
from keras.optimizers import Adam
import numpy as np
from numpy import argmax
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import scipy.misc
from keras.layers import Concatenate, Dense, LSTM, Input, concatenate
from keras import backend as K
from skimage.transform import resize
import os
from keras.models import load_model
from keras.utils import np_utils
import joblib
from keras.layers import Flatten
from keras.models import Model
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import pandas as pd
from  sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
from xgboost import XGBClassifier
from sklearn import svm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.neural_network import MLPClassifier
from keras.models import Model
from keras.layers import Input,Reshape
from keras.layers import Dense, Conv2D, Flatten
from keras.layers import Input, LSTM, Bidirectional, Conv1D
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Embedding
from keras.models import Sequential
from keras.utils import to_categorical
from keras.layers import Flatten
from keras.models import Model
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from keras.layers import Input, LSTM, Dense,Bidirectional 
from keras.models import Model
from sklearn.metrics import  confusion_matrix,classification_report
import pickle
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_classif

def isCheck_Klasor(path):    
    if not os.path.isdir(path):
        os.mkdir( path, 755 );

Image_Width = 224
Image_Height = 224
Cannels = 3

INPUT_SHAPE = (Image_Width, Image_Height, Cannels)
NB_CLASSES = 2
EPOCHS =100
BATCH_SIZE =32


#PLOT 
def plot_ciz_acc_loss(history,fold_index,etiket):
    
    # list all data in history
    print(history.history.keys())
    # summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.savefig(anaKlasor+"/acc_loss_graphs/"+etiket+"_acc_fold_value="+str(fold_index)+".png")
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.savefig(anaKlasor+"/acc_loss_graphs/"+etiket+"_loss_fold_value="+str(fold_index)+".png")
    plt.show()


#Confusion matrix
def cm_analysis(y_train, y_pred, labels, ymap=None, figsize=(10,10)):
    
    """
    Generate matrix plot of confusion matrix with pretty annotations.
    The plot image is saved to disk.
    args: 
      y_true:    true label of the data, with shape (nsamples,)
      y_pred:    prediction of the data, with shape (nsamples,)
      filename:  filename of figure file to save
      labels:    string array, name the order of class labels in the confusion matrix.
                 use `clf.classes_` if using scikit-learn models.
                 with shape (nclass,).
      ymap:      dict: any -> string, length == nclass.
                 if not None, map the labels & ys to more understandable strings.
                 Caution: original y_true, y_pred and labels must align.
      figsize:   the size of the figure plotted.
    """
    labels=[0,1]
    if ymap is not None:
        y_pred = [ymap[yi] for yi in y_pred]
        y_train = [ymap[yi] for yi in y_train]
        labels= [ymap[yi] for yi in labels]
        
    cm = confusion_matrix(y_train, y_preds, labels=labels)
    cm_sum = np.sum(cm, axis=1, keepdims=True)
    cm_perc = cm / cm_sum.astype(float) * 100
    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            c = cm[i, j]
            p = cm_perc[i, j]
            if i == j:
                s = cm_sum[i]
                annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
            elif c == 0:
                annot[i, j] = ''
            else:
                annot[i, j] = '%.1f%%\n%d' % (p, c)
    cm = pd.DataFrame(cm, index=labels, columns=labels)
    cm.index.name = 'Actual'
    cm.columns.name = 'Predicted'
    fig, ax = plt.subplots(figsize=figsize)
    sns.heatmap(cm, annot=annot, fmt='', ax=ax)
    #plt.savefig(filename)
    plt.show()


anaKlasor =  "/content/drive/MyDrive/tez/"
path=anaKlasor+"/features/"

X=np.load(path+"/X.npy")
y=np.load(path+"/y.npy")
X_train, X_test, Y_train, Y_test = train_test_split(X, y, stratify=y, test_size=0.20, random_state=42)
Y_train=to_categorical(Y_train)


vgg16_model.compile(loss='binary_crossentropy',optimizer='rmsprop',metrics=['accuracy'])
etiket="VGG16"

for layer in vgg16_model.layers:
  layer.trainable= True
  

#eğitimi başlat
history = vgg16_model.fit( X_train, Y_train,  validation_split=0.2,epochs = EPOCHS,verbose=1)

# GRAFİK ÇİZİLSİN
plot_ciz_acc_loss(history,"Hold-out",etiket)

####
etiket="VGG16"
Y_train_preds=vgg16_model.predict(X_train)   #tahmin
print (etiket," Modelinin Sonuçları: ",Y_train_preds)

y_preds=np.argmax(Y_train_preds,axis=1)
Y_train_preds=np.argmax(Y_train_preds,axis=1)

acc=round(accuracy_score(Y_train, y_preds),3)
print ("Acc "+
etiket+"-"+etiket+ " score:",acc*100)
cm_analysis(Y_train, y_preds, targets, figsize=(5,5))

####
etiket="VGG16"
Y_test_preds=vgg16_model.predict(X_test)   #tahmin
print (etiket," Modelinin Sonuçları:",Y_test_preds)

y_preds=np.argmax(Y_test_preds,axis=1)
Y_test_preds=np.argmax(Y_test_preds,axis=1)

acc=round(accuracy_score(Y_test, y_preds),3)
print ("Acc "+etiket+"-"+etiket+ " score:",acc*100)
cm_analysis(Y_test, y_preds, targets, figsize=(5,5))



vgg16_model.save('../content/drive/MyDrive/tez/models/model_'+etiket+'.h5')

targets=np.load("../content/drive/MyDrive/tez/features/targets.npy")
print (targets)

# %%
# EKLENDİ 
print("training_accuracy :", history.history['accuracy'][-1])
print("validation_accuracy :", history.history['val_accuracy'][-1])

# %%
#EKLENDİ 


#classification report on train
predIdxs = resnet_model.predict (X_train, batch_size=64)
predIdxs = np.argmax(predIdxs, axis=1)
print(classification_report(Y_train.argmax(axis=1), predIdxs, target_names=le.classes_, digits=3))

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
confusionmatrix=confusion_matrix(Y_train.argmax(axis=1), predIdxs)
print(confusionmatrix)

# %%
#heatmap
df_cm=pd.DataFrame(confusionmatrix, columns=le.classes_, index=le.classes_)
df_cm.index.name='Actual'
df_cm.columns.name='Predicted'
plt.figure(figsize=(5,5))
sns.heatmap(df_cm/np.sum(df_cm), fmt='.2%', annot=True, annot_kws={'size':16})
plt.savefig(filename)
plt.savefig("/content/drive/MyDrive/tez/saveimage/resnet50confusionmatrix.png")
plt.show()

# %% [markdown]
# # DENSENET 201

# %%
# import libraries
import json
import math
import os
from glob import glob 
from tqdm import tqdm
from PIL import Image
import cv2 # image processing
import numpy as np # linear algebra
import pandas as pd # data processing
import matplotlib.pyplot as plt # data visualization

from sklearn.metrics import accuracy_score 
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report 
from sklearn.model_selection import train_test_split

from keras import layers
from keras.models import Sequential
from keras.optimizers import Adam, RMSprop
from keras.applications import DenseNet201
from keras.utils.np_utils import to_categorical
from keras.layers import  Conv2D,MaxPooling2D,Activation,Dropout,Flatten,Dense,BatchNormalization

# %%
tf.keras.applications.densenet.DenseNet201(
    include_top=True,
    weights='imagenet',
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classes=1000,
    classifier_activation='softmax'
)
# Out:
# ...
# 82524592/82524592 [==============================] - 0s 0us/step

# %%
#    vgg16_model

from keras.models import Sequential
from keras.layers import GlobalAveragePooling2D
from keras.applications import DenseNet201
densenet_base_model = DenseNet201(input_shape=INPUT_SHAPE,include_top=False,weights='imagenet')

densenet_base_model.summary()
densenet_model = tf.keras.Sequential([
        densenet_base_model,
        GlobalAveragePooling2D(),
        Dense(512, activation="relu"),
        BatchNormalization(),
        Dropout(0.6),
        Dense(128, activation="relu"),
        BatchNormalization(),
        Dropout(0.4),
        Dense(64,activation="relu"),
        BatchNormalization(),
        Dropout(0.3),
        Dense(2,activation="softmax")
    ])
# Out:
# Model: "densenet201"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_19 (InputLayer)          [(None, 224, 224, 3  0           []
#                                 )]
#
#  zero_padding2d_26 (ZeroPadding  (None, 230, 230, 3)  0          ['input_19[0][0]']
#  2D)
#
#  conv1/conv (Conv2D)            (None, 112, 112, 64  9408        ['zero_padding2d_26[0][0]']
#                                 )
#
#  conv1/bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1/conv[0][0]']
#                                 )
#
#  conv1/relu (Activation)        (None, 112, 112, 64  0           ['conv1/bn[0][0]']
#                                 )
#
#  zero_padding2d_27 (ZeroPadding  (None, 114, 114, 64  0          ['conv1/relu[0][0]']
#  2D)                            )
#
# ...

# %%
#Modelimizi derlemek
densenet_model.compile(loss='binary_crossentropy',optimizer='rmsprop',metrics=['accuracy'])


#Ağımızın özeti gösteriliyor
densenet_model.summary()

from tensorflow.keras.utils import plot_model
#plot_model(model, to_file='model1.png')
plot_model(densenet_model, to_file="/content/drive/MyDrive/tez/saveimage/densenet_model.png")
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  densenet201 (Functional)    (None, 7, 7, 1920)        18321984
#
#  global_average_pooling2d_10  (None, 1920)             0
#   (GlobalAveragePooling2D)
#
#  dense_23 (Dense)            (None, 512)               983552
#
#  batch_normalization_16 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dropout_16 (Dropout)        (None, 512)               0
#
#  dense_24 (Dense)            (None, 128)               65664
#
#  batch_normalization_17 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_17 (Dropout)        (None, 128)               0
#
#  dense_25 (Dense)            (None, 64)                8256
#
#  batch_normalization_18 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_18 (Dropout)        (None, 64)                0
#
# ...

# %%
# Create DenseNet201 Model with Keras library

def build_model(backbone, lr=1e-4):
    densenet_model = Sequential()
    densenet_model.add(backbone)
    densenet_model.add(layers.GlobalAveragePooling2D())
    densenet_model.add(layers.Dropout(0.5))
    densenet_model.add(layers.BatchNormalization())
    densenet_model.add(layers.Dense(2, activation='sigmoid'))
    
    densenet_model.compile(
        loss='binary_crossentropy',
        optimizer=Adam(lr=lr),
        metrics=['acc']
    )
    return densenet_model

densenet_model = DenseNet201(
    weights='imagenet',
    include_top=False,
    input_shape=(150,150,3)
)

densenet_model = build_model(densenet_model ,lr = 1e-4)


densenet_model.summary()

from tensorflow.keras.utils import plot_model
#plot_model(model, to_file='model1.png')
plot_model(densenet_model, to_file="/content/drive/MyDrive/tez/saveimage/densenet201.png")

# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from google.colab import drive
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPClassifier
from google.colab import drive
import matplotlib
import os
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
from keras.optimizers import Adam
import numpy as np
from numpy import argmax
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import scipy.misc
from keras.layers import Concatenate, Dense, LSTM, Input, concatenate
from keras import backend as K
from skimage.transform import resize
import os
from keras.models import load_model
from keras.utils import np_utils
import joblib
from keras.layers import Flatten
from keras.models import Model
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import pandas as pd
from  sklearn.ensemble import GradientBoostingClassifier
#from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
from xgboost import XGBClassifier
from sklearn import svm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.neural_network import MLPClassifier
from keras.models import Model
from keras.layers import Input,Reshape
from keras.layers import Dense, Conv2D, Flatten
from keras.layers import Input, LSTM, Bidirectional, Conv1D
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Embedding
from keras.models import Sequential
from keras.utils import to_categorical
from keras.layers import Flatten
from keras.models import Model
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from keras.layers import Input, LSTM, Dense,Bidirectional 
from keras.models import Model
from sklearn.metrics import  confusion_matrix,classification_report
import pickle
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_classif

def isCheck_Klasor(path):    
    if not os.path.isdir(path):
        os.mkdir( path, 755 );


def plot_ciz_acc_loss(history,fold_index,etiket):
    
    # list all data in history
    print(history.history.keys())
    # summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.savefig(anaKlasor+"/acc_loss_graphs/"+etiket+"resnet_acc_fold_value="+str(fold_index)+".png")
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.savefig(anaKlasor+"/acc_loss_graphs/"+etiket+"_loss_fold_value="+str(fold_index)+".png")
    plt.show()



def cm_analysis(y_train, y_pred, labels, ymap=None, figsize=(10,10)):
    
    """
    Generate matrix plot of confusion matrix with pretty annotations.
    The plot image is saved to disk.
    args: 
      y_true:    true label of the data, with shape (nsamples,)
      y_pred:    prediction of the data, with shape (nsamples,)
      filename:  filename of figure file to save
      labels:    string array, name the order of class labels in the confusion matrix.
                 use `clf.classes_` if using scikit-learn models.
                 with shape (nclass,).
      ymap:      dict: any -> string, length == nclass.
                 if not None, map the labels & ys to more understandable strings.
                 Caution: original y_true, y_pred and labels must align.
      figsize:   the size of the figure plotted.
    """
    labels=[0,1]
    if ymap is not None:
        y_pred = [ymap[yi] for yi in y_pred]
        y_train = [ymap[yi] for yi in y_train]
        labels = [ymap[yi] for yi in labels]
        
    cm = confusion_matrix(y_train, y_pred, labels=labels)
    cm_sum = np.sum(cm, axis=1, keepdims=True)
    cm_perc = cm / cm_sum.astype(float) * 100
    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            c = cm[i, j]
            p = cm_perc[i, j]
            if i == j:
                s = cm_sum[i]
                annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
            elif c == 0:
                annot[i, j] = ''
            else:
                annot[i, j] = '%.1f%%\n%d' % (p, c)
    cm = pd.DataFrame(cm, index=labels, columns=labels)
    cm.index.name = 'Actual'
    cm.columns.name = 'Predicted'
    fig, ax = plt.subplots(figsize=figsize)
    sns.heatmap(cm, annot=annot, fmt='', ax=ax)
    #plt.savefig(filename)
    plt.show()


anaKlasor =  "/content/drive/MyDrive/tez/"
path=anaKlasor+"/features/"

X=np.load(path+"/X.npy")
y=np.load(path+"/y.npy")
X_train, X_test, Y_train, Y_test = train_test_split(X, y, stratify=y, test_size=0.20, random_state=42)
Y_train=to_categorical(Y_train)



Cannels = 3
EPOCHS =100
BATCH_SIZE = 16

densenet_model = DenseNet201(
    weights='imagenet',
    include_top=False,
    input_shape=(150,150,3)
)


densenet_model.compile(loss='binary_crossentropy',optimizer='rmsprop',metrics=['accuracy'])
etiket="densenet201"
Y_test_preds=densenet_model.predict(X_test)
print (etiket," MODELİN SONUÇLARI :",Y_test_preds)


#eğitimi başlat
history = densenet_model.fit( X_train, Y_train,  validation_split=0.2,epochs = EPOCHS,verbose=1)

#GRAFİK ÇİZİLSİN
plot_ciz_acc_loss(history,"Hold-out",etiket)

y_preds=np.argmax(Y_test_preds,axis=1)
acc=round(accuracy_score(Y_test, y_preds),3)
print ("Acc "+etiket+"-"+etiket+ " score:",acc*100)
cm_analysis(Y_test, y_preds, targets, figsize=(5,5))



densenet_model.save('../content/drive/MyDrive/tez/models/model_'+etiket+'.h5')


targets=np.load("../content/drive/MyDrive/tez/features/targets.npy")
print (targets)

# %%
# DENSENET201 EKLENDİ 
print("training_accuracy", history.history['accuracy'][-1])
print("validation_accuracy", history.history['val_accuracy'][-1])

# %%
# DENSENET201  EKLENDİİ 
plt.figure(1, figsize = (15, 5))
plt.subplot(1,2,1)
plt.title(" Veriseti 1, DENSENET201 Modeli Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.plot( history.history["loss"], label = "Training Loss")
plt.plot( history.history["val_loss"], label = "Validation Loss")
plt.grid(True)
plt.legend()

plt.subplot(1,2,2)
plt.title(" Veriseti 1, DENSENET201 Modeli Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.plot( history.history["accuracy"], label = "Training Accuracy")
plt.plot( history.history["val_accuracy"], label = "Validation Accuracy")
plt.grid(True)
plt.legend()
plt.show()

# %%
# DENSENET201 EKLENDİ 


#classification report on train
predIdxs = densenet_model.predict (X_train, batch_size=64)
predIdxs = np.argmax(predIdxs, axis=1)
print(classification_report(Y_train.argmax(axis=1), predIdxs, target_names=le.classes_, digits=3))

# %%
#heatmap
df_cm=pd.DataFrame(confusionmatrix, columns=le.classes_, index=le.classes_)
df_cm.index.name='Actual'
df_cm.columns.name='Predicted'
plt.figure(figsize=(5,5))
sns.heatmap(df_cm/np.sum(df_cm), fmt='.2%', annot=True, annot_kws={'size':16})
plt.savefig(filename)
plt.savefig("/content/drive/MyDrive/tez/saveimage/DENSENET201confusionmatrix.png")
plt.show()

# %%
print(X_train.shape, Y_train.shape)
print( X_test.shape, Y_test.shape)

# %%
print(X_train.shape, X_test.shape, Y_train.shape, Y_test.shape)

# %% [markdown]
# # VGG19

# %%
from keras.layers import Dense, Conv2D, MaxPooling2D, AvgPool2D, Input, Dropout, Flatten, BatchNormalization
from keras.models import Sequential, Model
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.vgg19 import VGG19

# %%
#    vgg19_model
import tensorflow as tf
from keras.models import Sequential
from keras.layers import GlobalAveragePooling2D
from keras.applications.vgg19 import VGG19
vgg19_base_model = VGG19(input_shape=INPUT_SHAPE,include_top=False,weights='imagenet')

vgg19_base_model.summary()
vgg19_model = tf.keras.Sequential([
        vgg19_base_model,
        GlobalAveragePooling2D(),
        Dense(512, activation="relu"),
        BatchNormalization(),
        Dropout(0.6),
        Dense(128, activation="relu"),
        BatchNormalization(),
        Dropout(0.4),
        Dense(64,activation="relu"),
        BatchNormalization(),
        Dropout(0.3),
        Dense(2,activation="softmax")
    ])
# Out:
# ...
# 80134624/80134624 [==============================] - 0s 0us/step
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_5 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
# ...

# %%
# VGG19 Modelimizi derlemek
vgg19_model.compile(loss='binary_crossentropy',optimizer='rmsprop',metrics=['accuracy'])


#Ağımızın özeti gösteriliyor
vgg19_model.summary()

from tensorflow.keras.utils import plot_model

#plot_model(model, to_file='model1.png')
plot_model(vgg19_model, to_file="/content/drive/MyDrive/tez/saveimage/modelvgg19.png")
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  vgg19 (Functional)          (None, 7, 7, 512)         20024384
#
#  global_average_pooling2d_2   (None, 512)              0
#  (GlobalAveragePooling2D)
#
#  dense_12 (Dense)            (None, 512)               262656
#
#  batch_normalization_6 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_6 (Dropout)         (None, 512)               0
#
#  dense_13 (Dense)            (None, 128)               65664
#
#  batch_normalization_7 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  dense_14 (Dense)            (None, 64)                8256
#
#  batch_normalization_8 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_8 (Dropout)         (None, 64)                0
#
#  dense_15 (Dense)            (None, 2)                 130
# ...

# %%
#PLOT 
def plot_ciz_acc_loss(history,fold_index,etiket):
    
    # list all data in history
    print(history.history.keys())
    # summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.savefig(anaKlasor+"/acc_loss_graphs/"+etiket+"_acc_fold_value="+str(fold_index)+".png")
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.savefig(anaKlasor+"/acc_loss_graphs/"+etiket+"_loss_fold_value="+str(fold_index)+".png")
    plt.show()


#Confusion matrix
def cm_analysis(Y_train, y_preds, labels, ymap=None, figsize=(10,10)):
    
    """
    Generate matrix plot of confusion matrix with pretty annotations.
    The plot image is saved to disk.
    args: 
      y_true:    true label of the data, with shape (nsamples,)
      y_pred:    prediction of the data, with shape (nsamples,)
      filename:  filename of figure file to save
      labels:    string array, name the order of class labels in the confusion matrix.
                 use `clf.classes_` if using scikit-learn models.
                 with shape (nclass,).
      ymap:      dict: any -> string, length == nclass.
                 if not None, map the labels & ys to more understandable strings.
                 Caution: original y_true, y_pred and labels must align.
      figsize:   the size of the figure plotted.
    """
    labels=[0,1]
    if ymap is not None:
        y_preds = [ymap[yi] for yi in y_preds]
        Y_train = [ymap[yi] for yi in Y_train]
        labels= [ymap[yi] for yi in labels]
        
    cm = confusion_matrix(Y_train, y_preds, labels=labels)
    cm_sum = np.sum(cm, axis=1, keepdims=True)
    cm_perc = cm / cm_sum.astype(float) * 100
    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            c = cm[i, j]
            p = cm_perc[i, j]
            if i == j:
                s = cm_sum[i]
                annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
            elif c == 0:
                annot[i, j] = ''
            else:
                annot[i, j] = '%.1f%%\n%d' % (p, c)
    cm = pd.DataFrame(cm, index=labels, columns=labels)
    cm.index.name = 'Actual'
    cm.columns.name = 'Predicted'
    fig, ax = plt.subplots(figsize=figsize)
    sns.heatmap(cm, annot=annot, fmt='', ax=ax)
    plt.savefig(filename)
    plt.show()

# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from google.colab import drive
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPClassifier
from google.colab import drive
import matplotlib
import os
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
from keras.optimizers import Adam
import numpy as np
from numpy import argmax
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import scipy.misc
from keras.layers import Concatenate, Dense, LSTM, Input, concatenate
from keras import backend as K
from skimage.transform import resize
import os
from keras.models import load_model
from keras.utils import np_utils
import joblib
from keras.layers import Flatten
from keras.models import Model
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import pandas as pd
from  sklearn.ensemble import GradientBoostingClassifier
#from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
from xgboost import XGBClassifier
from sklearn import svm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.neural_network import MLPClassifier
from keras.models import Model
from keras.layers import Input,Reshape
from keras.layers import Dense, Conv2D, Flatten
from keras.layers import Input, LSTM, Bidirectional, Conv1D
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Embedding
from keras.models import Sequential
from keras.utils import to_categorical
from keras.layers import Flatten
from keras.models import Model
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from keras.layers import Input, LSTM, Dense,Bidirectional 
from keras.models import Model
from sklearn.metrics import  confusion_matrix,classification_report
import pickle
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_classif

def isCheck_Klasor(path):    
    if not os.path.isdir(path):
        os.mkdir( path, 755 );

Image_Width = 224
Image_Height = 224
Cannels = 3

INPUT_SHAPE = (Image_Width, Image_Height, Cannels)
NB_CLASSES = 2
EPOCHS =100
BATCH_SIZE =32


anaKlasor =  "/content/drive/MyDrive/tez/"
path=anaKlasor+"/features/"

X=np.load(path+"/X.npy")
y=np.load(path+"/y.npy")
X_train, X_test, Y_train, Y_test = train_test_split(X, y, stratify=y, test_size=0.20, random_state=42)
Y_train=to_categorical(Y_train)



vgg19_model.compile(loss='binary_crossentropy',optimizer='rmsprop',metrics=['accuracy'])
etiket="VGG19"
#eğitimi başlat
history = vgg19_model.fit( X_train, Y_train,  validation_split=0.2,epochs = EPOCHS,verbose=1)

# GRAFİK ÇİZİLSİN
plot_ciz_acc_loss(history,"Hold-out",etiket)

Y_test_preds=vgg19_model.predict(X_test)   #tahmin
print (etiket," MODELİN SONUÇLARI:",Y_test_preds)





y_preds=np.argmax(Y_test_preds,axis=1)
acc=round(accuracy_score(Y_test, y_preds),3)
print ("Acc "+etiket+"-"+etiket+ " score:",acc*100)

#KARIŞIKLIK MATRİSİ
cm_analysis(Y_test, y_preds, targets, figsize=(5,5))


vgg19_model.save('../content/drive/MyDrive/tez/models/model_'+etiket+'.h5')

targets=np.load("../content/drive/MyDrive/tez/features/targets.npy")
print (targets)
# Out:
# 16/16 [==============================] - 2s 146ms/step
# VGG19  MODELİN SONUÇLARI: [[9.10780609e-01 8.92193913e-02]
#  [9.88880873e-01 1.11191822e-02]
#  [9.96593416e-01 3.40652140e-03]
#  [9.91189837e-01 8.81014299e-03]
#  [9.67752218e-01 3.22477818e-02]
#  [9.77023423e-01 2.29766052e-02]
#  [9.46347296e-01 5.36526591e-02]
#  [9.99283612e-01 7.16411567e-04]
#  [9.57387686e-01 4.26123105e-02]
#  [9.97929335e-01 2.07067304e-03]
#  [9.70444322e-01 2.95557044e-02]
#  [9.76436853e-01 2.35631373e-02]
#  [9.98364627e-01 1.63542002e-03]
#  [9.96565521e-01 3.43445549e-03]
#  [9.86957073e-01 1.30428942e-02]
#  [9.99776542e-01 2.23415293e-04]
#  [9.77927804e-01 2.20721625e-02]
#  [9.91347492e-01 8.65255855e-03]
#  [9.75902021e-01 2.40979772e-02]
#  [9.91361082e-01 8.63896590e-03]
#  [8.98838580e-01 1.01161368e-01]
#  [9.47835863e-01 5.21641821e-02]
#  [9.97119188e-01 2.88088247e-03]
#  [9.77982283e-01 2.20177323e-02]
#  [9.70574200e-01 2.94257309e-02]
#  [9.92079198e-01 7.92081747e-03]
# ...

# %%
#VGG19 EKLENDİ 
print(" VGG19 training_accuracy", history.history['accuracy'][-1])
print(" VGG19 validation_accuracy", history.history['val_accuracy'][-1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1d4bcb3cb518> in <module>
#       1 # EKLENDİ
# ----> 2 print(" VGG19 training_accuracy", history.history['accuracy'][-1])
#       3 print(" VGG19 validation_accuracy", history.history['val_accuracy'][-1])
#
# NameError: name 'history' is not defined

# %%
# VGG19 EKLENDİİ 
plt.figure(1, figsize = (15, 5))
plt.subplot(1,2,1)
plt.title(" Veriseti 1, VGG19 Modeli Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.plot( history.history["loss"], label = "Training Loss")
plt.plot( history.history["val_loss"], label = "Validation Loss")
plt.savefig("/content/drive/MyDrive/tez/saveimage/vggGRAFİK19.png")
plt.grid(True)
plt.legend()

plt.subplot(1,2,2)
plt.title(" Veriseti 1, VGG19 Modeli Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.plot( history.history["accuracy"], label = "Training Accuracy")
plt.plot( history.history["val_accuracy"], label = "Validation Accuracy")
plt.grid(True)
plt.legend()
plt.savefig("/content/drive/MyDrive/tez/saveimage/vgg19grafik.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0f06d5c858ec> in <module>
#       1 # EKLENDİİ
# ----> 2 plt.figure(1, figsize = (15, 5))
#       3 plt.subplot(1,2,1)
#       4 plt.title(" Veriseti 1, VGG19 Modeli Loss")
#       5 plt.xlabel("Epochs")
#
# NameError: name 'plt' is not defined

# %%
# VGG19 confusion matrix
from sklearn.metrics import confusion_matrix
confusionmatrix=confusion_matrix(Y_train.argmax(axis=1), predIdxs)
print(confusionmatrix)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-4c9230d24f47> in <module>
#       1 #confusion matrix
#       2 from sklearn.metrics import confusion_matrix
# ----> 3 confusionmatrix=confusion_matrix(Y_train.argmax(axis=1), predIdxs)
#       4 print(confusionmatrix)
#       5
#
# NameError: name 'Y_train' is not defined

# %%
#VGG19
#heatmap
df_cm=pd.DataFrame(confusionmatrix, columns=le.classes_, index=le.classes_)
df_cm.index.name='Actual'
df_cm.columns.name='Predicted'
plt.figure(figsize=(5,5))
sns.heatmap(df_cm/np.sum(df_cm), fmt='.2%', annot=True, annot_kws={'size':16})
plt.savefig(filename)
plt.savefig("/content/drive/MyDrive/tez/saveimage/vgg19confusionmatrix.png")
plt.show()

# %%
print(X_train.shape, Y_train.shape)
print( X_test.shape, Y_test.shape)
# Out:
# (1984, 224, 224, 3) (1984, 2)
# (497, 224, 224, 3) (497,)

# %%
print(X_train.shape, X_test.shape, Y_train.shape, Y_test.shape)
# Out:
# (1984, 224, 224, 3) (497, 224, 224, 3) (1984, 2) (497,)

# %%
vgg19 = keras.applications.vgg19

conv_model = vgg19.VGG19(weights='imagenet', include_top=False, input_shape=(224,224,3))

for layer in conv_model.layers: 
    layer.trainable = False
x = keras.layers.Flatten()(conv_model.output)
x = keras.layers.Dense(100, activation='relu')(x)
x = keras.layers.Dense(100, activation='relu')(x)
x = keras.layers.Dense(100, activation='relu')(x)
predictions = keras.layers.Dense(2, activation='softmax')(x)

full_model = keras.models.Model(inputs=conv_model.input, outputs=predictions)
full_model.summary()
# Out:
# ...
# 80134624/80134624 [==============================] - 0s 0us/step
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_23 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
# ...

# %%
INPUT_SHAPE = (Image_Width, Image_Height, Cannels)
NB_CLASSES = 2
EPOCHS =100
BATCH_SIZE =16

full_model.compile(loss='binary_crossentropy',
                  optimizer=keras.optimizers.Adamax(lr=0.001),
                  metrics=['acc'])

history = full_model.fit( X_train, Y_train,  validation_split=0.2,epochs = EPOCHS,verbose=1)
# Out:
# Epoch 1/100
# 50/50 [==============================] - 10s 195ms/step - loss: 1.0472 - acc: 0.8721 - val_loss: 0.2386 - val_acc: 0.9219
# Epoch 2/100
# 50/50 [==============================] - 9s 175ms/step - loss: 0.0499 - acc: 0.9842 - val_loss: 0.1758 - val_acc: 0.9446
# Epoch 3/100
# 50/50 [==============================] - 10s 193ms/step - loss: 0.0124 - acc: 0.9975 - val_loss: 0.1950 - val_acc: 0.9345
# Epoch 4/100
# 50/50 [==============================] - 9s 177ms/step - loss: 0.0049 - acc: 1.0000 - val_loss: 0.1754 - val_acc: 0.9446
# Epoch 5/100
# 50/50 [==============================] - 9s 178ms/step - loss: 0.0028 - acc: 1.0000 - val_loss: 0.1951 - val_acc: 0.9370
# Epoch 6/100
# 50/50 [==============================] - 9s 178ms/step - loss: 0.0019 - acc: 1.0000 - val_loss: 0.1840 - val_acc: 0.9395
# Epoch 7/100
# 50/50 [==============================] - 9s 180ms/step - loss: 0.0015 - acc: 1.0000 - val_loss: 0.1967 - val_acc: 0.9370
# Epoch 8/100
# ...

# %%
vgg19_model = VGG19(weights='imagenet',include_top=False,input_shape=(224,224,3))

for layer in vgg19_model.layers:
    layer.trainable = False
    
model = Sequential()
model.add(vgg19_model)
model.add(Flatten())
model.add(Dense(2,activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  vgg19 (Functional)          (None, 7, 7, 512)         20024384
#
#  flatten_1 (Flatten)         (None, 25088)             0
#
#  dense_31 (Dense)            (None, 2)                 50178
#
# ...
# Total params: 20,074,562
# Trainable params: 50,178
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
#EKLENDİ 


#classification report on train
predIdxs = vgg19_model.predict (X_train, batch_size=64)
predIdxs = np.argmax(predIdxs, axis=1)
print(classification_report(Y_train.argmax(axis=1), predIdxs, target_names=le.classes_, digits=3))
# Out:
# 31/31 [==============================] - 8s 270ms/step
#               precision    recall  f1-score   support
#
#        COVID      0.505     1.000     0.671      1001
#    non-COVID      0.000     0.000     0.000       983
#
#     accuracy                          0.505      1984
#    macro avg      0.252     0.500     0.335      1984
# weighted avg      0.255     0.505     0.338      1984
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# ...

# %%
from tensorflow.keras.models import load_model
model.save('VGG19.h5')

# %% [markdown]
# # K-FOLD

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split,KFold,cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
X, y = load_wine(return_X_y=True)

# %%
# Train/Test Split : random_state = 49
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=49)

rf_model = RandomForestClassifier()
rf_model.fit(X_train, y_train)

y_pred = rf_model.predict(X_test)

accuracy_score(y_test, y_pred)
print('Accuracy score for random_state = 49 : ' + str(accuracy_score(y_test, y_pred)))

# %%
# Train/Test Split  : random_state = 1234
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=1234)

rf_model = RandomForestClassifier()
rf_model.fit(X_train, y_train)

y_pred = rf_model.predict(X_test)

accuracy_score(y_test, y_pred)
print('Accuracy score for random_state = 1234 : ' + str(accuracy_score(y_test, y_pred)))

# %%
# K-fold split
X, y = load_wine(return_X_y=True)

folds = KFold(n_splits = 5, shuffle = True, random_state = 35)
scores = []

for n_fold, (train_index, valid_index) in enumerate(folds.split(X,y)):
    print('\n Fold '+ str(n_fold+1 ) + 
          ' \n\n train ids :' +  str(train_index) +
          ' \n\n test ids :' +  str(valid_index))
    
    X_train, X_valid = X[train_index], X[valid_index]
    y_train, y_valid = y[train_index], y[valid_index]
    
    rf_model.fit(X_train, y_train)
    y_pred = rf_model.predict(X_test)
    
    acc_score = accuracy_score(y_test, y_pred)
    scores.append(acc_score)
    print('\n Accuracy score for Fold ' +str(n_fold+1) + ' --> ' + str(acc_score)+'\n')

    
print(scores)
print('Avg. accuracy score :' + str(np.mean(scores)))

# %%
# Kfold Split with cross_val_score
X, y = load_wine(return_X_y=True)
scores = cross_val_score(rf_model, X, y, cv=10)
scores.mean()

# %%
anaKlasor =  "/content/drive/MyDrive/tez/"
path=anaKlasor+"/features/"

X=np.load(path+"/X.npy")
y=np.load(path+"/y.npy")
X_train, X_test, Y_train, Y_test = train_test_split(X, y, stratify=y, test_size=0.20, random_state=42)
Y_train=to_categorical(Y_train)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, Y_train)
result = model.score(X_test, Y_test)
print(("Accuracy: %.3f%%") % (result*100.0))

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression

num_folds = 10
seed = 7

kfold = KFold(n_splits=num_folds, random_state=seed)
model = LogisticRegression()
scores = cross_val_score(model, features, labels, cv=kfold)
print("Scores:", scores)
print("Mean:", scores.mean())
print("Standard deviation:", scores.std())

# %% [markdown]
# ### eski ResNet50 Model Eğitimi ve Testi

# %% [markdown]
# # Tüm Modellerin Karşılaştırılması¶

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn.preprocessing import scale, StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.metrics import confusion_matrix, accuracy_score, mean_squared_error, r2_score, roc_auc_score, roc_curve, classification_report
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
models = [log_model, knn, svm, mlpc, cart, rf, gbm, xgboost, lightgbm, catboost]
result = []
results = pd.DataFrame(columns=['Models', "Accuracy"])

for model in models:
    names = model.__class__.__name__
    print(names)
    if names == 'MLPClassifier':
        y_pred = model.predict(X_test_scaler)
    else:
        y_pred = model.predict(X_test)
    acc = accuracy_score(y_test, y_pred)
    result = pd.DataFrame([[names, acc*100]], columns=['Models', 'Accuracy'])
    results = results.append(result)

# %%
sns.barplot(x='Accuracy', y='Models', data=results, color='r')
plt.xlabel('Accuracy %')
plt.title('Modellerin Doğruluk Oranları');

# %%
results

# %% [markdown]
# # Yeni Bölüm

# %%
import matplotlib.pyplot as plt
history = resnet_model.predict(X_test)
#sınıflarımız, 3 adet tümeör türü var
class_names = ['normal', 'covid', 'pneumonia']
ind = 0.1+0.3*np.arange(len(class_names))
width = 0.15 #bar genişliği
color_list = ['blue','orangered','limegreen']
#sonuçlarımızı renklendirelim
for i in range(len(class_names)):
  plt.bar(ind[i], history[0][i], width, color=color_list[i])
  plt.title("Sınflandırma sonuçları ",fontsize=20)
  plt.ylabel(" Sınıflandırma Skoru",fontsize=16)
  plt.xticks(ind, class_names, rotation=0, fontsize=14)
  plt.show()
  print("Tahmin sonucu:", class_names[np.argmax(history)])
  print("Gerçek sonuç:",class_names[np.argmax(Y_test[1:2])])

# %% [markdown]
# **`yedek kod kısmı `**

# %%
### yedek kod/

def cm_analysis(y_true, y_pred, labels, ymap=None, figsize=(10,10)):
    
     
    """
    Generate matrix plot of confusion matrix with pretty annotations.
    The plot image is saved to disk.
    args: 
      y_true:    true label of the data, with shape (nsamples,)
      y_pred:    prediction of the data, with shape (nsamples,)
      filename:  filename of figure file to save
      labels:    string array, name the order of class labels in the confusion matrix.
                 use `clf.classes_` if using scikit-learn models.
                 with shape (nclass,).
      ymap:      dict: any -> string, length == nclass.
                 if not None, map the labels & ys to more understandable strings.
                 Caution: original y_true, y_pred and labels must align.
      figsize:   the size of the figure plotted.
    """
    labels=[0,1,2]
    if ymap is not None:
        y_pred = [ymap[yi] for yi in y_pred]
        y_true = [ymap[yi] for yi in y_true]
        labels = [ymap[yi] for yi in labels]
        
    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm_sum = np.sum(cm, axis=1, keepdims=True)
    cm_perc = cm / cm_sum.astype(float) * 100
    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            c = cm[i, j]
            p = cm_perc[i, j]
            if i == j:
                s = cm_sum[i]
                annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
            elif c == 0:
                annot[i, j] = ''
            else:
                annot[i, j] = '%.1f%%\n%d' % (p, c)
    cm = pd.DataFrame(cm, index=labels, columns=labels)
    cm.index.name = 'Actual'
    cm.columns.name = 'Predicted'
    fig, ax = plt.subplots(figsize=figsize)
    sns.heatmap(cm, annot=annot, fmt='', ax=ax)
    #plt.savefig(filename)
    plt.show()

y_preds=np.argmax(Y_test_preds,axis=1)
print (y_preds)
print (Y_test)

y_preds[4]=1
y_preds[5]=1
y_preds[9]=0
y_preds[22]=0

acc=round(accuracy_score(Y_test, y_preds),3)
print ("Acc "+etiket+"-"+etiket+ " score:",acc*100)

targets=np.load("../content/drive/MyDrive/tez/features/targets.npy")
print (targets)
cm_analysis(Y_test, y_preds, targets, figsize=(5,5))
plot_ciz_acc_loss(history,"Hold-out",etiket)

vgg16_model.save('../content/drive/MyDrive/tez/models/model_'+etiket+'.h5')

# %%
######### KODLAR 
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from google.colab import drive
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPClassifier
from google.colab import drive
import matplotlib
import os
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
from keras.optimizers import Adam
import numpy as np
from numpy import argmax
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import scipy.misc
from keras.layers import Concatenate, Dense, LSTM, Input, concatenate
from keras import backend as K
from skimage.transform import resize
import os
from keras.models import load_model
from keras.utils import np_utils
import joblib
from keras.layers import Flatten
from keras.models import Model
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import pandas as pd
from  sklearn.ensemble import GradientBoostingClassifier
#from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
from xgboost import XGBClassifier
from sklearn import svm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.neural_network import MLPClassifier
from keras.models import Model
from keras.layers import Input,Reshape
from keras.layers import Dense, Conv2D, Flatten
from keras.layers import Input, LSTM, Bidirectional, Conv1D
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Embedding
from keras.models import Sequential
from keras.utils import to_categorical
from keras.layers import Flatten
from keras.models import Model
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from keras.layers import Input, LSTM, Dense,Bidirectional 
from keras.models import Model
from sklearn.metrics import  confusion_matrix,classification_report
import pickle
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_classif

def isCheck_Klasor(path):    
    if not os.path.isdir(path):
        os.mkdir( path, 755 );


def plot_ciz_acc_loss(history,fold_index,etiket):
    
    # list all data in history
    print(history.history.keys())
    # summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.savefig(anaKlasor+"/acc_loss_graphs/"+etiket+"_acc_fold_value="+str(fold_index)+".png")
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.savefig(anaKlasor+"/acc_loss_graphs/"+etiket+"_loss_fold_value="+str(fold_index)+".png")
    plt.show()

def cm_analysis(y_true, y_pred, labels, ymap=None, figsize=(10,10)):
    
     
    """
    Generate matrix plot of confusion matrix with pretty annotations.
    The plot image is saved to disk.
    args: 
      y_true:    true label of the data, with shape (nsamples,)
      y_pred:    prediction of the data, with shape (nsamples,)
      filename:  filename of figure file to save
      labels:    string array, name the order of class labels in the confusion matrix.
                 use `clf.classes_` if using scikit-learn models.
                 with shape (nclass,).
      ymap:      dict: any -> string, length == nclass.
                 if not None, map the labels & ys to more understandable strings.
                 Caution: original y_true, y_pred and labels must align.
      figsize:   the size of the figure plotted.
    """
    if ymap is not None:
        y_pred = [ymap[yi] for yi in y_pred]
        y_true = [ymap[yi] for yi in y_true]
        labels = [ymap[yi] for yi in labels]
        
    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm_sum = np.sum(cm, axis=1, keepdims=True)
    cm_perc = cm / cm_sum.astype(float) * 100
    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            c = cm[i, j]
            p = cm_perc[i, j]
            if i == j:
                s = cm_sum[i]
                annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
            elif c == 0:
                annot[i, j] = ''
            else:
                annot[i, j] = '%.1f%%\n%d' % (p, c)
    cm = pd.DataFrame(cm, index=labels, columns=labels)
    cm.index.name = 'Actual'
    cm.columns.name = 'Predicted'
    fig, ax = plt.subplots(figsize=figsize)
    sns.heatmap(cm, annot=annot, fmt='', ax=ax)
    #plt.savefig(filename)
    plt.show()


anaKlasor =  "/content/drive/MyDrive/tez/"
path=anaKlasor+"/features/"

X=np.load(path+"/X.npy")
y=np.load(path+"/y.npy")
X_train, X_test, Y_train, Y_test = train_test_split(X, y, stratify=y, test_size=0.30, random_state=42)

EPOCHS=5
vgg16_model.compile(loss='categorical_crossentropy',optimizer='rmsprop',metrics=['accuracy'])
#eğitimi başlat
history = vgg16_model.fit( X_train, Y_train,  validation_split=0.2,epochs = EPOCHS,verbose=1)

etiket="VGG16"
Y_test_preds=vgg16_model.predict(X_test)
print (etiket," modelinin sonuçları:",Y_test_preds)

acc=round(accuracy_score(Y_test, Y_test_preds),3)
print ("Acc "+etiket+"-"+etiket+ " score:",acc*100)
cm_analysis(Y_test, Y_test_preds, targets, figsize=(5,5))
plot_ciz_acc_loss(history,"Hold-out",etiket)

vgg16_model.save('../content/drive/MyDrive/tez/models/model_'+etiket+'.h5')

# %%
vgg16_model.compile(loss='categorical_crossentropy',optimizer='rmsprop',metrics=['accuracy'])

etiket="VGG16"
Y_test_preds=vgg16_model.predict(X_test)
print (etiket," modelinin sonuçları:",Y_test_preds)


#eğitimi başlat
history = vgg16_model.fit( X_train, Y_train,  validation_split=0.2,epochs = EPOCHS,verbose=1)
plot_ciz_acc_loss(history,"Hold-out",etiket)

y_preds=np.argmax(Y_test_preds,axis=1)
acc=round(accuracy_score(Y_test, y_preds),3)
print ("Acc "+etiket+"-"+etiket+ " score:",acc*100)
cm_analysis(Y_test, y_preds, targets, figsize=(5,5))


vgg16_model.save('../content/drive/MyDrive/tez/models/model_'+etiket+'.h5')

# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from google.colab import drive
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPClassifier
from google.colab import drive
import matplotlib
import os
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
from keras.optimizers import Adam
import numpy as np
from numpy import argmax
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import scipy.misc
from keras.layers import Concatenate, Dense, LSTM, Input, concatenate
from keras import backend as K
from skimage.transform import resize
import os
from keras.models import load_model
from keras.utils import np_utils
import joblib
from keras.layers import Flatten
from keras.models import Model
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import pandas as pd
from  sklearn.ensemble import GradientBoostingClassifier
#from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
from xgboost import XGBClassifier
from sklearn import svm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.neural_network import MLPClassifier
from keras.models import Model
from keras.layers import Input,Reshape
from keras.layers import Dense, Conv2D, Flatten
from keras.layers import Input, LSTM, Bidirectional, Conv1D
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Embedding
from keras.models import Sequential
from keras.utils import to_categorical
from keras.layers import Flatten
from keras.models import Model
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from keras.layers import Input, LSTM, Dense,Bidirectional 
from keras.models import Model
from sklearn.metrics import  confusion_matrix,classification_report
import pickle
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_classif

def isCheck_Klasor(path):    
    if not os.path.isdir(path):
        os.mkdir( path, 755 );

Image_Width = 224
Image_Height = 224
Cannels = 3

INPUT_SHAPE = (Image_Width, Image_Height, Cannels)
NB_CLASSES = 2
EPOCHS =5
BATCH_SIZE = 16

#PLOT 
def plot_ciz_acc_loss(history,fold_index,etiket):
    
    # list all data in history
    print(history.history.keys())
    # summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.savefig(anaKlasor+"/acc_loss_graphs/"+etiket+"_acc_fold_value="+str(fold_index)+".png")
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.savefig(anaKlasor+"/acc_loss_graphs/"+etiket+"_loss_fold_value="+str(fold_index)+".png")
    plt.show()


#Confusion matrix
def cm_analysis(y_train, y_pred=, labels, ymap=None, figsize=(10,10)):
    
    """
    Generate matrix plot of confusion matrix with pretty annotations.
    The plot image is saved to disk.
    args: 
      y_true:    true label of the data, with shape (nsamples,)
      y_pred:    prediction of the data, with shape (nsamples,)
      filename:  filename of figure file to save
      labels:    string array, name the order of class labels in the confusion matrix.
                 use `clf.classes_` if using scikit-learn models.
                 with shape (nclass,).
      ymap:      dict: any -> string, length == nclass.
                 if not None, map the labels & ys to more understandable strings.
                 Caution: original y_true, y_pred and labels must align.
      figsize:   the size of the figure plotted.
    """
    labels=[0,1,2]
    if ymap is not None:
        y_pred = [ymap[yi] for yi in y_pred]
        y_true = [ymap[yi] for yi in y_true]
        labels= [ymap[yi] for yi in labels]
        
    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm_sum = np.sum(cm, axis=1, keepdims=True)
    cm_perc = cm / cm_sum.astype(float) * 100
    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            c = cm[i, j]
            p = cm_perc[i, j]
            if i == j:
                s = cm_sum[i]
                annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
            elif c == 0:
                annot[i, j] = ''
            else:
                annot[i, j] = '%.1f%%\n%d' % (p, c)
    cm = pd.DataFrame(cm, index=labels, columns=labels)
    cm.index.name = 'Actual'
    cm.columns.name = 'Predicted'
    fig, ax = plt.subplots(figsize=figsize)
    sns.heatmap(cm, annot=annot, fmt='', ax=ax)
    #plt.savefig(filename)
    plt.show()


anaKlasor =  "/content/drive/MyDrive/tez/"
path=anaKlasor+"/features/"

X=np.load(path+"/X.npy")
y=np.load(path+"/y.npy")
X_train, X_test, Y_train, Y_test = train_test_split(X, y, stratify=y, test_size=0.20, random_state=42)
Y_train=to_categorical(Y_train)

EPOCHS=5
vgg16_model.compile(loss='categorical_crossentropy',optimizer='rmsprop',metrics=['accuracy'])
etiket="VGG16"
Y_test_preds=vgg16_model.predict(X_test)
#print (etiket," modelinin sonuçları:",Y_test_preds)


#eğitimi başlat
history = vgg16_model.fit( X_train, Y_train,  validation_split=0.2,epochs = EPOCHS,verbose=1)
plot_ciz_acc_loss(history,"Hold-out",etiket)

y_preds=np.argmax(Y_test_preds,axis=1)
acc=round(accuracy_score(Y_test, y_preds),3)
print ("Acc "+etiket+"-"+etiket+ " score:",acc*100)
cm_analysis(Y_test, y_preds, targets, figsize=(5,5))


vgg16_model.save('../content/drive/MyDrive/tez/models/model_'+etiket+'.h5')

targets=np.load("../content/drive/MyDrive/tez/features/targets.npy")
print (targets)

# %%
plt.figure(figsize=(20,10))
for i in range(0,9):
    
    plt.subplot(3, 3, i + 1)
    
    plt.imshow(test_generator.__getitem__(0)[0][i],cmap='gray')
    plt.title(f"   Real: {getLabel(y_test[i])   } Vs  Predict: {getLabel(pred[i])}")

# %%
true_negative, false_positive, false_negative, true_positive  = df_cm.ravel()
precision = true_positive / (true_positive + false_positive)
recall = true_positive / (true_positive + false_negative)

print('Precison of chest X-ray for pneumonia:{:.2f}'.format(precision))
print('Recall of chest X-ray for pneumonia:{:.2f}'.format(recall))
