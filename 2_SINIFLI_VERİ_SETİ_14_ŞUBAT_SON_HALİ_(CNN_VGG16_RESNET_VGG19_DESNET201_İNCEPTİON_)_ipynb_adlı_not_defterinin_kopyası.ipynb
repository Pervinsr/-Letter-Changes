# %% [markdown]
# <a href="https://colab.research.google.com/github/Pervinsr/-Letter-Changes/blob/main/2_SINIFLI_VER%C4%B0_SET%C4%B0_14_%C5%9EUBAT_SON_HAL%C4%B0_(CNN_VGG16_RESNET_VGG19_DESNET201_%C4%B0NCEPT%C4%B0ON_)_ipynb_adl%C4%B1_not_defterinin_kopyas%C4%B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# veri seti : dataset_deneme r

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Kütüphaneler

# %%
import tensorflow as tf
import gc
from tensorflow import keras
import keras
from keras import backend as k
tf.keras.optimizers.Adam()
tf.keras.optimizers.SGD()
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import random
import shutil
import cv2
import os
from datetime import datetime
# %load_ext tensorboard
from google.colab import drive
import matplotlib
from sklearn.metrics import roc_auc_score, roc_curve


#%% roc ROC auc AUC Roc
import numpy as np
import matplotlib.pyplot as plt
from itertools import cycle

from sklearn import svm, datasets
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
from scipy import interp
from sklearn.metrics import roc_auc_score  


import tensorflow as tf
inputs = tf.keras.Input(shape=(3,))
x = tf.keras.layers.Dense(4, activation=tf.nn.relu)(inputs)
outputs = tf.keras.layers.Dense(5, activation=tf.nn.softmax)(x)
model = tf.keras.Model(inputs=inputs, outputs=outputs)


from tensorflow.python.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint,TensorBoard,TerminateOnNaN, LearningRateScheduler
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, TerminateOnNaN
from tensorflow.keras import regularizers
from tensorflow.keras import backend as K
from sklearn.metrics import precision_recall_curve,  plot_precision_recall_curve,  classification_report,  confusion_matrix, roc_auc_score, roc_curve, auc
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split, StratifiedKFold, RepeatedStratifiedKFold
from imutils import paths


from google.colab import drive
import matplotlib
from sklearn.metrics import roc_auc_score, roc_curve
import os
import cv2
import skimage
from tensorflow.python.keras.callbacks import ModelCheckpoint, EarlyStopping
import os 
import zipfile 
import tensorflow as tf 
from tensorflow.keras.preprocessing.image import ImageDataGenerator 
from tensorflow.keras import layers 
from tensorflow.keras import Model 
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet import ResNet152
from tensorflow.keras.applications import EfficientNetB0,EfficientNetB1,EfficientNetB2,EfficientNetB3,EfficientNetB4,EfficientNetB5,EfficientNetB6,EfficientNetB7
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.applications import Xception
from tensorflow.keras.applications import NASNetMobile
from tensorflow.keras.applications import MobileNetV2
import random
from skimage import filters
from tensorflow.keras.utils import to_categorical
import os
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns

def isCheck_Klasor(path):    
    if not os.path.isdir(path):
        os.mkdir( path, 755 );


import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPooling2D,GlobalAveragePooling2D
from keras.layers import Activation, Dropout, BatchNormalization, Flatten, Dense, AvgPool2D,MaxPool2D
from keras.models import Sequential, Model
from keras.applications.vgg16 import VGG16, preprocess_input
import tensorflow as tf

import os
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import glob
import matplotlib.image as mpimg
# %matplotlib inline
import plotly.offline as py
import plotly.express as px
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %% [markdown]
# # Veri Seti Ön işlem

# %%
from google.colab import drive
import matplotlib
from sklearn.metrics import roc_auc_score, roc_curve
import os
import cv2

#%% roc ROC auc AUC Roc
import numpy as np
import matplotlib.pyplot as plt
from itertools import cycle

from sklearn import svm, datasets
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
from scipy import interp
from sklearn.metrics import roc_auc_score   

from PIL import Image
import requests
import numpy as np

def isCheck_Klasor(path):    
    if not os.path.isdir(path):
        os.mkdir( path, 755 );


#Drive bağlama
drive.mount('/content/drive')
anaKlasor =  "/content/drive/MyDrive/tez/"

#Verisetim
anaKlasor2=anaKlasor+'dataset_deneme/'
altKlasorler =  os.listdir(anaKlasor2)


targets=[]
for index, altKlasor in enumerate(altKlasorler):
  if altKlasor not in targets:
    targets.append(altKlasor)

print (targets)
np.save(anaKlasor+'/features/targets.npy',targets)   # x ve y kaydettim 



X,y=[],[]

for index, altKlasor in enumerate(altKlasorler):

    cikis=targets.index(altKlasor)
    
    path1=anaKlasor2+'/'+altKlasor+'/'

    imagelist=os.listdir(path1)
    
    for i,file_name in enumerate(imagelist):

       #print (path1+'/'+file_name)        
        
        img = cv2.imread(os.path.join(anaKlasor2,altKlasor,file_name))
        img = cv2.resize(img,(224,224))
        img=np.array(img)
        X.append(img)
        y.append(cikis)
        #print (i,"/",len(imagelist),"->",altKlasor,altKlasorler,"->",img.shape)


X=np.array(X)

path=anaKlasor+"/features/"
isCheck_Klasor(path)

np.save(path+"/X.npy",X)
np.save(path+"/y.npy",y)
# Out:
# Mounted at /content/drive
# ['COVID', 'non-COVID']

# %%
# !pip install imutils
# !pip install image-classifiers==1.0.0b1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imutils in /usr/local/lib/python3.8/dist-packages (0.5.4)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting image-classifiers==1.0.0b1
#   Downloading image_classifiers-1.0.0b1.tar.gz (18 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: image-classifiers
#   Building wheel for image-classifiers (setup.py) ... done
#   Created wheel for image-classifiers: filename=image_classifiers-1.0.0b1-py3-none-any.whl size=19968 sha256=e8e5d36a4b12fbfceca7b646427ee0161c4a1e4770dbd14a6f4a9f696238abb4
#   Stored in directory: /root/.cache/pip/wheels/59/ee/99/bdd974449ed4653c3c2e37d600817c9da816057dfa43c67878
# Successfully built image-classifiers
# Installing collected packages: image-classifiers
# Successfully installed image-classifiers-1.0.0b1

# %%
# dataset_deneme klasörünü gerçek veri setindeki görüntülerin hepsi yer almıyor. Az bir kısmını aktardım.
anaKlasor =  "/content/drive/MyDrive/tez/dataset_deneme"
print(anaKlasor)

print(os.listdir(anaKlasor))
# Out:
# /content/drive/MyDrive/tez/dataset_deneme
# ['COVID', 'non-COVID']

# %%
df = pd.DataFrame(columns =['class', 'directory'])  # sınıf ve dizin kısmı
df
# Out:
# Empty DataFrame
# Columns: [class, directory]
# Index: []

# %%
import os
for dirpath, dirnames, filenames in os.walk('../content/drive/MyDrive/tez/dataset_deneme/COVID'):
    for filename in filenames:
        df.loc[-1] = ["COVID", ('COVID/' + filename)] 
        df.index = df.index + 1 
        df = df.sort_index() 
for dirpath, dirnames, filenames in os.walk('../content/drive/MyDrive/tez/dataset_deneme/non-COVID'):
    for filename in filenames:
        df.loc[-1] = ["non-COVID", ('non-COVID/' + filename)] 
        df.index = df.index + 1 
        df = df.sort_index()

# %%
df.head()
# Out:
#        class                       directory
# 0  non-COVID  non-COVID/Non-Covid (1143).png
# 1  non-COVID  non-COVID/Non-Covid (1203).png
# 2  non-COVID  non-COVID/Non-Covid (1138).png
# 3  non-COVID  non-COVID/Non-Covid (1205).png
# 4  non-COVID   non-COVID/Non-Covid (104).png

# %%
#sınıf ve dizinlerini listeleme
df
# Out:
#           class                       directory
# 0     non-COVID  non-COVID/Non-Covid (1143).png
# 1     non-COVID  non-COVID/Non-Covid (1203).png
# 2     non-COVID  non-COVID/Non-Covid (1138).png
# 3     non-COVID  non-COVID/Non-Covid (1205).png
# 4     non-COVID   non-COVID/Non-Covid (104).png
# ...         ...                             ...
# 2476      COVID           COVID/Covid (151).png
# 2477      COVID           COVID/Covid (221).png
# 2478      COVID           COVID/Covid (266).png
# 2479      COVID           COVID/Covid (156).png
# 2480      COVID          COVID/Covid (1233).png
#
# [2481 rows x 2 columns]

# %%
y = df['class']
X = df['directory']

#kaç tane oldukları
y.value_counts()
# Out:
# COVID        1252
# non-COVID    1229
# Name: class, dtype: int64

# %%
X.value_counts()
# Out:
# non-COVID/Non-Covid (1143).png    1
# COVID/Covid (825).png             1
# COVID/Covid (756).png             1
# COVID/Covid (782).png             1
# COVID/Covid (798).png             1
#                                  ..
# non-COVID/Non-Covid (370).png     1
# non-COVID/Non-Covid (373).png     1
# non-COVID/Non-Covid (380).png     1
# non-COVID/Non-Covid (420).png     1
# COVID/Covid (1233).png            1
# Name: directory, Length: 2481, dtype: int64

# %%
#box plot and counting the lables
df=pd.DataFrame(targets,columns=['labels'])
sns.countplot(df['labels'])
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
#COVID Image
COVID_images = []
for img_path in glob.glob(anaKlasor + '/COVID/*'):
    COVID_images.append(mpimg.imread(img_path))

fig = plt.figure()
fig.suptitle('COVID Image')
plt.imshow(COVID_images[0], cmap='gray')
plt.savefig("/content/drive/MyDrive/tez/saveimage/COVIDimage.png")    #klasöre kaydettim

#non-COVID Image
nonCOVID_images = []
for img_path in glob.glob(anaKlasor + '/non-COVID/*'):
   nonCOVID_images.append(mpimg.imread(img_path))
fig = plt.figure()
fig.suptitle('nonCOVID Image')
plt.imshow(nonCOVID_images[0], cmap='gray')
plt.savefig("/content/drive/MyDrive/tez/saveimage/non-COVID_image.png")

# %% [markdown]
# **VGG16**

# %%
Image_Width = 224
Image_Height = 224
Cannels = 3

INPUT_SHAPE = (Image_Width, Image_Height, Cannels)
NB_CLASSES = 2
EPOCHS = 100
BATCH_SIZE = 5

# %%
from sklearn.model_selection import train_test_split
import numpy as np
import seaborn as sns
X_train, X_test, Y_train, Y_test = train_test_split(X, y, stratify=y, test_size=0.20, random_state=7)

# %%
print('Öğrenme verisinin boyutları (Gözlem, öznitelik) = ' + str(np.shape(X_train)))
print('Sınama verisinin boyutları (Gözlem, öznitelik) = ' + str(np.shape(X_test)))
# Out:
# Öğrenme verisinin boyutları (Gözlem, öznitelik) = (1984,)
# Sınama verisinin boyutları (Gözlem, öznitelik) = (497,)

# %%
#sns.scatterplot(x = X, y = y)

# %%
Y_train.value_counts()
# Out:
# COVID        1001
# non-COVID     983
# Name: class, dtype: int64

# %%
Y_test.value_counts()
# Out:
# COVID        251
# non-COVID    246
# Name: class, dtype: int64

# %%
#encode labels as integer
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder() #labelencoder used to normalize labels
labels=le.fit_transform(targets) #also be used to transform non-numerical labels to numerical labels
labels=to_categorical(labels)

print(le.classes_)
print(labels[0])
# Out:
# ['COVID' 'non-COVID']
# [1. 0.]

# %%
X_train=np.array(X_train)
X_test=np.array(X_test)
Y_train=np.array(Y_train)
Y_test=np.array(Y_test)

print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (1984,)
# (497,)
# (1984,)
# (497,)

# %%
#    vgg16_model
import tensorflow as tf
from keras.models import Sequential
from keras.layers import GlobalAveragePooling2D
from keras.applications import VGG16
vgg16_base_model = VGG16(input_shape=INPUT_SHAPE,include_top=False,weights='imagenet')

vgg16_base_model.summary()
vgg16_model = tf.keras.Sequential([
        vgg16_base_model,
        GlobalAveragePooling2D(),
        Dense(512, activation="relu"),
        BatchNormalization(),
        Dropout(0.6),
        Dense(128, activation="relu"),
        BatchNormalization(),
        Dropout(0.4),
        Dense(64,activation="relu"),
        BatchNormalization(),
        Dropout(0.3),
        Dense(2,activation="softmax")
    ])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Modelimizi derlemek
vgg16_model.compile(loss='binary_crossentropy',optimizer='rmsprop',metrics=['accuracy'])


#Ağımızın özeti gösteriliyor
vgg16_model.summary()

from tensorflow.keras.utils import plot_model

#plot_model(model, to_file='model1.png')
plot_model(vgg16_model, to_file="/content/drive/MyDrive/tez/saveimage/modelvgg16.png")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense_4 (Dense)             (None, 512)               262656
#
#  batch_normalization (BatchN  (None, 512)              2048
#  ormalization)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_5 (Dense)             (None, 128)               65664
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_6 (Dense)             (None, 64)                8256
#
#  batch_normalization_2 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_7 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 15,054,210
# Trainable params: 15,052,802
# Non-trainable params: 1,408
# _________________________________________________________________

# %% [markdown]
# ### VGG16 Model Eğitimi ve Testi

# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from google.colab import drive
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPClassifier
from google.colab import drive
import matplotlib
import os
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
from keras.optimizers import Adam
import numpy as np
from numpy import argmax
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import scipy.misc
from keras.layers import Concatenate, Dense, LSTM, Input, concatenate
from keras import backend as K
from skimage.transform import resize
import os
from keras.models import load_model
from keras.utils import np_utils
import joblib
from keras.layers import Flatten
from keras.models import Model
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import pandas as pd
from  sklearn.ensemble import GradientBoostingClassifier
#from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
from xgboost import XGBClassifier
from sklearn import svm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.neural_network import MLPClassifier
from keras.models import Model
from keras.layers import Input,Reshape
from keras.layers import Dense, Conv2D, Flatten
from keras.layers import Input, LSTM, Bidirectional, Conv1D
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Embedding
from keras.models import Sequential
from keras.utils import to_categorical
from keras.layers import Flatten
from keras.models import Model
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from keras.layers import Input, LSTM, Dense,Bidirectional 
from keras.models import Model
from sklearn.metrics import  confusion_matrix,classification_report
import pickle
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_classif

def isCheck_Klasor(path):    
    if not os.path.isdir(path):
        os.mkdir( path, 755 );

Image_Width = 224
Image_Height = 224
Cannels = 3

INPUT_SHAPE = (Image_Width, Image_Height, Cannels)
NB_CLASSES = 2
EPOCHS =100
BATCH_SIZE =16


#PLOT 
def plot_ciz_acc_loss(history,fold_index,etiket):
    
    # list all data in history
    print(history.history.keys())
    # summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.savefig(anaKlasor+"/acc_loss_graphs/"+etiket+"_acc_fold_value="+str(fold_index)+".png")
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.savefig(anaKlasor+"/acc_loss_graphs/"+etiket+"_loss_fold_value="+str(fold_index)+".png")
    plt.show()


#Confusion matrix
def cm_analysis(y_train, y_pred, labels, ymap=None, figsize=(10,10)):
    
    """
    Generate matrix plot of confusion matrix with pretty annotations.
    The plot image is saved to disk.
    args: 
      y_true:    true label of the data, with shape (nsamples,)
      y_pred:    prediction of the data, with shape (nsamples,)
      filename:  filename of figure file to save
      labels:    string array, name the order of class labels in the confusion matrix.
                 use `clf.classes_` if using scikit-learn models.
                 with shape (nclass,).
      ymap:      dict: any -> string, length == nclass.
                 if not None, map the labels & ys to more understandable strings.
                 Caution: original y_true, y_pred and labels must align.
      figsize:   the size of the figure plotted.
    """
    labels=[0,1]
    if ymap is not None:
        y_pred = [ymap[yi] for yi in y_pred]
        y_train = [ymap[yi] for yi in y_train]
        labels= [ymap[yi] for yi in labels]
        
    cm = confusion_matrix(y_train, y_preds, labels=labels)
    cm_sum = np.sum(cm, axis=1, keepdims=True)
    cm_perc = cm / cm_sum.astype(float) * 100
    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            c = cm[i, j]
            p = cm_perc[i, j]
            if i == j:
                s = cm_sum[i]
                annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
            elif c == 0:
                annot[i, j] = ''
            else:
                annot[i, j] = '%.1f%%\n%d' % (p, c)
    cm = pd.DataFrame(cm, index=labels, columns=labels)
    cm.index.name = 'Actual'
    cm.columns.name = 'Predicted'
    fig, ax = plt.subplots(figsize=figsize)
    sns.heatmap(cm, annot=annot, fmt='', ax=ax)
    #plt.savefig(filename)
    plt.show()




anaKlasor =  "/content/drive/MyDrive/tez/"
path=anaKlasor+"/features/"

X=np.load(path+"/X.npy")
y=np.load(path+"/y.npy")
X_train, X_test, Y_train, Y_test = train_test_split(X, y, stratify=y, test_size=0.20, random_state=42)
Y_train=to_categorical(Y_train)



vgg16_model.compile(loss='binary_crossentropy',optimizer='rmsprop',metrics=['accuracy'])
etiket="VGG16"
Y_test_preds=vgg16_model.predict(X_test)   #tahmin
print (etiket," modelinin sonuçları:",Y_test_preds)


#eğitimi başlat
history = vgg16_model.fit( X_train, Y_train,  validation_split=0.2,epochs = EPOCHS,verbose=1)

# GRAFİK ÇİZİLSİN
plot_ciz_acc_loss(history,"Hold-out",etiket)


#KARIŞIKLIK MATRİSİ
y_preds=np.argmax(Y_test_preds,axis=1)
acc=round(accuracy_score(Y_test, y_preds),3)
print ("Acc "+etiket+"-"+etiket+ " score:",acc*100)
cm_analysis(Y_test, y_preds, targets, figsize=(5,5))


vgg16_model.save('../content/drive/MyDrive/tez/models/model_'+etiket+'.h5')

targets=np.load("../content/drive/MyDrive/tez/features/targets.npy")
print (targets)
# Out:
# 16/16 [==============================] - 2s 104ms/step
# Epoch 1/100
# 50/50 [==============================] - 34s 487ms/step - loss: 0.8057 - accuracy: 0.5942 - val_loss: 1.4098 - val_accuracy: 0.5189
# Epoch 2/100
# 50/50 [==============================] - 20s 407ms/step - loss: 0.7172 - accuracy: 0.6364 - val_loss: 1.9225 - val_accuracy: 0.5013
# Epoch 3/100
# 50/50 [==============================] - 21s 413ms/step - loss: 0.5474 - accuracy: 0.7662 - val_loss: 3.2626 - val_accuracy: 0.4811
# Epoch 4/100
# 50/50 [==============================] - 22s 439ms/step - loss: 0.4594 - accuracy: 0.8147 - val_loss: 9.1490 - val_accuracy: 0.4811
# Epoch 5/100
# 50/50 [==============================] - 22s 444ms/step - loss: 0.3878 - accuracy: 0.8570 - val_loss: 2.3065 - val_accuracy: 0.4887
# Epoch 6/100
# 50/50 [==============================] - 22s 447ms/step - loss: 0.3700 - accuracy: 0.8658 - val_loss: 6.4347 - val_accuracy: 0.4811
# Epoch 7/100
# 50/50 [==============================] - 21s 423ms/step - loss: 0.3516 - accuracy: 0.8633 - val_loss: 0.5492 - val_accuracy: 0.7834
# Epoch 8/100
# 50/50 [==============================] - 21s 422ms/step - loss: 0.3168 - accuracy: 0.8733 - val_loss: 3.8451 - val_accuracy: 0.4811
# Epoch 9/100
# 50/50 [==============================] - 21s 422ms/step - loss: 0.3255 - accuracy: 0.8759 - val_loss: 222.2658 - val_accuracy: 0.5718
# Epoch 10/100
# 50/50 [==============================] - 21s 424ms/step - loss: 0.3065 - accuracy: 0.8841 - val_loss: 8.8452 - val_accuracy: 0.5189
# Epoch 11/100
# 50/50 [==============================] - 22s 446ms/step - loss: 0
100
# 50/50 [==============================] - 21s 424ms/step - loss: 0.0732 - accuracy: 0.9691 - val_loss: 0.4156 - val_accuracy: 0.8489
# Epoch 41/100
# 50/50 [==============================] - 22s 446ms/step - loss: 0.0993 - accuracy: 0.9672 - val_loss: 0.3006 - val_accuracy: 0.8841
# Epoch 42/100
# 50/50 [==============================] - 21s 423ms/step - loss: 0.1164 - accuracy: 0.9603 - val_loss: 1.9244 - val_accuracy: 0.5542
# Epoch 43/100
# 50/50 [==============================] - 21s 423ms/step - loss: 0.1324 - accuracy: 0.9496 - val_loss: 4.7002 - val_accuracy: 0.5189
# Epoch 44/100
# 50/50 [==============================] - 22s 445ms/step - loss: 0.0912 - accuracy: 0.9704 - val_loss: 1.2638 - val_accuracy: 0.6549
# Epoch 45/100
# 50/50 [==============================] - 22s 445ms/step - loss: 0.0905 - accuracy: 0.9685 - val_loss: 0.7885 - val_accuracy: 0.7960
# Epoch 46/100
# 50/50 [==============================] - 22s 446ms/step - loss: 0.0876 - accuracy: 0.9685 - val_loss: 0.7227 - val_accuracy: 0.7708
# Epoch 47/100
# 50/50 [==============================] - 22s 446ms/step - loss: 0.0987 - accuracy: 0.9672 - val_loss: 0.6282 - val_accuracy: 0.8111
# Epoch 48/100
# 50/50 [==============================] - 21s 423ms/step - loss: 0.0961 - accuracy: 0.9691 - val_loss: 0.5010 - val_accuracy: 0.8363
# Epoch 49/100
# 50/50 [==============================] - 21s 424ms/step - loss: 0.1035 - accuracy: 0.9622 - val_loss: 0.2040 - val_accuracy: 0.9370
# Epoch 50/100
# 50/50 [==============================] - 22s 446ms/step - loss: 0.0843 - accuracy: 0.9672 - val_loss: 0.3185 - val_accuracy: 0.8917
# Epoch 51/100
# 50/50 [==============================] - 21s 422ms/step - loss: 0.0685 - accuracy: 0.9786 - val_loss: 4.9273 - val_accuracy: 0.4861
# Epoch 52/100
# 50/50 [==============================] - 22s 447ms/step - loss: 0.0763 - accuracy: 0.9773 - val_loss: 0.7387 - val_accuracy: 0.8111
# Epoch 53/100
# 50/50 [==============================] - 22s 446ms/step - loss: 0.0737 - accuracy: 0.9748 - val_loss: 3.6949 - val_accuracy: 0.5189
# Epoch 54/100
# 50/50 [==============================] - 21s 423ms/step - loss: 0.0740 - accuracy: 0.9798 - val_loss: 5.2532 - val_accuracy: 0.5189
# Epoch 55/100
# 50/50 [==============================] - 22s 446ms/step - loss: 0.0805 - accuracy: 0.9679 - val_loss: 1.7969 - val_accuracy: 0.6071
# Epoch 56/100
# 50/50 [==============================] - 22s 446ms/step - loss: 0.0674 - accuracy: 0.9761 - val_loss: 1.2022 - val_accuracy: 0.7179
# Epoch 57/100
# 50/50 [==============================] - 21s 423ms/step - loss: 0.0622 - accuracy: 0.9811 - val_loss: 0.9385 - val_accuracy: 0.7481
# Epoch 58/100
# 50/50 [==============================] - 22s 446ms/step - loss: 0.0892 - accuracy: 0.9698 - val_loss: 1.4474 - val_accuracy: 0.6373
# Epoch 59/100
# 50/50 [==============================] - 22s 446ms/step - loss: 0.0424 - accuracy: 0.9868 - val_loss: 0.2430 - val_accuracy: 0.9345
# Epoch 60/100
# 50/50 [==============================] - 22s 446ms/step - loss: 0.0590 - accuracy: 0.9805 - val_loss: 0.7412 - val_accuracy: 0.7985
# Epoch 61/100
# 50/50 [==============================] - 22s 446ms/step - loss: 0.0668 - accuracy: 0.9817 - val_loss: 1.2721 - val_accuracy: 0.7154
# Epoch 62/100
# 50/50 [==============================] - 21s 425ms/step - loss: 0.0691 - accuracy: 0.9805 - val_loss: 1.2440 - val_accuracy: 0.6952
# Epoch 63/100
# 50/50 [==============================] - 21s 424ms/step - loss: 0.0538 - accuracy: 0.9805 - val_loss: 0.6521 - val_accuracy: 0.8212
# Epoch 64/100
# 50/50 [==============================] - 21s 424ms/step - loss: 0.0484 - accuracy: 0.9855 - val_loss: 0.4216 - val_accuracy: 0.8741
# Epoch 65/100
# 50/50 [==============================] - 22s 445ms/step - loss: 0.0732 - accuracy: 0.9748 - val_loss: 1.9067 - val_accuracy: 0.6297
# Epoch 66/100
# 50/50 [==============================] - 21s 422ms/step - loss: 0.0726 - accuracy: 0.9754 - val_loss: 0.2780 - val_accuracy: 0.9295
# Epoch 67/100
# 50/50 [==============================] - 21s 425ms/step - loss: 0.0410 - accuracy: 0.9849 - val_loss: 0.7817 - val_accuracy: 0.7960
# Epoch 68/100
# 50/50 [==============================] - 22s 446ms/step - loss: 0.0463 - accuracy: 0.9842 - val_loss: 0.7958 - val_accuracy: 0.8086
# Epoch 69/100
# 50/50 [==============================] - 21s 424ms/step - loss: 0.0352 - accuracy: 0.9874 - val_loss: 1.8119 - val_accuracy: 0.6322
# Epoch 70/100
# 50/50 [==============================] - 21s 424ms/step - loss: 0.0764 - accuracy: 0.9792 - val_loss: 1.2520 - val_accuracy: 0.6877
# Epoch 71/100
# 50/50 [==============================] - 22s 446ms/step - loss: 0.0510 - accuracy: 0.9861 - val_loss: 0.2375 - val_accuracy: 0.9471
# Epoch 72/100
# 50/50 [==============================] - 21s 424ms/step - loss: 0.0683 - accuracy: 0.9735 - val_loss: 7.3561 - val_accuracy: 0.5189
# Epoch 73/100
# 50/50 [==============================] - 21s 424ms/step - loss: 0.0167 - accuracy: 0.9962 - val_loss: 0.3921 - val_accuracy: 0.8992
# Epoch 74/100
# 50/50 [==============================] - 22s 447ms/step - loss: 0.0769 - accuracy: 0.9805 - val_loss: 0.6526 - val_accuracy: 0.8262
# Epoch 75/100
# 50/50 [==============================] - 22s 446ms/step - loss: 0.0847 - accuracy: 0.9786 - val_loss: 1.0549 - val_accuracy: 0.8715
# Epoch 76/100
# 50/50 [==============================] - 21s 424ms/step - loss: 0.0595 - accuracy: 0.9868 - val_loss: 3.8601 - val_accuracy: 0.5214
# Epoch 77/100
# 50/50 [==============================] - 21s 426ms/step - loss: 0.0661 - accuracy: 0.9792 - val_loss: 1.0413 - val_accuracy: 0.7632
# Epoch 78/100
# 50/50 [==============================] - 21s 425ms/step - loss: 0.0253 - accuracy: 0.9912 - val_loss: 0.2238 - val_accuracy: 0.9496
# Epoch 79/100
# 50/50 [==============================] - 22s 446ms/step - loss: 0.0714 - accuracy: 0.9754 - val_loss: 4.9743 - val_accuracy: 0.4987
# Epoch 80/100
# 50/50 [==============================] - 21s 424ms/step - loss: 0.0617 - accuracy: 0.9792 - val_loss: 1.3517 - val_accuracy: 0.7254
# Epoch 81/100
# 50/50 [==============================] - 22s 446ms/step - loss: 0.0450 - accuracy: 0.9824 - val_loss: 0.9765 - val_accuracy: 0.7607
# Epoch 82/100
# 50/50 [==============================] - 22s 445ms/step - loss: 0.0315 - accuracy: 0.9924 - val_loss: 0.6336 - val_accuracy: 0.8212
# Epoch 83/100
# 50/50 [==============================] - 22s 446ms/step - loss: 0.0462 - accuracy: 0.9868 - val_loss: 0.2738 - val_accuracy: 0.9345
# Epoch 84/100
# 50/50 [==============================] - 22s 446ms/step - loss: 0.0662 - accuracy: 0.9817 - val_loss: 5.1098 - val_accuracy: 0.5214
# Epoch 85/100
# 50/50 [==============================] - 21s 424ms/step - loss: 0.0411 - accuracy: 0.9880 - val_loss: 0.4956 - val_accuracy: 0.8816
# Epoch 86/100
# 50/50 [==============================] - 21s 425ms/step - loss: 0.0266 - accuracy: 0.9899 - val_loss: 4.3123 - val_accuracy: 0.5264
# Epoch 87/100
# 50/50 [==============================] - 22s 446ms/step - loss: 0.0406 - accuracy: 0.9868 - val_loss: 5.5133 - val_accuracy: 0.4811
# Epoch 88/100
# 50/50 [==============================] - 21s 423ms/step - loss: 0.0265 - accuracy: 0.9918 - val_loss: 0.7117 - val_accuracy: 0.8212
# Epoch 89/100
# 50/50 [==============================] - 21s 424ms/step - loss: 0.0597 - accuracy: 0.9855 - val_loss: 0.4840 - val_accuracy: 0.8766
# Epoch 90/100
# 50/50 [==============================] - 22s 447ms/step - loss: 0.0408 - accuracy: 0.9880 - val_loss: 5.7101 - val_accuracy: 0.5189
# Epoch 91/100
# 50/50 [==============================] - 21s 424ms/step - loss: 0.0639 - accuracy: 0.9824 - val_loss: 3.5919 - val_accuracy: 0.5264
# Epoch 92/100
# 50/50 [==============================] - 21s 424ms/step - loss: 0.0394 - accuracy: 0.9887 - val_loss: 1.6971 - val_accuracy: 0.6725
# Epoch 93/100
# 50/50 [==============================] - 21s 424ms/step - loss: 0.0614 - accuracy: 0.9830 - val_loss: 0.2732 - val_accuracy: 0.9395
# Epoch 94/100
# 50/50 [==============================] - 22s 447ms/step - loss: 0.0217 - accuracy: 0.9956 - val_loss: 0.3288 - val_accuracy: 0.9320
# Epoch 95/100
# 50/50 [==============================] - 21s 424ms/step - loss: 0.0546 - accuracy: 0.9855 - val_loss: 1.2626 - val_accuracy: 0.7229
# Epoch 96/100
# 50/50 [==============================] - 21s 424ms/step - loss: 0.0203 - accuracy: 0.9950 - val_loss: 0.3126 - val_accuracy: 0.9194
# Epoch 97/100
# 50/50 [==============================] - 21s 424ms/step - loss: 0.0317 - accuracy: 0.9893 - val_loss: 1.4273 - val_accuracy: 0.6851
# Epoch 98/100
# 50/50 [==============================] - 22s 446ms/step - loss: 0.0699 - accuracy: 0.9836 - val_loss: 0.5669 - val_accuracy: 0.8489
# Epoch 99/100
# 50/50 [==============================] - 21s 424ms/step - loss: 0.0486 - accuracy: 0.9855 - val_loss: 5.9640 - val_accuracy: 0.5189
# Epoch 100/100
# 50/50 [==============================] - 21s 425ms/step - loss: 0.0374 - accuracy: 0.9868 - val_loss: 0.3053 - val_accuracy: 0.9144
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# Acc VGG16-VGG16 score: 49.5
# <ipython-input-46-a90959985214>:138: RuntimeWarning:
#
# invalid value encountered in true_divide
# ['COVID' 'non-COVID']

# %%
# EKLENDİ 
print("training_accuracy :", history.history['accuracy'][-1])
print("validation_accuracy :", history.history['val_accuracy'][-1])
# Out:
# training_accuracy 0.9867674708366394
# validation_accuracy 0.9143576622009277

# %%
# EKLENDİİ 
plt.figure(1, figsize = (15, 5))
plt.subplot(1,2,1)
plt.title(" Veriseti 1, VGG16 Modeli Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.plot( history.history["loss"], label = "Training Loss")
plt.plot( history.history["val_loss"], label = "Validation Loss")
plt.grid(True)
plt.legend()

plt.subplot(1,2,2)
plt.title(" Veriseti 1, VGG16 Modeli Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.plot( history.history["accuracy"], label = "Training Accuracy")
plt.plot( history.history["val_accuracy"], label = "Validation Accuracy")
plt.grid(True)
plt.legend()
plt.show()

# %%
#EKLENDİ 
#VGG16

#classification report on train
predIdxs = vgg16_model.predict (X_train, batch_size=64)
predIdxs = np.argmax(predIdxs, axis=1)
print(classification_report(Y_train.argmax(axis=1), predIdxs, target_names=le.classes_, digits=3))
# Out:
# 31/31 [==============================] - 12s 224ms/step
#               precision    recall  f1-score   support
#
#        COVID      0.943     0.996     0.969      1001
#    non-COVID      0.996     0.939     0.966       983
#
#     accuracy                          0.968      1984
#    macro avg      0.969     0.967     0.968      1984
# weighted avg      0.969     0.968     0.968      1984

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
confusionmatrix=confusion_matrix(Y_train.argmax(axis=1), predIdxs)
print(confusionmatrix)
# Out:
# [[997   4]
#  [ 60 923]]

# %%
#heatmap
df_cm=pd.DataFrame(confusionmatrix, columns=le.classes_, index=le.classes_)
df_cm.index.name='Actual'
df_cm.columns.name='Predicted'
plt.figure(figsize=(5,5))
sns.heatmap(df_cm/np.sum(df_cm), fmt='.2%', annot=True, annot_kws={'size':16})
plt.savefig(filename)
plt.savefig("/content/drive/MyDrive/tez/saveimage/vgg16confusionmatrix.png")
plt.show()

# %%
print(X_train.shape, Y_train.shape)
print( X_test.shape, Y_test.shape)
# Out:
# (1984, 224, 224, 3) (1984, 2)
# (497, 224, 224, 3) (497,)

# %%
print(X_train.shape, X_test.shape, Y_train.shape, Y_test.shape)
# Out:
# (1984, 224, 224, 3) (497, 224, 224, 3) (1984, 2) (497,)

# %%
# EKLENDİ  hata

#print(classification_report(Y_train, y_preds))

# %%
#print("y test",Y_test)
#print("y train ",Y_train)

# %%
targets=np.load("../content/drive/MyDrive/tez/features/targets.npy")
print (targets)
# Out:
# ['COVID' 'non-COVID']

# %% [markdown]
# ### ResNet50 Model Eğitimi ve Testi

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Convolution2D 
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
import os
import shutil
from keras.preprocessing.image import ImageDataGenerator

from keras.models import Sequential
from keras.layers import GlobalAveragePooling2D
from keras.preprocessing import image

                   #  RESNET

resnet_model = ResNet50(input_shape=INPUT_SHAPE,include_top=False,weights='imagenet')
resnet_model.summary()
resnet_model = tf.keras.Sequential([
        resnet_model,
        GlobalAveragePooling2D(),
        Dense(512, activation="relu"),
        BatchNormalization(),
        Dropout(0.6),
        Dense(128, activation="relu"),
        BatchNormalization(),
        Dropout(0.4),
        Dense(64,activation="relu"),
        BatchNormalization(),
        Dropout(0.3),
        Dense(2,activation="softmax")#bu kısımdaki 3 sayısı sizin almak istediğiniz sonuc sayısı.yani covid, zatüre ve normal 3 adet olduğu için 3
    ])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 0s 0us/step
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_4[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 112, 112, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 56, 56, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 56, 56, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 28, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 28, 28, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 28, 28, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 14, 14, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 14, 14, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 14, 14, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 14, 14, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 14, 14, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 7, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 7, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block3_add[0][0]']
#
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 23,534,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
#Modelimizi derlemek
resnet_model.compile(loss='binary_crossentropy',optimizer='rmsprop',metrics=['accuracy'])

#Ağımızın özeti gösteriliyor
resnet_model.summary()

from tensorflow.keras.utils import plot_model
#plot_model(model, to_file='model1.png')
plot_model(resnet_model, to_file="/content/drive/MyDrive/tez/saveimage/modelresnet.png")
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  global_average_pooling2d_1   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  dense_8 (Dense)             (None, 512)               1049088
#
#  batch_normalization_3 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_9 (Dense)             (None, 128)               65664
#
#  batch_normalization_4 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_10 (Dense)            (None, 64)                8256
#
#  batch_normalization_5 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_11 (Dense)            (None, 2)                 130
#
# =================================================================
# Total params: 24,713,666
# Trainable params: 24,659,138
# Non-trainable params: 54,528
# _________________________________________________________________

# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from google.colab import drive
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPClassifier
from google.colab import drive
import matplotlib
import os
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
from keras.optimizers import Adam
import numpy as np
from numpy import argmax
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import scipy.misc
from keras.layers import Concatenate, Dense, LSTM, Input, concatenate
from keras import backend as K
from skimage.transform import resize
import os
from keras.models import load_model
from keras.utils import np_utils
import joblib
from keras.layers import Flatten
from keras.models import Model
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import pandas as pd
from  sklearn.ensemble import GradientBoostingClassifier
#from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
from xgboost import XGBClassifier
from sklearn import svm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.neural_network import MLPClassifier
from keras.models import Model
from keras.layers import Input,Reshape
from keras.layers import Dense, Conv2D, Flatten
from keras.layers import Input, LSTM, Bidirectional, Conv1D
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Embedding
from keras.models import Sequential
from keras.utils import to_categorical
from keras.layers import Flatten
from keras.models import Model
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from keras.layers import Input, LSTM, Dense,Bidirectional 
from keras.models import Model
from sklearn.metrics import  confusion_matrix,classification_report
import pickle
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_classif

def isCheck_Klasor(path):    
    if not os.path.isdir(path):
        os.mkdir( path, 755 );

def plot_ciz_acc_loss(history,fold_index,etiket):
    
    # list all data in history
    print(history.history.keys())
    # summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
   # plt.savefig(anaKlasor+"/acc_loss_graphs/"+etiket+"resnet_acc_fold_value="+str(fold_index)+".png")
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.savefig(anaKlasor+"/acc_loss_graphs/"+etiket+"_loss_fold_value="+str(fold_index)+".png")
    plt.show()


def cm_analysis(y_train, y_pred, labels, ymap=None, figsize=(10,10)):
    
    """
    Generate matrix plot of confusion matrix with pretty annotations.
    The plot image is saved to disk.
    args: 
      y_true:    true label of the data, with shape (nsamples,)
      y_pred:    prediction of the data, with shape (nsamples,)
      filename:  filename of figure file to save
      labels:    string array, name the order of class labels in the confusion matrix.
                 use `clf.classes_` if using scikit-learn models.
                 with shape (nclass,).
      ymap:      dict: any -> string, length == nclass.
                 if not None, map the labels & ys to more understandable strings.
                 Caution: original y_true, y_pred and labels must align.
      figsize:   the size of the figure plotted.
    """
    labels=[0,1]
    if ymap is not None:
        y_pred = [ymap[yi] for yi in y_pred]
        y_train = [ymap[yi] for yi in y_train]
        labels = [ymap[yi] for yi in labels]
        
    cm = confusion_matrix(y_train, y_pred, labels=labels)
    cm_sum = np.sum(cm, axis=1, keepdims=True)
    cm_perc = cm / cm_sum.astype(float) * 100
    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            c = cm[i, j]
            p = cm_perc[i, j]
            if i == j:
                s = cm_sum[i]
                annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
            elif c == 0:
                annot[i, j] = ''
            else:
                annot[i, j] = '%.1f%%\n%d' % (p, c)
    cm = pd.DataFrame(cm, index=labels, columns=labels)
    cm.index.name = 'Actual'
    cm.columns.name = 'Predicted'
    fig, ax = plt.subplots(figsize=figsize)
    sns.heatmap(cm, annot=annot, fmt='', ax=ax)
    #plt.savefig(filename)
    plt.show()

anaKlasor =  "/content/drive/MyDrive/tez/"
path=anaKlasor+"/features/"

X=np.load(path+"/X.npy")
y=np.load(path+"/y.npy")
X_train, X_test, Y_train, Y_test = train_test_split(X, y, stratify=y, test_size=0.20, random_state=42)
Y_train=to_categorical(Y_train)


EPOCHS =100
BATCH_SIZE = 16


resnet_model.compile(loss='binary_crossentropy',optimizer='rmsprop',metrics=['accuracy'])
etiket="ResNet50"
Y_test_preds=resnet_model.predict(X_test)
print (etiket,"MODELİN SONUÇLARI :",Y_test_preds)


#eğitimi başlat
history = resnet_model.fit( X_train, Y_train,  validation_split=0.2,epochs = EPOCHS,verbose=1)


# GRAFİK ÇİZİLSİN
plot_ciz_acc_loss(history,"Hold-out",etiket)


y_preds=np.argmax(Y_test_preds,axis=1)
acc=round(accuracy_score(Y_test, y_preds),3)
print ("Acc "+etiket+"-"+etiket+ " score:",acc*100)

#KARIŞIKLIK MATRİSİ
cm_analysis(Y_test, y_preds, targets, figsize=(5,5))


resnet_model.save('../content/drive/MyDrive/tez/models/model_'+etiket+'.h5')

targets=np.load("../content/drive/MyDrive/tez/features/targets.npy")
print (targets)
# Out:
# 16/16 [==============================] - 4s 122ms/step
# Epoch 1/100
# 50/50 [==============================] - 50s 407ms/step - loss: 0.5942 - accuracy: 0.7417 - val_loss: 22.4357 - val_accuracy: 0.5189
# Epoch 2/100
# 50/50 [==============================] - 16s 330ms/step - loss: 0.4039 - accuracy: 0.8601 - val_loss: 107.8683 - val_accuracy: 0.5013
# Epoch 3/100
# 50/50 [==============================] - 17s 337ms/step - loss: 0.3086 - accuracy: 0.8847 - val_loss: 26.6680 - val_accuracy: 0.5214
# Epoch 4/100
# 50/50 [==============================] - 17s 336ms/step - loss: 0.2593 - accuracy: 0.9055 - val_loss: 25.9442 - val_accuracy: 0.5063
# Epoch 5/100
# 50/50 [==============================] - 17s 333ms/step - loss: 0.1894 - accuracy: 0.9370 - val_loss: 1.5894 - val_accuracy: 0.6725
# Epoch 6/100
# 50/50 [==============================] - 17s 335ms/step - loss: 0.1987 - accuracy: 0.9269 - val_loss: 8.5492 - val_accuracy: 0.4811
# Epoch 7/100
# 50/50 [==============================] - 17s 332ms/step - loss: 0.1319 - accuracy: 0.9483 - val_loss: 2.4850 - val_accuracy: 0.6776
# Epoch 8/100
# 50/50 [==============================] - 17s 332ms/step - loss: 0.1111 - accuracy: 0.9628 - val_loss: 1.4142 - val_accuracy: 0.7657
# Epoch 9/100
# 50/50 [==============================] - 17s 334ms/step - loss: 0.1083 - accuracy: 0.9628 - val_loss: 0.3925 - val_accuracy: 0.9068
# Epoch 10/100
# 50/50 [==============================] - 17s 337ms/step - loss: 0.0979 - accuracy: 0.9653 - val_loss: 0.4928 - val_accuracy: 0.8539
# Epoch 11/100
# 50/50 [==============================] - 17s 335ms/step - loss: 0.0909 - accuracy: 0.9641 - val_loss: 2.2501 - val_accuracy: 0.5693
# Epoch 12/100
# 50/50 [==============================] - 17s 335ms/step - loss: 0.0991 - accuracy: 0.9641 - val_loss: 1.1479 - val_accuracy: 0.7280
# Epoch 13/100
# 50/50 [==============================] - 17s 334ms/step - loss: 0.0621 - accuracy: 0.9786 - val_loss: 0.4479 - val_accuracy: 0.8615
# Epoch 14/100
# 50/50 [==============================] - 17s 337ms/step - loss: 0.0664 - accuracy: 0.9805 - val_loss: 0.2302 - val_accuracy: 0.9345
# Epoch 15/100
# 50/50 [==============================] - 17s 333ms/step - loss: 0.1098 - accuracy: 0.9635 - val_loss: 0.6543 - val_accuracy: 0.8161
# Epoch 16/100
# 50/50 [==============================] - 17s 336ms/step - loss: 0.0614 - accuracy: 0.9779 - val_loss: 0.4476 - val_accuracy: 0.8539
# Epoch 17/100
# 50/50 [==============================] - 17s 336ms/step - loss: 0.0579 - accuracy: 0.9811 - val_loss: 0.4509 - val_accuracy: 0.8967
# Epoch 18/100
# 50/50 [==============================] - 17s 336ms/step - loss: 0.0625 - accuracy: 0.9798 - val_loss: 1.4301 - val_accuracy: 0.6675
# Epoch 19/100
# 50/50 [==============================] - 17s 333ms/step - loss: 0.0386 - accuracy: 0.9849 - val_loss: 0.3922 - val_accuracy: 0.8892
# Epoch 20/100
# 50/50 [==============================] - 17s 333ms/step - loss: 0.0834 - accuracy: 0.9754 - val_loss: 0.3756 - val_accuracy: 0.9345
# Epoch 21/100
# 50/50 [==============================] - 17s 336ms/step - loss: 0.0614 - accuracy: 0.9805 - val_loss: 0.2346 - val_accuracy: 0.9370
# Epoch 22/100
# 50/50 [==============================] - 17s 336ms/step - loss: 0.0640 - accuracy: 0.9830 - val_loss: 0.7308 - val_accuracy: 0.8388
# Epoch 23/100
# 50/50 [==============================] - 17s 336ms/step - loss: 0.0636 - accuracy: 0.9773 - val_loss: 0.4914 - val_accuracy: 0.8741
# Epoch 24/100
# 50/50 [==============================] - 17s 336ms/step - loss: 0.0453 - accuracy: 0.9880 - val_loss: 0.6410 - val_accuracy: 0.8312
# Epoch 25/100
# 50/50 [==============================] - 17s 337ms/step - loss: 0.0584 - accuracy: 0.9811 - val_loss: 0.4653 - val_accuracy: 0.8766
# Epoch 26/100
# 50/50 [==============================] - 17s 333ms/step - loss: 0.0524 - accuracy: 0.9824 - val_loss: 0.4226 - val_accuracy: 0.9219
# Epoch 27/100
# 50/50 [==============================] - 17s 336ms/step - loss: 0.0321 - accuracy: 0.9899 - val_loss: 0.6478 - val_accuracy: 0.8035
# Epoch 28/100
# 50/50 [==============================] - 17s 334ms/step - loss: 0.0674 - accuracy: 0.9792 - val_loss: 3.5896 - val_accuracy: 0.5365
# Epoch 29/100
# 50/50 [==============================] - 17s 337ms/step - loss: 0.0565 - accuracy: 0.9830 - val_loss: 0.3384 - val_accuracy: 0.9244
# Epoch 30/100
# 50/50 [==============================] - 17s 333ms/step - loss: 0.0308 - accuracy: 0.9912 - val_loss: 1.1258 - val_accuracy: 0.7985
# Epoch 31/100
# 50/50 [==============================] - 17s 333ms/step - loss: 0.0556 - accuracy: 0.9868 - val_loss: 2.3847 - val_accuracy: 0.5995
# Epoch 32/100
# 50/50 [==============================] - 17s 336ms/step - loss: 0.0228 - accuracy: 0.9931 - val_loss: 0.5324 - val_accuracy: 0.8589
# Epoch 33/100
# 50/50 [==============================] - 17s 336ms/step - loss: 0.0340 - accuracy: 0.9918 - val_loss: 1.1505 - val_accuracy: 0.7229
# Epoch 34/100
# 50/50 [==============================] - 17s 333ms/step - loss: 0.0265 - accuracy: 0.9918 - val_loss: 4.0633 - val_accuracy: 0.5214
# Epoch 35/100
# 50/50 [==============================] - 17s 333ms/step - loss: 0.0427 - accuracy: 0.9880 - val_loss: 1.7393 - val_accuracy: 0.6877
# Epoch 36/100
# 50/50 [==============================] - 17s 337ms/step - loss: 0.0341 - accuracy: 0.9899 - val_loss: 0.7090 - val_accuracy: 0.8489
# Epoch 37/100
# 50/50 [==============================] - 17s 333ms/step - loss: 0.0802 - accuracy: 0.9773 - val_loss: 1.3701 - val_accuracy: 0.6625
# Epoch 38/100
# 50/50 [==============================] - 17s 336ms/step - loss: 0.0564 - accuracy: 0.9817 - val_loss: 1.1645 - val_accuracy: 0.7431
# Epoch 39/100
# 50/50 [==============================] - 17s 333ms/step - loss: 0.0225 - accuracy: 0.9943 - val_loss: 0.5275 - val_accuracy: 0.8942
# Epoch 40/100
# 50/50 [==============================] - 17s 336ms/step - loss: 0.0192 - accuracy: 0.9937 - val_loss: 0.3931 - val_accuracy: 0.8892
# Epoch 41/100
# 50/50 [==============================] - 17s 334ms/step - loss: 0.0487 - accuracy: 0.9868 - val_loss: 1.5755 - val_accuracy: 0.6599
# Epoch 42/100
# 50/50 [==============================] - 17s 336ms/step - loss: 0.0422 - accuracy: 0.9868 - val_loss: 0.6258 - val_accuracy: 0.8514
# Epoch 43/100
# 50/50 [==============================] - 17s 336ms/step - loss: 0.0145 - accuracy: 0.9968 - val_loss: 0.3825 - val_accuracy: 0.8841
# Epoch 44/100
# 50/50 [==============================] - 17s 336ms/step - loss: 0.0458 - accuracy: 0.9887 - val_loss: 0.5381 - val_accuracy: 0.8791
# Epoch 45/100
# 50/50 [==============================] - 17s 333ms/step - loss: 0.0240 - accuracy: 0.9937 - val_loss: 0.9775 - val_accuracy: 0.8312
# Epoch 46/100
# 50/50 [==============================] - 17s 333ms/step - loss: 0.0248 - accuracy: 0.9924 - val_loss: 0.3526 - val_accuracy: 0.9270
# Epoch 47/100
# 50/50 [==============================] - 17s 336ms/step - loss: 0.0139 - accuracy: 0.9962 - val_loss: 1.2738 - val_accuracy: 0.7859
# Epoch 48/100
# 50/50 [==============================] - 17s 333ms/step - loss: 0.0330 - accuracy: 0.9899 - val_loss: 0.6484 - val_accuracy: 0.8564
# Epoch 49/100
# 50/50 [==============================] - 17s 333ms/step - loss: 0.0168 - accuracy: 0.9962 - val_loss: 0.6038 - val_accuracy: 0.8766
# Epoch 50/100
# 50/50 [==============================] - 17s 333ms/step - loss: 0.0357 - accuracy: 0.9918 - val_loss: 0.3705 - val_accuracy: 0.9043
# Epoch 51/100
# 50/50 [==============================] - 17s 336ms/step - loss: 0.0341 - accuracy: 0.9893 - val_loss: 1.2951 - val_accuracy: 0.7431
# Epoch 52/100
# 50/50 [==============================] - 17s 336ms/step - loss: 0.0216 - accuracy: 0.9962 - val_loss: 0.2394 - val_accuracy: 0.9421
# Epoch 53/100
# 50/50 [==============================] - 17s 333ms/step - loss: 0.0070 - accuracy: 0.9975 - val_loss: 0.2616 - val_accuracy: 0.9370
# Epoch 54/100
# 50/50 [==============================] - 17s 334ms/step - loss: 0.0216 - accuracy: 0.9943 - val_loss: 2.6086 - val_accuracy: 0.7103
# Epoch 55/100
# 50/50 [==============================] - 17s 337ms/step - loss: 0.0263 - accuracy: 0.9912 - val_loss: 0.2304 - val_accuracy: 0.9345
# Epoch 56/100
# 50/50 [==============================] - 17s 336ms/step - loss: 0.0218 - accuracy: 0.9943 - val_loss: 0.6643 - val_accuracy: 0.8766
# Epoch 57/100
# 50/50 [==============================] - 17s 336ms/step - loss: 0.0287 - accuracy: 0.9937 - val_loss: 1.2647 - val_accuracy: 0.7884
# Epoch 58/100
# 50/50 [==============================] - 17s 337ms/step - loss: 0.0129 - accuracy: 0.9968 - val_loss: 2.2632 - val_accuracy: 0.6877
# Epoch 59/100
# 50/50 [==============================] - 17s 336ms/step - loss: 0.0340 - accuracy: 0.9937 - val_loss: 1.7436 - val_accuracy: 0.7128
# Epoch 60/100
# 50/50 [==============================] - 17s 336ms/step - loss: 0.0133 - accuracy: 0.9962 - val_loss: 0.9171 - val_accuracy: 0.7909
# Epoch 61/100
# 50/50 [==============================] - 17s 336ms/step - loss: 0.0186 - accuracy: 0.9937 - val_loss: 0.3351 - val_accuracy: 0.9219
# Epoch 62/100
# 50/50 [==============================] - 17s 334ms/step - loss: 0.0177 - accuracy: 0.9937 - val_loss: 0.7615 - val_accuracy: 0.8186
# Epoch 63/100
# 50/50 [==============================] - 17s 336ms/step - loss: 0.0128 - accuracy: 0.9962 - val_loss: 0.5059 - val_accuracy: 0.9068
# Epoch 64/100
# 50/50 [==============================] - 17s 336ms/step - loss: 0.0206 - accuracy: 0.9943 - val_loss: 0.8256 - val_accuracy: 0.8640
# Epoch 65/100
# 50/50 [==============================] - 17s 336ms/step - loss: 0.0302 - accuracy: 0.9887 - val_loss: 0.9880 - val_accuracy: 0.8413
# Epoch 66/100
# 50/50 [==============================] - 17s 333ms/step - loss: 0.0157 - accuracy: 0.9968 - val_loss: 0.3763 - val_accuracy: 0.9270
# Epoch 67/100
# 50/50 [==============================] - 17s 333ms/step - loss: 0.0284 - accuracy: 0.9931 - val_loss: 2.3687 - val_accuracy: 0.6952
# Epoch 68/100
# 50/50 [==============================] - 17s 337ms/step - loss: 0.0040 - accuracy: 0.9987 - val_loss: 0.3630 - val_accuracy: 0.9471
# Epoch 69/100
# 50/50 [==============================] - 17s 334ms/step - loss: 9.2426e-04 - accuracy: 1.0000 - val_loss: 0.3729 - val_accuracy: 0.9446
# Epoch 70/100
# 50/50 [==============================] - 17s 336ms/step - loss: 9.3584e-04 - accuracy: 0.9994 - val_loss: 0.3965 - val_accuracy: 0.9345
# Epoch 71/100
# 50/50 [==============================] - 17s 336ms/step - loss: 0.0171 - accuracy: 0.9962 - val_loss: 1.0840 - val_accuracy: 0.8564
# Epoch 72/100
# 50/50 [==============================] - 17s 333ms/step - loss: 0.0221 - accuracy: 0.9950 - val_loss: 0.7132 - val_accuracy: 0.8967
# Epoch 73/100
# 50/50 [==============================] - 17s 336ms/step - loss: 0.0603 - accuracy: 0.9887 - val_loss: 0.5058 - val_accuracy: 0.9169
# Epoch 74/100
# 50/50 [==============================] - 17s 333ms/step - loss: 0.0428 - accuracy: 0.9899 - val_loss: 0.3687 - val_accuracy: 0.9270
# Epoch 75/100
# 50/50 [==============================] - 17s 333ms/step - loss: 0.0114 - accuracy: 0.9950 - val_loss: 0.3833 - val_accuracy: 0.9169
# Epoch 76/100
# 50/50 [==============================] - 17s 333ms/step - loss: 0.0519 - accuracy: 0.9880 - val_loss: 0.3123 - val_accuracy: 0.9421
# Epoch 77/100
# 50/50 [==============================] - 17s 337ms/step - loss: 0.0123 - accuracy: 0.9956 - val_loss: 0.6710 - val_accuracy: 0.8841
# Epoch 78/100
# 50/50 [==============================] - 17s 336ms/step - loss: 0.0196 - accuracy: 0.9956 - val_loss: 0.7524 - val_accuracy: 0.8589
# Epoch 79/100
# 50/50 [==============================] - 17s 333ms/step - loss: 0.0320 - accuracy: 0.9912 - val_loss: 6.6536 - val_accuracy: 0.5416
# Epoch 80/100
# 50/50 [==============================] - 17s 337ms/step - loss: 0.0259 - accuracy: 0.9950 - val_loss: 0.2752 - val_accuracy: 0.9169
# Epoch 81/100
# 50/50 [==============================] - 17s 336ms/step - loss: 0.0315 - accuracy: 0.9918 - val_loss: 0.3552 - val_accuracy: 0.8841
# Epoch 82/100
# 50/50 [==============================] - 17s 334ms/step - loss: 0.0527 - accuracy: 0.9874 - val_loss: 0.6696 - val_accuracy: 0.8438
# Epoch 83/100
# 50/50 [==============================] - 17s 333ms/step - loss: 0.0081 - accuracy: 0.9987 - val_loss: 2.2285 - val_accuracy: 0.6851
# Epoch 84/100
# 50/50 [==============================] - 17s 337ms/step - loss: 0.0215 - accuracy: 0.9950 - val_loss: 0.6812 - val_accuracy: 0.8967
# Epoch 85/100
# 50/50 [==============================] - 17s 334ms/step - loss: 0.0183 - accuracy: 0.9924 - val_loss: 0.8381 - val_accuracy: 0.8413
# Epoch 86/100
# 50/50 [==============================] - 17s 336ms/step - loss: 0.0180 - accuracy: 0.9950 - val_loss: 0.3226 - val_accuracy: 0.9244
# Epoch 87/100
# 50/50 [==============================] - 17s 337ms/step - loss: 0.0191 - accuracy: 0.9962 - val_loss: 0.3716 - val_accuracy: 0.9043
# Epoch 88/100
# 50/50 [==============================] - 17s 337ms/step - loss: 0.0065 - accuracy: 0.9975 - val_loss: 0.4243 - val_accuracy: 0.9244
# Epoch 89/100
# 50/50 [==============================] - 17s 336ms/step - loss: 0.0095 - accuracy: 0.9987 - val_loss: 0.4442 - val_accuracy: 0.9169
# Epoch 90/100
# 50/50 [==============================] - 17s 334ms/step - loss: 0.0051 - accuracy: 0.9981 - val_loss: 0.3289 - val_accuracy: 0.9320
# Epoch 91/100
# 50/50 [==============================] - 17s 337ms/step - loss: 0.0252 - accuracy: 0.9950 - val_loss: 0.4569 - val_accuracy: 0.9244
# Epoch 92/100
# 50/50 [==============================] - 17s 334ms/step - loss: 0.0175 - accuracy: 0.9968 - val_loss: 1.1681 - val_accuracy: 0.8338
# Epoch 93/100
# 50/50 [==============================] - 17s 336ms/step - loss: 0.0071 - accuracy: 0.9975 - val_loss: 1.5260 - val_accuracy: 0.8060
# Epoch 94/100
# 50/50 [==============================] - 17s 336ms/step - loss: 0.0124 - accuracy: 0.9968 - val_loss: 0.5025 - val_accuracy: 0.9320
# Epoch 95/100
# 50/50 [==============================] - 17s 338ms/step - loss: 0.0044 - accuracy: 0.9975 - val_loss: 0.3287 - val_accuracy: 0.9295
# Epoch 96/100
# 50/50 [==============================] - 17s 336ms/step - loss: 0.0244 - accuracy: 0.9943 - val_loss: 0.4150 - val_accuracy: 0.9421
# Epoch 97/100
# 50/50 [==============================] - 17s 333ms/step - loss: 0.0262 - accuracy: 0.9943 - val_loss: 0.3536 - val_accuracy: 0.9244
# Epoch 98/100
# 50/50 [==============================] - 17s 336ms/step - loss: 0.0202 - accuracy: 0.9943 - val_loss: 0.2322 - val_accuracy: 0.9471
# Epoch 99/100
# 50/50 [==============================] - 17s 334ms/step - loss: 0.0204 - accuracy: 0.9937 - val_loss: 0.2873 - val_accuracy: 0.9370
# Epoch 100/100
# 50/50 [==============================] - 17s 333ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.5618 - val_accuracy: 0.9169
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# Acc ResNet50-ResNet50 score: 47.099999999999994
# ['COVID' 'non-COVID']

# %%
# EKLENDİ 
print("training_accuracy :", history.history['accuracy'][-1])
print("validation_accuracy :", history.history['val_accuracy'][-1])
# Out:
# training_accuracy 1.0
# validation_accuracy 0.9168765544891357

# %%
# EKLENDİİ 
plt.figure(1, figsize = (15, 5))
plt.subplot(1,2,1)
plt.title(" Veriseti 1, RESNET50 Modeli Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.plot( history.history["loss"], label = "Training Loss")
plt.plot( history.history["val_loss"], label = "Validation Loss")
plt.grid(True)
plt.legend()

plt.subplot(1,2,2)
plt.title(" Veriseti 1, RESNET50 Modeli Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.plot( history.history["accuracy"], label = "Training Accuracy")
plt.plot( history.history["val_accuracy"], label = "Validation Accuracy")
plt.grid(True)
plt.legend()
plt.show()

# %%
#EKLENDİ 


#classification report on train
predIdxs = resnet_model.predict (X_train, batch_size=64)
predIdxs = np.argmax(predIdxs, axis=1)
print(classification_report(Y_train.argmax(axis=1), predIdxs, target_names=le.classes_, digits=3))
# Out:
# 31/31 [==============================] - 6s 168ms/step
#               precision    recall  f1-score   support
#
#        COVID      0.996     0.941     0.968      1001
#    non-COVID      0.943     0.996     0.969       983
#
#     accuracy                          0.968      1984
#    macro avg      0.969     0.968     0.968      1984
# weighted avg      0.970     0.968     0.968      1984

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
confusionmatrix=confusion_matrix(Y_train.argmax(axis=1), predIdxs)
print(confusionmatrix)
# Out:
# [[942  59]
#  [  4 979]]

# %%
#heatmap
df_cm=pd.DataFrame(confusionmatrix, columns=le.classes_, index=le.classes_)
df_cm.index.name='Actual'
df_cm.columns.name='Predicted'
plt.figure(figsize=(5,5))
sns.heatmap(df_cm/np.sum(df_cm), fmt='.2%', annot=True, annot_kws={'size':16})
plt.savefig("/content/drive/MyDrive/tez/saveimage/resnet50confusionmatrix.png")
plt.show()

# %%
print(X_train.shape, Y_train.shape)
print( X_test.shape, Y_test.shape)
# Out:
# (1984, 224, 224, 3) (1984, 2)
# (497, 224, 224, 3) (497,)

# %%
print(X_train.shape, X_test.shape, Y_train.shape, Y_test.shape)
# Out:
# (1984, 224, 224, 3) (497, 224, 224, 3) (1984, 2) (497,)

# %%
targets=np.load("../content/drive/MyDrive/tez/features/targets.npy")
print (targets)
# Out:
# ['COVID' 'non-COVID']

# %% [markdown]
# # DENSENET 201

# %%
# import libraries
import json
import math
import os
from glob import glob 
from tqdm import tqdm
from PIL import Image
import cv2 # image processing
import numpy as np # linear algebra
import pandas as pd # data processing
import matplotlib.pyplot as plt # data visualization

from sklearn.metrics import accuracy_score 
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report 
from sklearn.model_selection import train_test_split

from keras import layers
from keras.models import Sequential
from keras.optimizers import Adam, RMSprop
from keras.applications import DenseNet201
from keras.utils.np_utils import to_categorical
from keras.layers import  Conv2D,MaxPooling2D,Activation,Dropout,Flatten,Dense,BatchNormalization

# %%
tf.keras.applications.densenet.DenseNet201(
    include_top=True,
    weights='imagenet',
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classes=1000,
    classifier_activation='softmax'
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels.h5
# 82524592/82524592 [==============================] - 0s 0us/step

# %%
#    vgg16_model

from keras.models import Sequential
from keras.layers import GlobalAveragePooling2D
from keras.applications import DenseNet201
densenet_base_model = DenseNet201(input_shape=INPUT_SHAPE,include_top=False,weights='imagenet')

densenet_base_model.summary()
densenet_model = tf.keras.Sequential([
        densenet_base_model,
        GlobalAveragePooling2D(),
        Dense(512, activation="relu"),
        BatchNormalization(),
        Dropout(0.6),
        Dense(128, activation="relu"),
        BatchNormalization(),
        Dropout(0.4),
        Dense(64,activation="relu"),
        BatchNormalization(),
        Dropout(0.3),
        Dense(2,activation="softmax")
    ])
# Out:
# Model: "densenet201"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_19 (InputLayer)          [(None, 224, 224, 3  0           []
#                                 )]
#
#  zero_padding2d_26 (ZeroPadding  (None, 230, 230, 3)  0          ['input_19[0][0]']
#  2D)
#
#  conv1/conv (Conv2D)            (None, 112, 112, 64  9408        ['zero_padding2d_26[0][0]']
#                                 )
#
#  conv1/bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1/conv[0][0]']
#                                 )
#
#  conv1/relu (Activation)        (None, 112, 112, 64  0           ['conv1/bn[0][0]']
#                                 )
#
#  zero_padding2d_27 (ZeroPadding  (None, 114, 114, 64  0          ['conv1/relu[0][0]']
#  2D)                            )
#
#  pool1 (MaxPooling2D)           (None, 56, 56, 64)   0           ['zero_padding2d_27[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 56, 56, 64)  256         ['pool1[0][0]']
#  ization)
#
#  conv2_block1_0_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_0_bn[0][0]']
#  n)
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 128)  8192        ['conv2_block1_0_relu[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_concat (Concatena  (None, 56, 56, 96)  0           ['pool1[0][0]',
#  te)                                                              'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, 56, 56, 96)  384         ['conv2_block1_concat[0][0]']
#  ization)
#
#  conv2_block2_0_relu (Activatio  (None, 56, 56, 96)  0           ['conv2_block2_0_bn[0][0]']
#  n)
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 128)  12288       ['conv2_block2_0_relu[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_concat (Concatena  (None, 56, 56, 128)  0          ['conv2_block1_concat[0][0]',
#  te)                                                              'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block2_concat[0][0]']
#  ization)
#
#  conv2_block3_0_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block3_0_bn[0][0]']
#  n)
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 128)  16384       ['conv2_block3_0_relu[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_concat (Concatena  (None, 56, 56, 160)  0          ['conv2_block2_concat[0][0]',
#  te)                                                              'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, 56, 56, 160)  640        ['conv2_block3_concat[0][0]']
#  ization)
#
#  conv2_block4_0_relu (Activatio  (None, 56, 56, 160)  0          ['conv2_block4_0_bn[0][0]']
#  n)
#
#  conv2_block4_1_conv (Conv2D)   (None, 56, 56, 128)  20480       ['conv2_block4_0_relu[0][0]']
#
#  conv2_block4_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block4_1_conv[0][0]']
#  ization)
#
#  conv2_block4_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block4_1_bn[0][0]']
#  n)
#
#  conv2_block4_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block4_1_relu[0][0]']
#
#  conv2_block4_concat (Concatena  (None, 56, 56, 192)  0          ['conv2_block3_concat[0][0]',
#  te)                                                              'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, 56, 56, 192)  768        ['conv2_block4_concat[0][0]']
#  ization)
#
#  conv2_block5_0_relu (Activatio  (None, 56, 56, 192)  0          ['conv2_block5_0_bn[0][0]']
#  n)
#
#  conv2_block5_1_conv (Conv2D)   (None, 56, 56, 128)  24576       ['conv2_block5_0_relu[0][0]']
#
#  conv2_block5_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block5_1_conv[0][0]']
#  ization)
#
#  conv2_block5_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block5_1_bn[0][0]']
#  n)
#
#  conv2_block5_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block5_1_relu[0][0]']
#
#  conv2_block5_concat (Concatena  (None, 56, 56, 224)  0          ['conv2_block4_concat[0][0]',
#  te)                                                              'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, 56, 56, 224)  896        ['conv2_block5_concat[0][0]']
#  ization)
#
#  conv2_block6_0_relu (Activatio  (None, 56, 56, 224)  0          ['conv2_block6_0_bn[0][0]']
#  n)
#
#  conv2_block6_1_conv (Conv2D)   (None, 56, 56, 128)  28672       ['conv2_block6_0_relu[0][0]']
#
#  conv2_block6_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block6_1_conv[0][0]']
#  ization)
#
#  conv2_block6_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block6_1_bn[0][0]']
#  n)
#
#  conv2_block6_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block6_1_relu[0][0]']
#
#  conv2_block6_concat (Concatena  (None, 56, 56, 256)  0          ['conv2_block5_concat[0][0]',
#  te)                                                              'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, 56, 56, 256)  1024        ['conv2_block6_concat[0][0]']
#
#  pool2_relu (Activation)        (None, 56, 56, 256)  0           ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)            (None, 56, 56, 128)  32768       ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling2D)  (None, 28, 28, 128)  0           ['pool2_conv[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 28, 28, 128)  512        ['pool2_pool[0][0]']
#  ization)
#
#  conv3_block1_0_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_0_bn[0][0]']
#  n)
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  16384       ['conv3_block1_0_relu[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_concat (Concatena  (None, 28, 28, 160)  0          ['pool2_pool[0][0]',
#  te)                                                              'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNormal  (None, 28, 28, 160)  640        ['conv3_block1_concat[0][0]']
#  ization)
#
#  conv3_block2_0_relu (Activatio  (None, 28, 28, 160)  0          ['conv3_block2_0_bn[0][0]']
#  n)
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  20480       ['conv3_block2_0_relu[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_concat (Concatena  (None, 28, 28, 192)  0          ['conv3_block1_concat[0][0]',
#  te)                                                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, 28, 28, 192)  768        ['conv3_block2_concat[0][0]']
#  ization)
#
#  conv3_block3_0_relu (Activatio  (None, 28, 28, 192)  0          ['conv3_block3_0_bn[0][0]']
#  n)
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  24576       ['conv3_block3_0_relu[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_concat (Concatena  (None, 28, 28, 224)  0          ['conv3_block2_concat[0][0]',
#  te)                                                              'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNormal  (None, 28, 28, 224)  896        ['conv3_block3_concat[0][0]']
#  ization)
#
#  conv3_block4_0_relu (Activatio  (None, 28, 28, 224)  0          ['conv3_block4_0_bn[0][0]']
#  n)
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  28672       ['conv3_block4_0_relu[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_concat (Concatena  (None, 28, 28, 256)  0          ['conv3_block3_concat[0][0]',
#  te)                                                              'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNormal  (None, 28, 28, 256)  1024       ['conv3_block4_concat[0][0]']
#  ization)
#
#  conv3_block5_0_relu (Activatio  (None, 28, 28, 256)  0          ['conv3_block5_0_bn[0][0]']
#  n)
#
#  conv3_block5_1_conv (Conv2D)   (None, 28, 28, 128)  32768       ['conv3_block5_0_relu[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_concat (Concatena  (None, 28, 28, 288)  0          ['conv3_block4_concat[0][0]',
#  te)                                                              'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNormal  (None, 28, 28, 288)  1152       ['conv3_block5_concat[0][0]']
#  ization)
#
#  conv3_block6_0_relu (Activatio  (None, 28, 28, 288)  0          ['conv3_block6_0_bn[0][0]']
#  n)
#
#  conv3_block6_1_conv (Conv2D)   (None, 28, 28, 128)  36864       ['conv3_block6_0_relu[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_concat (Concatena  (None, 28, 28, 320)  0          ['conv3_block5_concat[0][0]',
#  te)                                                              'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNormal  (None, 28, 28, 320)  1280       ['conv3_block6_concat[0][0]']
#  ization)
#
#  conv3_block7_0_relu (Activatio  (None, 28, 28, 320)  0          ['conv3_block7_0_bn[0][0]']
#  n)
#
#  conv3_block7_1_conv (Conv2D)   (None, 28, 28, 128)  40960       ['conv3_block7_0_relu[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_concat (Concatena  (None, 28, 28, 352)  0          ['conv3_block6_concat[0][0]',
#  te)                                                              'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNormal  (None, 28, 28, 352)  1408       ['conv3_block7_concat[0][0]']
#  ization)
#
#  conv3_block8_0_relu (Activatio  (None, 28, 28, 352)  0          ['conv3_block8_0_bn[0][0]']
#  n)
#
#  conv3_block8_1_conv (Conv2D)   (None, 28, 28, 128)  45056       ['conv3_block8_0_relu[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_concat (Concatena  (None, 28, 28, 384)  0          ['conv3_block7_concat[0][0]',
#  te)                                                              'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNormal  (None, 28, 28, 384)  1536       ['conv3_block8_concat[0][0]']
#  ization)
#
#  conv3_block9_0_relu (Activatio  (None, 28, 28, 384)  0          ['conv3_block9_0_bn[0][0]']
#  n)
#
#  conv3_block9_1_conv (Conv2D)   (None, 28, 28, 128)  49152       ['conv3_block9_0_relu[0][0]']
#
#  conv3_block9_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block9_1_conv[0][0]']
#  ization)
#
#  conv3_block9_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block9_1_bn[0][0]']
#  n)
#
#  conv3_block9_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block9_1_relu[0][0]']
#
#  conv3_block9_concat (Concatena  (None, 28, 28, 416)  0          ['conv3_block8_concat[0][0]',
#  te)                                                              'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchNorma  (None, 28, 28, 416)  1664       ['conv3_block9_concat[0][0]']
#  lization)
#
#  conv3_block10_0_relu (Activati  (None, 28, 28, 416)  0          ['conv3_block10_0_bn[0][0]']
#  on)
#
#  conv3_block10_1_conv (Conv2D)  (None, 28, 28, 128)  53248       ['conv3_block10_0_relu[0][0]']
#
#  conv3_block10_1_bn (BatchNorma  (None, 28, 28, 128)  512        ['conv3_block10_1_conv[0][0]']
#  lization)
#
#  conv3_block10_1_relu (Activati  (None, 28, 28, 128)  0          ['conv3_block10_1_bn[0][0]']
#  on)
#
#  conv3_block10_2_conv (Conv2D)  (None, 28, 28, 32)   36864       ['conv3_block10_1_relu[0][0]']
#
#  conv3_block10_concat (Concaten  (None, 28, 28, 448)  0          ['conv3_block9_concat[0][0]',
#  ate)                                                             'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchNorma  (None, 28, 28, 448)  1792       ['conv3_block10_concat[0][0]']
#  lization)
#
#  conv3_block11_0_relu (Activati  (None, 28, 28, 448)  0          ['conv3_block11_0_bn[0][0]']
#  on)
#
#  conv3_block11_1_conv (Conv2D)  (None, 28, 28, 128)  57344       ['conv3_block11_0_relu[0][0]']
#
#  conv3_block11_1_bn (BatchNorma  (None, 28, 28, 128)  512        ['conv3_block11_1_conv[0][0]']
#  lization)
#
#  conv3_block11_1_relu (Activati  (None, 28, 28, 128)  0          ['conv3_block11_1_bn[0][0]']
#  on)
#
#  conv3_block11_2_conv (Conv2D)  (None, 28, 28, 32)   36864       ['conv3_block11_1_relu[0][0]']
#
#  conv3_block11_concat (Concaten  (None, 28, 28, 480)  0          ['conv3_block10_concat[0][0]',
#  ate)                                                             'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchNorma  (None, 28, 28, 480)  1920       ['conv3_block11_concat[0][0]']
#  lization)
#
#  conv3_block12_0_relu (Activati  (None, 28, 28, 480)  0          ['conv3_block12_0_bn[0][0]']
#  on)
#
#  conv3_block12_1_conv (Conv2D)  (None, 28, 28, 128)  61440       ['conv3_block12_0_relu[0][0]']
#
#  conv3_block12_1_bn (BatchNorma  (None, 28, 28, 128)  512        ['conv3_block12_1_conv[0][0]']
#  lization)
#
#  conv3_block12_1_relu (Activati  (None, 28, 28, 128)  0          ['conv3_block12_1_bn[0][0]']
#  on)
#
#  conv3_block12_2_conv (Conv2D)  (None, 28, 28, 32)   36864       ['conv3_block12_1_relu[0][0]']
#
#  conv3_block12_concat (Concaten  (None, 28, 28, 512)  0          ['conv3_block11_concat[0][0]',
#  ate)                                                             'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalization)  (None, 28, 28, 512)  2048        ['conv3_block12_concat[0][0]']
#
#  pool3_relu (Activation)        (None, 28, 28, 512)  0           ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)            (None, 28, 28, 256)  131072      ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling2D)  (None, 14, 14, 256)  0           ['pool3_conv[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 14, 14, 256)  1024       ['pool3_pool[0][0]']
#  ization)
#
#  conv4_block1_0_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_0_bn[0][0]']
#  n)
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 128)  32768       ['conv4_block1_0_relu[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_concat (Concatena  (None, 14, 14, 288)  0          ['pool3_pool[0][0]',
#  te)                                                              'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNormal  (None, 14, 14, 288)  1152       ['conv4_block1_concat[0][0]']
#  ization)
#
#  conv4_block2_0_relu (Activatio  (None, 14, 14, 288)  0          ['conv4_block2_0_bn[0][0]']
#  n)
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 128)  36864       ['conv4_block2_0_relu[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_concat (Concatena  (None, 14, 14, 320)  0          ['conv4_block1_concat[0][0]',
#  te)                                                              'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNormal  (None, 14, 14, 320)  1280       ['conv4_block2_concat[0][0]']
#  ization)
#
#  conv4_block3_0_relu (Activatio  (None, 14, 14, 320)  0          ['conv4_block3_0_bn[0][0]']
#  n)
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 128)  40960       ['conv4_block3_0_relu[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_concat (Concatena  (None, 14, 14, 352)  0          ['conv4_block2_concat[0][0]',
#  te)                                                              'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNormal  (None, 14, 14, 352)  1408       ['conv4_block3_concat[0][0]']
#  ization)
#
#  conv4_block4_0_relu (Activatio  (None, 14, 14, 352)  0          ['conv4_block4_0_bn[0][0]']
#  n)
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 128)  45056       ['conv4_block4_0_relu[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_concat (Concatena  (None, 14, 14, 384)  0          ['conv4_block3_concat[0][0]',
#  te)                                                              'conv4_block4_2_conv[0][0]']
#
#  conv4_block5_0_bn (BatchNormal  (None, 14, 14, 384)  1536       ['conv4_block4_concat[0][0]']
#  ization)
#
#  conv4_block5_0_relu (Activatio  (None, 14, 14, 384)  0          ['conv4_block5_0_bn[0][0]']
#  n)
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 128)  49152       ['conv4_block5_0_relu[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_concat (Concatena  (None, 14, 14, 416)  0          ['conv4_block4_concat[0][0]',
#  te)                                                              'conv4_block5_2_conv[0][0]']
#
#  conv4_block6_0_bn (BatchNormal  (None, 14, 14, 416)  1664       ['conv4_block5_concat[0][0]']
#  ization)
#
#  conv4_block6_0_relu (Activatio  (None, 14, 14, 416)  0          ['conv4_block6_0_bn[0][0]']
#  n)
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 128)  53248       ['conv4_block6_0_relu[0][0]']
#
# ...
#  ate)                                                             'conv5_block24_2_conv[0][0]']
#
#  conv5_block25_0_bn (BatchNorma  (None, 7, 7, 1664)  6656        ['conv5_block24_concat[0][0]']
#  lization)
#
#  conv5_block25_0_relu (Activati  (None, 7, 7, 1664)  0           ['conv5_block25_0_bn[0][0]']
#  on)
#
#  conv5_block25_1_conv (Conv2D)  (None, 7, 7, 128)    212992      ['conv5_block25_0_relu[0][0]']
#
#  conv5_block25_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block25_1_conv[0][0]']
#  lization)
#
#  conv5_block25_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block25_1_bn[0][0]']
#  on)
#
#  conv5_block25_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block25_1_relu[0][0]']
#
#  conv5_block25_concat (Concaten  (None, 7, 7, 1696)  0           ['conv5_block24_concat[0][0]',
#  ate)                                                             'conv5_block25_2_conv[0][0]']
#
#  conv5_block26_0_bn (BatchNorma  (None, 7, 7, 1696)  6784        ['conv5_block25_concat[0][0]']
#  lization)
#
#  conv5_block26_0_relu (Activati  (None, 7, 7, 1696)  0           ['conv5_block26_0_bn[0][0]']
#  on)
#
#  conv5_block26_1_conv (Conv2D)  (None, 7, 7, 128)    217088      ['conv5_block26_0_relu[0][0]']
#
#  conv5_block26_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block26_1_conv[0][0]']
#  lization)
#
#  conv5_block26_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block26_1_bn[0][0]']
#  on)
#
#  conv5_block26_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block26_1_relu[0][0]']
#
#  conv5_block26_concat (Concaten  (None, 7, 7, 1728)  0           ['conv5_block25_concat[0][0]',
#  ate)                                                             'conv5_block26_2_conv[0][0]']
#
#  conv5_block27_0_bn (BatchNorma  (None, 7, 7, 1728)  6912        ['conv5_block26_concat[0][0]']
#  lization)
#
#  conv5_block27_0_relu (Activati  (None, 7, 7, 1728)  0           ['conv5_block27_0_bn[0][0]']
#  on)
#
#  conv5_block27_1_conv (Conv2D)  (None, 7, 7, 128)    221184      ['conv5_block27_0_relu[0][0]']
#
#  conv5_block27_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block27_1_conv[0][0]']
#  lization)
#
#  conv5_block27_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block27_1_bn[0][0]']
#  on)
#
#  conv5_block27_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block27_1_relu[0][0]']
#
#  conv5_block27_concat (Concaten  (None, 7, 7, 1760)  0           ['conv5_block26_concat[0][0]',
#  ate)                                                             'conv5_block27_2_conv[0][0]']
#
#  conv5_block28_0_bn (BatchNorma  (None, 7, 7, 1760)  7040        ['conv5_block27_concat[0][0]']
#  lization)
#
#  conv5_block28_0_relu (Activati  (None, 7, 7, 1760)  0           ['conv5_block28_0_bn[0][0]']
#  on)
#
#  conv5_block28_1_conv (Conv2D)  (None, 7, 7, 128)    225280      ['conv5_block28_0_relu[0][0]']
#
#  conv5_block28_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block28_1_conv[0][0]']
#  lization)
#
#  conv5_block28_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block28_1_bn[0][0]']
#  on)
#
#  conv5_block28_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block28_1_relu[0][0]']
#
#  conv5_block28_concat (Concaten  (None, 7, 7, 1792)  0           ['conv5_block27_concat[0][0]',
#  ate)                                                             'conv5_block28_2_conv[0][0]']
#
#  conv5_block29_0_bn (BatchNorma  (None, 7, 7, 1792)  7168        ['conv5_block28_concat[0][0]']
#  lization)
#
#  conv5_block29_0_relu (Activati  (None, 7, 7, 1792)  0           ['conv5_block29_0_bn[0][0]']
#  on)
#
#  conv5_block29_1_conv (Conv2D)  (None, 7, 7, 128)    229376      ['conv5_block29_0_relu[0][0]']
#
#  conv5_block29_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block29_1_conv[0][0]']
#  lization)
#
#  conv5_block29_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block29_1_bn[0][0]']
#  on)
#
#  conv5_block29_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block29_1_relu[0][0]']
#
#  conv5_block29_concat (Concaten  (None, 7, 7, 1824)  0           ['conv5_block28_concat[0][0]',
#  ate)                                                             'conv5_block29_2_conv[0][0]']
#
#  conv5_block30_0_bn (BatchNorma  (None, 7, 7, 1824)  7296        ['conv5_block29_concat[0][0]']
#  lization)
#
#  conv5_block30_0_relu (Activati  (None, 7, 7, 1824)  0           ['conv5_block30_0_bn[0][0]']
#  on)
#
#  conv5_block30_1_conv (Conv2D)  (None, 7, 7, 128)    233472      ['conv5_block30_0_relu[0][0]']
#
#  conv5_block30_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block30_1_conv[0][0]']
#  lization)
#
#  conv5_block30_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block30_1_bn[0][0]']
#  on)
#
#  conv5_block30_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block30_1_relu[0][0]']
#
#  conv5_block30_concat (Concaten  (None, 7, 7, 1856)  0           ['conv5_block29_concat[0][0]',
#  ate)                                                             'conv5_block30_2_conv[0][0]']
#
#  conv5_block31_0_bn (BatchNorma  (None, 7, 7, 1856)  7424        ['conv5_block30_concat[0][0]']
#  lization)
#
#  conv5_block31_0_relu (Activati  (None, 7, 7, 1856)  0           ['conv5_block31_0_bn[0][0]']
#  on)
#
#  conv5_block31_1_conv (Conv2D)  (None, 7, 7, 128)    237568      ['conv5_block31_0_relu[0][0]']
#
#  conv5_block31_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block31_1_conv[0][0]']
#  lization)
#
#  conv5_block31_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block31_1_bn[0][0]']
#  on)
#
#  conv5_block31_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block31_1_relu[0][0]']
#
#  conv5_block31_concat (Concaten  (None, 7, 7, 1888)  0           ['conv5_block30_concat[0][0]',
#  ate)                                                             'conv5_block31_2_conv[0][0]']
#
#  conv5_block32_0_bn (BatchNorma  (None, 7, 7, 1888)  7552        ['conv5_block31_concat[0][0]']
#  lization)
#
#  conv5_block32_0_relu (Activati  (None, 7, 7, 1888)  0           ['conv5_block32_0_bn[0][0]']
#  on)
#
#  conv5_block32_1_conv (Conv2D)  (None, 7, 7, 128)    241664      ['conv5_block32_0_relu[0][0]']
#
#  conv5_block32_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block32_1_conv[0][0]']
#  lization)
#
#  conv5_block32_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block32_1_bn[0][0]']
#  on)
#
#  conv5_block32_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block32_1_relu[0][0]']
#
#  conv5_block32_concat (Concaten  (None, 7, 7, 1920)  0           ['conv5_block31_concat[0][0]',
#  ate)                                                             'conv5_block32_2_conv[0][0]']
#
#  bn (BatchNormalization)        (None, 7, 7, 1920)   7680        ['conv5_block32_concat[0][0]']
#
#  relu (Activation)              (None, 7, 7, 1920)   0           ['bn[0][0]']
#
# ==================================================================================================
# Total params: 18,321,984
# Trainable params: 18,092,928
# Non-trainable params: 229,056
# __________________________________________________________________________________________________

# %%
#Modelimizi derlemek
densenet_model.compile(loss='binary_crossentropy',optimizer='rmsprop',metrics=['accuracy'])


#Ağımızın özeti gösteriliyor
densenet_model.summary()

from tensorflow.keras.utils import plot_model
#plot_model(model, to_file='model1.png')
plot_model(densenet_model, to_file="/content/drive/MyDrive/tez/saveimage/densenet_model.png")
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet201 (Functional)    (None, 7, 7, 1920)        18321984
#
#  global_average_pooling2d_10  (None, 1920)             0
#   (GlobalAveragePooling2D)
#
#  dense_23 (Dense)            (None, 512)               983552
#
#  batch_normalization_16 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dropout_16 (Dropout)        (None, 512)               0
#
#  dense_24 (Dense)            (None, 128)               65664
#
#  batch_normalization_17 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_17 (Dropout)        (None, 128)               0
#
#  dense_25 (Dense)            (None, 64)                8256
#
#  batch_normalization_18 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_18 (Dropout)        (None, 64)                0
#
#  dense_26 (Dense)            (None, 2)                 130
#
# =================================================================
# Total params: 19,382,402
# Trainable params: 19,151,938
# Non-trainable params: 230,464
# _________________________________________________________________

# %%
# Create DenseNet201 Model with Keras library

def build_model(backbone, lr=1e-4):
    densenet_model = Sequential()
    densenet_model.add(backbone)
    densenet_model.add(layers.GlobalAveragePooling2D())
    densenet_model.add(layers.Dropout(0.5))
    densenet_model.add(layers.BatchNormalization())
    densenet_model.add(layers.Dense(2, activation='sigmoid'))
    
    densenet_model.compile(
        loss='binary_crossentropy',
        optimizer=Adam(lr=lr),
        metrics=['acc']
    )
    return densenet_model

densenet_model = DenseNet201(
    weights='imagenet',
    include_top=False,
    input_shape=(150,150,3)
)

densenet_model = build_model(densenet_model ,lr = 1e-4)


densenet_model.summary()

from tensorflow.keras.utils import plot_model
#plot_model(model, to_file='model1.png')
plot_model(densenet_model, to_file="/content/drive/MyDrive/tez/saveimage/modelvgg16.png")

# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from google.colab import drive
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPClassifier
from google.colab import drive
import matplotlib
import os
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
from keras.optimizers import Adam
import numpy as np
from numpy import argmax
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import scipy.misc
from keras.layers import Concatenate, Dense, LSTM, Input, concatenate
from keras import backend as K
from skimage.transform import resize
import os
from keras.models import load_model
from keras.utils import np_utils
import joblib
from keras.layers import Flatten
from keras.models import Model
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import pandas as pd
from  sklearn.ensemble import GradientBoostingClassifier
#from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
from xgboost import XGBClassifier
from sklearn import svm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.neural_network import MLPClassifier
from keras.models import Model
from keras.layers import Input,Reshape
from keras.layers import Dense, Conv2D, Flatten
from keras.layers import Input, LSTM, Bidirectional, Conv1D
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Embedding
from keras.models import Sequential
from keras.utils import to_categorical
from keras.layers import Flatten
from keras.models import Model
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from keras.layers import Input, LSTM, Dense,Bidirectional 
from keras.models import Model
from sklearn.metrics import  confusion_matrix,classification_report
import pickle
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_classif

def isCheck_Klasor(path):    
    if not os.path.isdir(path):
        os.mkdir( path, 755 );


def plot_ciz_acc_loss(history,fold_index,etiket):
    
    # list all data in history
    print(history.history.keys())
    # summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
   # plt.savefig(anaKlasor+"/acc_loss_graphs/"+etiket+"resnet_acc_fold_value="+str(fold_index)+".png")
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.savefig(anaKlasor+"/acc_loss_graphs/"+etiket+"_loss_fold_value="+str(fold_index)+".png")
    plt.show()



def cm_analysis(y_train, y_pred, labels, ymap=None, figsize=(10,10)):
    
    """
    Generate matrix plot of confusion matrix with pretty annotations.
    The plot image is saved to disk.
    args: 
      y_true:    true label of the data, with shape (nsamples,)
      y_pred:    prediction of the data, with shape (nsamples,)
      filename:  filename of figure file to save
      labels:    string array, name the order of class labels in the confusion matrix.
                 use `clf.classes_` if using scikit-learn models.
                 with shape (nclass,).
      ymap:      dict: any -> string, length == nclass.
                 if not None, map the labels & ys to more understandable strings.
                 Caution: original y_true, y_pred and labels must align.
      figsize:   the size of the figure plotted.
    """
    labels=[0,1]
    if ymap is not None:
        y_pred = [ymap[yi] for yi in y_pred]
        y_train = [ymap[yi] for yi in y_train]
        labels = [ymap[yi] for yi in labels]
        
    cm = confusion_matrix(y_train, y_pred, labels=labels)
    cm_sum = np.sum(cm, axis=1, keepdims=True)
    cm_perc = cm / cm_sum.astype(float) * 100
    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            c = cm[i, j]
            p = cm_perc[i, j]
            if i == j:
                s = cm_sum[i]
                annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
            elif c == 0:
                annot[i, j] = ''
            else:
                annot[i, j] = '%.1f%%\n%d' % (p, c)
    cm = pd.DataFrame(cm, index=labels, columns=labels)
    cm.index.name = 'Actual'
    cm.columns.name = 'Predicted'
    fig, ax = plt.subplots(figsize=figsize)
    sns.heatmap(cm, annot=annot, fmt='', ax=ax)
    #plt.savefig(filename)
    plt.show()


anaKlasor =  "/content/drive/MyDrive/tez/"
path=anaKlasor+"/features/"

X=np.load(path+"/X.npy")
y=np.load(path+"/y.npy")
X_train, X_test, Y_train, Y_test = train_test_split(X, y, stratify=y, test_size=0.20, random_state=42)
Y_train=to_categorical(Y_train)



Cannels = 3
EPOCHS =100
BATCH_SIZE = 16

densenet_model = DenseNet201(
    weights='imagenet',
    include_top=False,
    input_shape=(150,150,3)
)


densenet_model.compile(loss='binary_crossentropy',optimizer='rmsprop',metrics=['accuracy'])
etiket="densenet201"
Y_test_preds=densenet_model.predict(X_test)
print (etiket," MODELİN SONUÇLARI :",Y_test_preds)


#eğitimi başlat
history = densenet_model.fit( X_train, Y_train,  validation_split=0.2,epochs = EPOCHS,verbose=1)

#GRAFİK ÇİZİLSİN
plot_ciz_acc_loss(history,"Hold-out",etiket)

y_preds=np.argmax(Y_test_preds,axis=1)
acc=round(accuracy_score(Y_test, y_preds),3)
print ("Acc "+etiket+"-"+etiket+ " score:",acc*100)
cm_analysis(Y_test, y_preds, targets, figsize=(5,5))



densenet_model.save('../content/drive/MyDrive/tez/models/model_'+etiket+'.h5')


targets=np.load("../content/drive/MyDrive/tez/features/targets.npy")
print (targets)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-5a6fb28221df> in <module>
#     172 densenet_model.compile(loss='binary_crossentropy',optimizer='rmsprop',metrics=['accuracy'])
#     173 etiket="densenet201"
# --> 174 Y_test_preds=densenet_model.predict(X_test)
#     175 print (etiket," MODELİN SONUÇLARI :",Y_test_preds)
#     176
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/training.py in tf__predict_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# ValueError: in user code:
#
#     File "/usr/local/lib/python3.8/dist-packages/keras/engine/training.py", line 2137, in predict_function  *
#         return step_function(self, iterator)
#     File "/usr/local/lib/python3.8/dist-packages/keras/engine/training.py", line 2123, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/usr/local/lib/python3.8/dist-packages/keras/engine/training.py", line 2111, in run_step  **
#         outputs = model.predict_step(data)
#     File "/usr/local/lib/python3.8/dist-packages/keras/engine/training.py", line 2079, in predict_step
#         return self(x, training=False)
#     File "/usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/usr/local/lib/python3.8/dist-packages/keras/engine/input_spec.py", line 295, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "densenet201" is incompatible with the layer: expected shape=(None, 150, 150, 3), found shape=(None, 224, 224, 3)

# %%
# EKLENDİ 
print("training_accuracy", history.history['accuracy'][-1])
print("validation_accuracy", history.history['val_accuracy'][-1])

# %%
# EKLENDİİ 
plt.figure(1, figsize = (15, 5))
plt.subplot(1,2,1)
plt.title(" Veriseti 1, DENSENET201 Modeli Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.plot( history.history["loss"], label = "Training Loss")
plt.plot( history.history["val_loss"], label = "Validation Loss")
plt.grid(True)
plt.legend()

plt.subplot(1,2,2)
plt.title(" Veriseti 1, DENSENET201 Modeli Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.plot( history.history["accuracy"], label = "Training Accuracy")
plt.plot( history.history["val_accuracy"], label = "Validation Accuracy")
plt.grid(True)
plt.legend()
plt.show()

# %%
#EKLENDİ 


#classification report on train
predIdxs = densenet_model.predict (X_train, batch_size=64)
predIdxs = np.argmax(predIdxs, axis=1)
print(classification_report(Y_train.argmax(axis=1), predIdxs, target_names=le.classes_, digits=3))

# %%
#heatmap
df_cm=pd.DataFrame(confusionmatrix, columns=le.classes_, index=le.classes_)
df_cm.index.name='Actual'
df_cm.columns.name='Predicted'
plt.figure(figsize=(5,5))
sns.heatmap(df_cm/np.sum(df_cm), fmt='.2%', annot=True, annot_kws={'size':16})
plt.savefig("/content/drive/MyDrive/tez/saveimage/DENSENET201confusionmatrix.png")
plt.show()

# %%
print(X_train.shape, Y_train.shape)
print( X_test.shape, Y_test.shape)

# %%
print(X_train.shape, X_test.shape, Y_train.shape, Y_test.shape)

# %% [markdown]
# # VGG19

# %%
from keras.layers import Dense, Conv2D, MaxPooling2D, AvgPool2D, Input, Dropout, Flatten, BatchNormalization
from keras.models import Sequential, Model
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.vgg19 import VGG19

# %%
#    vgg19_model
import tensorflow as tf
from keras.models import Sequential
from keras.layers import GlobalAveragePooling2D
from keras.applications.vgg19 import VGG19
vgg19_base_model = VGG19(input_shape=INPUT_SHAPE,include_top=False,weights='imagenet')

vgg19_base_model.summary()
vgg19_model = tf.keras.Sequential([
        vgg19_base_model,
        GlobalAveragePooling2D(),
        Dense(512, activation="relu"),
        BatchNormalization(),
        Dropout(0.6),
        Dense(128, activation="relu"),
        BatchNormalization(),
        Dropout(0.4),
        Dense(64,activation="relu"),
        BatchNormalization(),
        Dropout(0.3),
        Dense(2,activation="softmax")
    ])
# Out:
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_25 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 20,024,384
# Trainable params: 20,024,384
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Modelimizi derlemek
vgg19_model.compile(loss='binary_crossentropy',optimizer='rmsprop',metrics=['accuracy'])


#Ağımızın özeti gösteriliyor
vgg19_model.summary()

from tensorflow.keras.utils import plot_model

#plot_model(model, to_file='model1.png')
plot_model(vgg19_model, to_file="/content/drive/MyDrive/tez/saveimage/modelvgg19.png")
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg19 (Functional)          (None, 7, 7, 512)         20024384
#
#  global_average_pooling2d_11  (None, 512)              0
#   (GlobalAveragePooling2D)
#
#  dense_32 (Dense)            (None, 512)               262656
#
#  batch_normalization_19 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dropout_19 (Dropout)        (None, 512)               0
#
#  dense_33 (Dense)            (None, 128)               65664
#
#  batch_normalization_20 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_20 (Dropout)        (None, 128)               0
#
#  dense_34 (Dense)            (None, 64)                8256
#
#  batch_normalization_21 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_21 (Dropout)        (None, 64)                0
#
#  dense_35 (Dense)            (None, 2)                 130
#
# =================================================================
# Total params: 20,363,906
# Trainable params: 20,362,498
# Non-trainable params: 1,408
# _________________________________________________________________

# %%
#PLOT 
def plot_ciz_acc_loss(history,fold_index,etiket):
    
    # list all data in history
    print(history.history.keys())
    # summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.savefig(anaKlasor+"/acc_loss_graphs/"+etiket+"_acc_fold_value="+str(fold_index)+".png")
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.savefig(anaKlasor+"/acc_loss_graphs/"+etiket+"_loss_fold_value="+str(fold_index)+".png")
    plt.show()


#Confusion matrix
def cm_analysis(y_train, y_pred, labels, ymap=None, figsize=(10,10)):
    
    """
    Generate matrix plot of confusion matrix with pretty annotations.
    The plot image is saved to disk.
    args: 
      y_true:    true label of the data, with shape (nsamples,)
      y_pred:    prediction of the data, with shape (nsamples,)
      filename:  filename of figure file to save
      labels:    string array, name the order of class labels in the confusion matrix.
                 use `clf.classes_` if using scikit-learn models.
                 with shape (nclass,).
      ymap:      dict: any -> string, length == nclass.
                 if not None, map the labels & ys to more understandable strings.
                 Caution: original y_true, y_pred and labels must align.
      figsize:   the size of the figure plotted.
    """
    labels=[0,1]
    if ymap is not None:
        y_pred = [ymap[yi] for yi in y_pred]
        y_train = [ymap[yi] for yi in y_train]
        labels= [ymap[yi] for yi in labels]
        
    cm = confusion_matrix(y_train, y_preds, labels=labels)
    cm_sum = np.sum(cm, axis=1, keepdims=True)
    cm_perc = cm / cm_sum.astype(float) * 100
    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            c = cm[i, j]
            p = cm_perc[i, j]
            if i == j:
                s = cm_sum[i]
                annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
            elif c == 0:
                annot[i, j] = ''
            else:
                annot[i, j] = '%.1f%%\n%d' % (p, c)
    cm = pd.DataFrame(cm, index=labels, columns=labels)
    cm.index.name = 'Actual'
    cm.columns.name = 'Predicted'
    fig, ax = plt.subplots(figsize=figsize)
    sns.heatmap(cm, annot=annot, fmt='', ax=ax)
    #plt.savefig(filename)
    plt.show()

# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from google.colab import drive
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPClassifier
from google.colab import drive
import matplotlib
import os
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
from keras.optimizers import Adam
import numpy as np
from numpy import argmax
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import scipy.misc
from keras.layers import Concatenate, Dense, LSTM, Input, concatenate
from keras import backend as K
from skimage.transform import resize
import os
from keras.models import load_model
from keras.utils import np_utils
import joblib
from keras.layers import Flatten
from keras.models import Model
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import pandas as pd
from  sklearn.ensemble import GradientBoostingClassifier
#from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
from xgboost import XGBClassifier
from sklearn import svm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.neural_network import MLPClassifier
from keras.models import Model
from keras.layers import Input,Reshape
from keras.layers import Dense, Conv2D, Flatten
from keras.layers import Input, LSTM, Bidirectional, Conv1D
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Embedding
from keras.models import Sequential
from keras.utils import to_categorical
from keras.layers import Flatten
from keras.models import Model
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from keras.layers import Input, LSTM, Dense,Bidirectional 
from keras.models import Model
from sklearn.metrics import  confusion_matrix,classification_report
import pickle
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_classif

def isCheck_Klasor(path):    
    if not os.path.isdir(path):
        os.mkdir( path, 755 );

Image_Width = 224
Image_Height = 224
Cannels = 3

INPUT_SHAPE = (Image_Width, Image_Height, Cannels)
NB_CLASSES = 2
EPOCHS =100
BATCH_SIZE =16


anaKlasor =  "/content/drive/MyDrive/tez/"
path=anaKlasor+"/features/"

X=np.load(path+"/X.npy")
y=np.load(path+"/y.npy")
X_train, X_test, Y_train, Y_test = train_test_split(X, y, stratify=y, test_size=0.20, random_state=42)
Y_train=to_categorical(Y_train)



vgg19_model.compile(loss='binary_crossentropy',optimizer='rmsprop',metrics=['accuracy'])
etiket="VGG19"
Y_test_preds=vgg19_model.predict(X_test)   #tahmin
print (etiket," MODELİN SONUÇLARI:",Y_test_preds)


#eğitimi başlat
history = vgg19_model.fit( X_train, Y_train,  validation_split=0.2,epochs = EPOCHS,verbose=1)

# GRAFİK ÇİZİLSİN
plot_ciz_acc_loss(history,"Hold-out",etiket)



y_preds=np.argmax(Y_test_preds,axis=1)
acc=round(accuracy_score(Y_test, y_preds),3)
print ("Acc "+etiket+"-"+etiket+ " score:",acc*100)

#KARIŞIKLIK MATRİSİ
cm_analysis(Y_test, y_preds, targets, figsize=(5,5))


vgg19_model.save('../content/drive/MyDrive/tez/models/model_'+etiket+'.h5')

targets=np.load("../content/drive/MyDrive/tez/features/targets.npy")
print (targets)
# Out:
# 16/16 [==============================] - 2s 135ms/step
# VGG19  MODELİN SONUÇLARI: [[1.00000000e+00 8.81577644e-10]
#  [1.00000000e+00 2.89946181e-16]
#  [1.00000000e+00 9.98295557e-10]
#  [1.00000000e+00 1.04970066e-09]
#  [1.00000000e+00 4.76972524e-18]
#  [1.00000000e+00 1.09892551e-09]
#  [1.00000000e+00 1.32160560e-10]
#  [1.00000000e+00 1.31818173e-14]
#  [1.00000000e+00 4.42070236e-13]
#  [1.00000000e+00 1.18752096e-14]
#  [1.00000000e+00 6.73771705e-10]
#  [1.00000000e+00 4.13778576e-14]
#  [1.00000000e+00 1.08778120e-09]
#  [1.00000000e+00 3.52613040e-14]
#  [1.00000000e+00 1.25363431e-09]
#  [1.00000000e+00 5.66788616e-10]
# 50/50 [==============================] - 26s 514ms/step - loss: 0.0214 - accuracy: 0.9962 - val_loss: 3.7631 - val_accuracy: 0.5214
# Epoch 4/100
# 50/50 [==============================] - 26s 524ms/step - loss: 0.0497 - accuracy: 0.9868 - val_loss: 0.2272 - val_accuracy: 0.9395
# Epoch 5/100
# 50/50 [==============================] - 25s 500ms/step - loss: 0.0299 - accuracy: 0.9893 - val_loss: 2.9495 - val_accuracy: 0.5466
# Epoch 6/100
# 50/50 [==============================] - 25s 498ms/step - loss: 0.0214 - accuracy: 0.9943 - val_loss: 0.2857 - val_accuracy: 0.9244
# Epoch 7/100
# 50/50 [==============================] - 26s 517ms/step - loss: 0.0404 - accuracy: 0.9912 - val_loss: 0.9484 - val_accuracy: 0.8186
# Epoch 8/100
# 50/50 [==============================] - 26s 518ms/step - loss: 0.0633 - accuracy: 0.9798 - val_loss: 0.3069 - val_accuracy: 0.9270
# Epoch 9/100
# 50/50 [==============================] - 25s 508ms/step - loss: 0.0220 - accuracy: 0.9924 - val_loss: 4.2618 - val_accuracy: 0.5189
# Epoch 10/100
# 50/50 [==============================] - 26s 516ms/step - loss: 0.0323 - accuracy: 0.9880 - val_loss: 1.3414 - val_accuracy: 0.7355
# Epoch 11/100
# 50/50 [==============================] - 25s 498ms/step - loss: 0.0124 - accuracy: 0.9968 - val_loss: 0.6091 - val_accuracy: 0.8615
# Epoch 12/100
# 50/50 [==============================] - 26s 516ms/step - loss: 0.0282 - accuracy: 0.9874 - val_loss: 2.2056 - val_accuracy: 0.6348
# Epoch 13/100
# 50/50 [==============================] - 26s 516ms/step - loss: 0.0205 - accuracy: 0.9937 - val_loss: 0.5136 - val_accuracy: 0.8992
# Epoch 14/100
# 50/50 [==============================] - 26s 516ms/step - loss: 0.0633 - accuracy: 0.9868 - val_loss: 1.3695 - val_accuracy: 0.7557
# Epoch 15/100
# 50/50 [==============================] - 26s 516ms/step - loss: 0.0245 - accuracy: 0.9918 - val_loss: 1.9565 - val_accuracy: 0.7028
# Epoch 16/100
# 50/50 [==============================] - 26s 515ms/step - loss: 0.0504 - accuracy: 0.9836 - val_loss: 0.4364 - val_accuracy: 0.8992
# Epoch 17/100
# 50/50 [==============================] - 26s 517ms/step - loss: 0.0186 - accuracy: 0.9956 - val_loss: 1.5724 - val_accuracy: 0.7330
# Epoch 18/100
# 50/50 [==============================] - 26s 515ms/step - loss: 0.0285 - accuracy: 0.9874 - val_loss: 4.5906 - val_accuracy: 0.5189
# Epoch 19/100
# 50/50 [==============================] - 25s 500ms/step - loss: 0.0503 - accuracy: 0.9899 - val_loss: 0.4684 - val_accuracy: 0.9093
# Epoch 20/100
# 50/50 [==============================] - 25s 500ms/step - loss: 0.0454 - accuracy: 0.9874 - val_loss: 5.9079 - val_accuracy: 0.5189
# Epoch 21/100
# 50/50 [==============================] - 26s 516ms/step - loss: 0.0405 - accuracy: 0.9880 - val_loss: 5.1128 - val_accuracy: 0.5189
# Epoch 22/100
# 50/50 [==============================] - 25s 500ms/step - loss: 0.0282 - accuracy: 0.9905 - val_loss: 2.4406 - val_accuracy: 0.6247
# Epoch 23/100
# 50/50 [==============================] - 25s 500ms/step - loss: 0.0181 - accuracy: 0.9956 - val_loss: 1.5315 - val_accuracy: 0.7330
# Epoch 24/100
# 50/50 [==============================] - 26s 516ms/step - loss: 0.0426 - accuracy: 0.9855 - val_loss: 2.6662 - val_accuracy: 0.5819
# Epoch 25/100
# 50/50 [==============================] - 26s 516ms/step - loss: 0.0348 - accuracy: 0.9899 - val_loss: 0.4526 - val_accuracy: 0.9194
# Epoch 26/100
# 50/50 [==============================] - 26s 514ms/step - loss: 0.0217 - accuracy: 0.9931 - val_loss: 0.3579 - val_accuracy: 0.9118
# Epoch 27/100
# 50/50 [==============================] - 25s 499ms/step - loss: 0.0579 - accuracy: 0.9836 - val_loss: 1.4037 - val_accuracy: 0.7179
# Epoch 28/100
# 50/50 [==============================] - 25s 499ms/step - loss: 0.0153 - accuracy: 0.9956 - val_loss: 0.5927 - val_accuracy: 0.8816
# Epoch 29/100
# 50/50 [==============================] - 25s 499ms/step - loss: 0.0380 - accuracy: 0.9893 - val_loss: 5.2615 - val_accuracy: 0.4912
# Epoch 30/100
# 50/50 [==============================] - 25s 499ms/step - loss: 0.0237 - accuracy: 0.9937 - val_loss: 3.2818 - val_accuracy: 0.5718
# Epoch 31/100
# 50/50 [==============================] - 26s 515ms/step - loss: 0.0528 - accuracy: 0.9874 - val_loss: 0.3385 - val_accuracy: 0.9219
# Epoch 32/100
# 50/50 [==============================] - 26s 515ms/step - loss: 0.0165 - accuracy: 0.9943 - val_loss: 0.6806 - val_accuracy: 0.8161
# Epoch 33/100
# 50/50 [==============================] - 25s 497ms/step - loss: 0.0245 - accuracy: 0.9937 - val_loss: 3.0121 - val_accuracy: 0.5617
# Epoch 34/100
# 50/50 [==============================] - 26s 516ms/step - loss: 0.0416 - accuracy: 0.9874 - val_loss: 0.3157 - val_accuracy: 0.9244
# Epoch 35/100
# 50/50 [==============================] - 26s 515ms/step - loss: 0.0221 - accuracy: 0.9950 - val_loss: 1.5103 - val_accuracy: 0.7028
# Epoch 36/100
# 50/50 [==============================] - 26s 514ms/step - loss: 0.0239 - accuracy: 0.9943 - val_loss: 2.1883 - val_accuracy: 0.6650
# Epoch 37/100
# 50/50 [==============================] - 25s 498ms/step - loss: 0.0219 - accuracy: 0.9924 - val_loss: 0.4054 - val_accuracy: 0.9144
# Epoch 38/100
# 50/50 [==============================] - 25s 499ms/step - loss: 0.0464 - accuracy: 0.9849 - val_loss: 0.5108 - val_accuracy: 0.8967
# Epoch 39/100
# 50/50 [==============================] - 26s 516ms/step - loss: 0.0258 - accuracy: 0.9905 - val_loss: 3.8280 - val_accuracy: 0.5466
# Epoch 40/100
# 50/50 [==============================] - 25s 497ms/step - loss: 0.0328 - accuracy: 0.9899 - val_loss: 0.5103 - val_accuracy: 0.8665
# Epoch 41/100
# 50/50 [==============================] - 25s 500ms/step - loss: 0.0546 - accuracy: 0.9855 - val_loss: 6.5237 - val_accuracy: 0.5189
# Epoch 42/100
# 50/50 [==============================] - 25s 498ms/step - loss: 0.0252 - accuracy: 0.9905 - val_loss: 7.1104 - val_accuracy: 0.4811
# Epoch 43/100
# 50/50 [==============================] - 26s 515ms/step - loss: 0.0213 - accuracy: 0.9956 - val_loss: 1.1599 - val_accuracy: 0.7935
# Epoch 44/100
# 50/50 [==============================] - 26s 516ms/step - loss: 0.0339 - accuracy: 0.9912 - val_loss: 2.9328 - val_accuracy: 0.6574
# Epoch 45/100
# 50/50 [==============================] - 25s 499ms/step - loss: 0.0398 - accuracy: 0.9893 - val_loss: 0.2808 - val_accuracy: 0.9370
# Epoch 46/100
# 50/50 [==============================] - 25s 499ms/step - loss: 0.0071 - accuracy: 0.9981 - val_loss: 0.2729 - val_accuracy: 0.9446
# Epoch 47/100
# 50/50 [==============================] - 25s 497ms/step - loss: 0.0413 - accuracy: 0.9880 - val_loss: 6.7469 - val_accuracy: 0.5189
# Epoch 48/100
# 50/50 [==============================] - 26s 515ms/step - loss: 0.0062 - accuracy: 0.9994 - val_loss: 3.6044 - val_accuracy: 0.5668
# Epoch 49/100
# 50/50 [==============================] - 25s 498ms/step - loss: 0.0290 - accuracy: 0.9905 - val_loss: 0.7422 - val_accuracy: 0.8615
# Epoch 50/100
# 50/50 [==============================] - 26s 516ms/step - loss: 0.0286 - accuracy: 0.9893 - val_loss: 3.5702 - val_accuracy: 0.5516
# Epoch 51/100
# 50/50 [==============================] - 26s 514ms/step - loss: 0.0424 - accuracy: 0.9899 - val_loss: 0.4992 - val_accuracy: 0.8866
# Epoch 52/100
# 50/50 [==============================] - 25s 499ms/step - loss: 0.0552 - accuracy: 0.9887 - val_loss: 4.2760 - val_accuracy: 0.5214
# Epoch 53/100
# 50/50 [==============================] - 25s 498ms/step - loss: 0.0198 - accuracy: 0.9943 - val_loss: 0.8757 - val_accuracy: 0.8262
# Epoch 54/100
# 50/50 [==============================] - 25s 497ms/step - loss: 0.0403 - accuracy: 0.9912 - val_loss: 3.7331 - val_accuracy: 0.5441
# Epoch 55/100
# 50/50 [==============================] - 26s 515ms/step - loss: 0.0377 - accuracy: 0.9912 - val_loss: 3.0412 - val_accuracy: 0.5668
# Epoch 56/100
# 50/50 [==============================] - 25s 498ms/step - loss: 0.0167 - accuracy: 0.9962 - val_loss: 0.6792 - val_accuracy: 0.8715
# Epoch 57/100
# 50/50 [==============================] - 26s 515ms/step - loss: 0.0211 - accuracy: 0.9918 - val_loss: 2.6175 - val_accuracy: 0.6272
# Epoch 58/100
# 50/50 [==============================] - 26s 514ms/step - loss: 0.0256 - accuracy: 0.9943 - val_loss: 6.1989 - val_accuracy: 0.5189
# Epoch 59/100
# 50/50 [==============================] - 26s 516ms/step - loss: 0.0134 - accuracy: 0.9950 - val_loss: 1.5945 - val_accuracy: 0.7531
# Epoch 60/100
# 50/50 [==============================] - 25s 499ms/step - loss: 0.0848 - accuracy: 0.9798 - val_loss: 5.9348 - val_accuracy: 0.5189
# Epoch 61/100
# 50/50 [==============================] - 26s 514ms/step - loss: 0.0519 - accuracy: 0.9842 - val_loss: 0.3107 - val_accuracy: 0.9270
# Epoch 62/100
# 50/50 [==============================] - 25s 498ms/step - loss: 0.0220 - accuracy: 0.9931 - val_loss: 0.9396 - val_accuracy: 0.8136
# Epoch 63/100
# 50/50 [==============================] - 25s 498ms/step - loss: 0.0232 - accuracy: 0.9924 - val_loss: 0.3361 - val_accuracy: 0.9169
# Epoch 64/100
# 50/50 [==============================] - 26s 516ms/step - loss: 0.0410 - accuracy: 0.9861 - val_loss: 7.6832 - val_accuracy: 0.4836
# Epoch 65/100
# 50/50 [==============================] - 26s 515ms/step - loss: 0.0058 - accuracy: 0.9981 - val_loss: 0.5122 - val_accuracy: 0.8917
# Epoch 66/100
# 50/50 [==============================] - 26s 514ms/step - loss: 0.0326 - accuracy: 0.9924 - val_loss: 0.3459 - val_accuracy: 0.9345
# Epoch 67/100
# 50/50 [==============================] - 25s 499ms/step - loss: 0.0064 - accuracy: 0.9987 - val_loss: 0.3184 - val_accuracy: 0.9370
# Epoch 68/100
# 50/50 [==============================] - 25s 500ms/step - loss: 0.0117 - accuracy: 0.9962 - val_loss: 2.4457 - val_accuracy: 0.6927
# Epoch 69/100
# 50/50 [==============================] - 26s 516ms/step - loss: 0.0413 - accuracy: 0.9918 - val_loss: 0.6717 - val_accuracy: 0.8615
# Epoch 70/100
# 50/50 [==============================] - 26s 514ms/step - loss: 0.0371 - accuracy: 0.9887 - val_loss: 3.2384 - val_accuracy: 0.5617
# Epoch 71/100
# 50/50 [==============================] - 25s 499ms/step - loss: 0.0285 - accuracy: 0.9918 - val_loss: 13.8453 - val_accuracy: 0.4811
# Epoch 72/100
# 50/50 [==============================] - 25s 499ms/step - loss: 0.0201 - accuracy: 0.9924 - val_loss: 0.4008 - val_accuracy: 0.9018
# Epoch 73/100
# 50/50 [==============================] - 25s 499ms/step - loss: 0.0258 - accuracy: 0.9937 - val_loss: 1.4278 - val_accuracy: 0.7632
# Epoch 74/100
# 50/50 [==============================] - 26s 516ms/step - loss: 0.0167 - accuracy: 0.9962 - val_loss: 0.3009 - val_accuracy: 0.9496
# Epoch 75/100
# 50/50 [==============================] - 25s 500ms/step - loss: 0.0458 - accuracy: 0.9893 - val_loss: 2.5018 - val_accuracy: 0.6171
# Epoch 76/100
# 50/50 [==============================] - 26s 516ms/step - loss: 0.0112 - accuracy: 0.9975 - val_loss: 3.2489 - val_accuracy: 0.5718
# Epoch 77/100
# 50/50 [==============================] - 25s 499ms/step - loss: 0.0217 - accuracy: 0.9968 - val_loss: 1.3148 - val_accuracy: 0.7657
# Epoch 78/100
# 50/50 [==============================] - 25s 499ms/step - loss: 0.0090 - accuracy: 0.9968 - val_loss: 0.4191 - val_accuracy: 0.9068
# Epoch 79/100
# 50/50 [==============================] - 25s 500ms/step - loss: 0.0241 - accuracy: 0.9950 - val_loss: 2.4790 - val_accuracy: 0.6398
# Epoch 80/100
# 50/50 [==============================] - 25s 500ms/step - loss: 0.0501 - accuracy: 0.9918 - val_loss: 7.7466 - val_accuracy: 0.4836
# Epoch 81/100
# 50/50 [==============================] - 26s 516ms/step - loss: 0.0061 - accuracy: 0.9987 - val_loss: 0.4883 - val_accuracy: 0.9068
# Epoch 82/100
# 50/50 [==============================] - 25s 500ms/step - loss: 0.0492 - accuracy: 0.9880 - val_loss: 1.5052 - val_accuracy: 0.7431
# Epoch 83/100
# 50/50 [==============================] - 25s 500ms/step - loss: 0.0097 - accuracy: 0.9962 - val_loss: 20517864.0000 - val_accuracy: 0.7657
# Epoch 84/100
# 50/50 [==============================] - 25s 499ms/step - loss: 0.0281 - accuracy: 0.9950 - val_loss: 9.1131 - val_accuracy: 0.5189
# Epoch 85/100
# 50/50 [==============================] - 25s 500ms/step - loss: 0.0174 - accuracy: 0.9937 - val_loss: 2314963968.0000 - val_accuracy: 0.6272
# Epoch 86/100
# 50/50 [==============================] - 25s 500ms/step - loss: 0.0285 - accuracy: 0.9924 - val_loss: 4.2201 - val_accuracy: 0.5516
# Epoch 87/100
# 50/50 [==============================] - 25s 500ms/step - loss: 0.0280 - accuracy: 0.9943 - val_loss: 1.1504 - val_accuracy: 0.7884
# Epoch 88/100
# 50/50 [==============================] - 26s 516ms/step - loss: 0.0186 - accuracy: 0.9956 - val_loss: 0.2793 - val_accuracy: 0.9395
# Epoch 89/100
# 50/50 [==============================] - 25s 500ms/step - loss: 9.8566e-04 - accuracy: 1.0000 - val_loss: 0.6397 - val_accuracy: 0.8892
# Epoch 90/100
# 50/50 [==============================] - 25s 500ms/step - loss: 0.0452 - accuracy: 0.9937 - val_loss: 2.1115 - val_accuracy: 0.6877
# Epoch 91/100
# 50/50 [==============================] - 26s 516ms/step - loss: 0.0486 - accuracy: 0.9887 - val_loss: 0.8942 - val_accuracy: 0.8438
# Epoch 92/100
# 50/50 [==============================] - 25s 499ms/step - loss: 0.0348 - accuracy: 0.9899 - val_loss: 2.3624 - val_accuracy: 0.7003
# Epoch 93/100
# 50/50 [==============================] - 26s 516ms/step - loss: 0.0318 - accuracy: 0.9893 - val_loss: 0.6986 - val_accuracy: 0.8615
# Epoch 94/100
# 50/50 [==============================] - 26s 516ms/step - loss: 0.0110 - accuracy: 0.9975 - val_loss: 0.4670 - val_accuracy: 0.8992
# Epoch 95/100
# 50/50 [==============================] - 26s 515ms/step - loss: 0.0154 - accuracy: 0.9950 - val_loss: 0.7627 - val_accuracy: 0.8589
# Epoch 96/100
# 50/50 [==============================] - 26s 516ms/step - loss: 0.0514 - accuracy: 0.9905 - val_loss: 0.9396 - val_accuracy: 0.8388
# Epoch 97/100
# 50/50 [==============================] - 25s 500ms/step - loss: 0.0102 - accuracy: 0.9956 - val_loss: 2.2142 - val_accuracy: 0.7028
# Epoch 98/100
# 50/50 [==============================] - 26s 516ms/step - loss: 0.0114 - accuracy: 0.9968 - val_loss: 1.7416 - val_accuracy: 0.7506
# Epoch 99/100
# 50/50 [==============================] - 25s 499ms/step - loss: 0.0178 - accuracy: 0.9962 - val_loss: 1.4436 - val_accuracy: 0.7809
# Epoch 100/100
# 50/50 [==============================] - 25s 500ms/step - loss: 0.0060 - accuracy: 0.9975 - val_loss: 0.5634 - val_accuracy: 0.8942
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# Acc VGG19-VGG19 score: 50.5
# ['COVID' 'non-COVID']

# %%
# EKLENDİ 
print(" VGG19 training_accuracy", history.history['accuracy'][-1])
print(" VGG19 validation_accuracy", history.history['val_accuracy'][-1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1d4bcb3cb518> in <module>
#       1 # EKLENDİ
# ----> 2 print(" VGG19 training_accuracy", history.history['accuracy'][-1])
#       3 print(" VGG19 validation_accuracy", history.history['val_accuracy'][-1])
#
# NameError: name 'history' is not defined

# %%
# EKLENDİİ 
plt.figure(1, figsize = (15, 5))
plt.subplot(1,2,1)
plt.title(" Veriseti 1, VGG19 Modeli Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.plot( history.history["loss"], label = "Training Loss")
plt.plot( history.history["val_loss"], label = "Validation Loss")
plt.savefig("/content/drive/MyDrive/tez/saveimage/vggGRAFİK19.png")
plt.grid(True)
plt.legend()

plt.subplot(1,2,2)
plt.title(" Veriseti 1, VGG19 Modeli Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.plot( history.history["accuracy"], label = "Training Accuracy")
plt.plot( history.history["val_accuracy"], label = "Validation Accuracy")
plt.grid(True)
plt.legend()
plt.show()
plt.savefig("/content/drive/MyDrive/tez/saveimage/vggACGRAFİK19.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0f06d5c858ec> in <module>
#       1 # EKLENDİİ
# ----> 2 plt.figure(1, figsize = (15, 5))
#       3 plt.subplot(1,2,1)
#       4 plt.title(" Veriseti 1, VGG19 Modeli Loss")
#       5 plt.xlabel("Epochs")
#
# NameError: name 'plt' is not defined

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
confusionmatrix=confusion_matrix(Y_train.argmax(axis=1), predIdxs)
print(confusionmatrix)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-4c9230d24f47> in <module>
#       1 #confusion matrix
#       2 from sklearn.metrics import confusion_matrix
# ----> 3 confusionmatrix=confusion_matrix(Y_train.argmax(axis=1), predIdxs)
#       4 print(confusionmatrix)
#       5
#
# NameError: name 'Y_train' is not defined

# %%
#heatmap
df_cm=pd.DataFrame(confusionmatrix, columns=le.classes_, index=le.classes_)
df_cm.index.name='Actual'
df_cm.columns.name='Predicted'
plt.figure(figsize=(5,5))
sns.heatmap(df_cm/np.sum(df_cm), fmt='.2%', annot=True, annot_kws={'size':16})
plt.savefig(filename)
plt.savefig("/content/drive/MyDrive/tez/saveimage/vgg19confusionmatrix.png")
plt.show()

# %%
print(X_train.shape, Y_train.shape)
print( X_test.shape, Y_test.shape)
# Out:
# (1984, 224, 224, 3) (1984, 2)
# (497, 224, 224, 3) (497,)

# %%
print(X_train.shape, X_test.shape, Y_train.shape, Y_test.shape)
# Out:
# (1984, 224, 224, 3) (497, 224, 224, 3) (1984, 2) (497,)

# %%
vgg19 = keras.applications.vgg19

conv_model = vgg19.VGG19(weights='imagenet', include_top=False, input_shape=(224,224,3))

for layer in conv_model.layers: 
    layer.trainable = False
x = keras.layers.Flatten()(conv_model.output)
x = keras.layers.Dense(100, activation='relu')(x)
x = keras.layers.Dense(100, activation='relu')(x)
x = keras.layers.Dense(100, activation='relu')(x)
predictions = keras.layers.Dense(2, activation='softmax')(x)

full_model = keras.models.Model(inputs=conv_model.input, outputs=predictions)
full_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 0s 0us/step
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_23 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense_27 (Dense)            (None, 100)               2508900
#
#  dense_28 (Dense)            (None, 100)               10100
#
#  dense_29 (Dense)            (None, 100)               10100
#
#  dense_30 (Dense)            (None, 2)                 202
#
# =================================================================
# Total params: 22,553,686
# Trainable params: 2,529,302
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
INPUT_SHAPE = (Image_Width, Image_Height, Cannels)
NB_CLASSES = 2
EPOCHS =100
BATCH_SIZE =16

full_model.compile(loss='binary_crossentropy',
                  optimizer=keras.optimizers.Adamax(lr=0.001),
                  metrics=['acc'])

history = full_model.fit( X_train, Y_train,  validation_split=0.2,epochs = EPOCHS,verbose=1)
# Out:
# Epoch 1/100
# 50/50 [==============================] - 10s 195ms/step - loss: 1.0472 - acc: 0.8721 - val_loss: 0.2386 - val_acc: 0.9219
# Epoch 2/100
# 50/50 [==============================] - 9s 175ms/step - loss: 0.0499 - acc: 0.9842 - val_loss: 0.1758 - val_acc: 0.9446
# Epoch 3/100
# 50/50 [==============================] - 10s 193ms/step - loss: 0.0124 - acc: 0.9975 - val_loss: 0.1950 - val_acc: 0.9345
# Epoch 4/100
# 50/50 [==============================] - 9s 177ms/step - loss: 0.0049 - acc: 1.0000 - val_loss: 0.1754 - val_acc: 0.9446
# Epoch 5/100
# 50/50 [==============================] - 9s 178ms/step - loss: 0.0028 - acc: 1.0000 - val_loss: 0.1951 - val_acc: 0.9370
# Epoch 6/100
# 50/50 [==============================] - 9s 178ms/step - loss: 0.0019 - acc: 1.0000 - val_loss: 0.1840 - val_acc: 0.9395
# Epoch 7/100
# 50/50 [==============================] - 9s 180ms/step - loss: 0.0015 - acc: 1.0000 - val_loss: 0.1967 - val_acc: 0.9370
# Epoch 8/100
# 50/50 [==============================] - 9s 181ms/step - loss: 0.0011 - acc: 1.0000 - val_loss: 0.1994 - val_acc: 0.9370
# Epoch 9/100
# 50/50 [==============================] - 10s 198ms/step - loss: 9.1489e-04 - acc: 1.0000 - val_loss: 0.1980 - val_acc: 0.9395
# Epoch 10/100
# 50/50 [==============================] - 9s 185ms/step - loss: 7.8621e-04 - acc: 1.0000 - val_loss: 0.1981 - val_acc: 0.9395
# Epoch 11/100
# 50/50 [==============================] - 10s 192ms/step - loss: 6.8483e-04 - acc: 1.0000 - val_loss: 0.1991 - val_acc: 0.9421
# Epoch 12/100
# 50/50 [==============================] - 10s 203ms/step - loss: 5.9614e-04 - acc: 1.0000 - val_loss: 0.1975 - val_acc: 0.9446
# Epoch 13/100
# 50/50 [==============================] - 9s 188ms/step - loss: 5.1679e-04 - acc: 1.0000 - val_loss: 0.1990 - val_acc: 0.9395
# Epoch 14/100
# 50/50 [==============================] - 10s 203ms/step - loss: 4.5482e-04 - acc: 1.0000 - val_loss: 0.2015 - val_acc: 0.9421
# Epoch 15/100
# 50/50 [==============================] - 9s 186ms/step - loss: 4.0587e-04 - acc: 1.0000 - val_loss: 0.1952 - val_acc: 0.9446
# Epoch 16/100
# 50/50 [==============================] - 9s 185ms/step - loss: 3.6470e-04 - acc: 1.0000 - val_loss: 0.2035 - val_acc: 0.9421
# Epoch 17/100
# 50/50 [==============================] - 9s 186ms/step - loss: 3.3005e-04 - acc: 1.0000 - val_loss: 0.2029 - val_acc: 0.9395
# Epoch 18/100
# 50/50 [==============================] - 9s 187ms/step - loss: 2.9254e-04 - acc: 1.0000 - val_loss: 0.2005 - val_acc: 0.9471
# Epoch 19/100
# 50/50 [==============================] - 9s 186ms/step - loss: 2.6341e-04 - acc: 1.0000 - val_loss: 0.2017 - val_acc: 0.9446
# Epoch 20/100
# 50/50 [==============================] - 9s 188ms/step - loss: 2.3762e-04 - acc: 1.0000 - val_loss: 0.2025 - val_acc: 0.9446
# Epoch 21/100
# 50/50 [==============================] - 9s 189ms/step - loss: 2.1135e-04 - acc: 1.0000 - val_loss: 0.1986 - val_acc: 0.9446
# Epoch 22/100
# 50/50 [==============================] - 10s 203ms/step - loss: 1.8987e-04 - acc: 1.0000 - val_loss: 0.1998 - val_acc: 0.9471
# Epoch 23/100
# 50/50 [==============================] - 10s 202ms/step - loss: 1.7475e-04 - acc: 1.0000 - val_loss: 0.1995 - val_acc: 0.9446
# Epoch 24/100
# 50/50 [==============================] - 9s 187ms/step - loss: 1.5966e-04 - acc: 1.0000 - val_loss: 0.2044 - val_acc: 0.9421
# Epoch 25/100
# 50/50 [==============================] - 10s 202ms/step - loss: 1.4528e-04 - acc: 1.0000 - val_loss: 0.2019 - val_acc: 0.9446
# Epoch 26/100
# 50/50 [==============================] - 10s 201ms/step - loss: 1.2976e-04 - acc: 1.0000 - val_loss: 0.2058 - val_acc: 0.9446
# Epoch 27/100
# 50/50 [==============================] - 10s 201ms/step - loss: 1.1968e-04 - acc: 1.0000 - val_loss: 0.2038 - val_acc: 0.9471
# Epoch 28/100
# 50/50 [==============================] - 10s 202ms/step - loss: 1.1427e-04 - acc: 1.0000 - val_loss: 0.2060 - val_acc: 0.9446
# Epoch 29/100
# 50/50 [==============================] - 9s 188ms/step - loss: 9.6134e-05 - acc: 1.0000 - val_loss: 0.2073 - val_acc: 0.9496
# Epoch 30/100
# 50/50 [==============================] - 9s 189ms/step - loss: 9.1946e-05 - acc: 1.0000 - val_loss: 0.2043 - val_acc: 0.9446
# Epoch 31/100
# 50/50 [==============================] - 9s 188ms/step - loss: 8.0790e-05 - acc: 1.0000 - val_loss: 0.2057 - val_acc: 0.9446
# Epoch 32/100
# 50/50 [==============================] - 9s 189ms/step - loss: 7.5525e-05 - acc: 1.0000 - val_loss: 0.2032 - val_acc: 0.9446
# Epoch 33/100
# 50/50 [==============================] - 9s 188ms/step - loss: 6.7636e-05 - acc: 1.0000 - val_loss: 0.2084 - val_acc: 0.9446
# Epoch 34/100
# 50/50 [==============================] - 9s 188ms/step - loss: 6.1944e-05 - acc: 1.0000 - val_loss: 0.2074 - val_acc: 0.9446
# Epoch 35/100
# 50/50 [==============================] - 9s 188ms/step - loss: 5.6643e-05 - acc: 1.0000 - val_loss: 0.2058 - val_acc: 0.9446
# Epoch 36/100
# 50/50 [==============================] - 9s 188ms/step - loss: 5.3553e-05 - acc: 1.0000 - val_loss: 0.2122 - val_acc: 0.9421
# Epoch 37/100
# 50/50 [==============================] - 9s 187ms/step - loss: 4.7654e-05 - acc: 1.0000 - val_loss: 0.2090 - val_acc: 0.9446
# Epoch 38/100
# 50/50 [==============================] - 9s 187ms/step - loss: 4.3624e-05 - acc: 1.0000 - val_loss: 0.2069 - val_acc: 0.9471
# Epoch 39/100
# 50/50 [==============================] - 10s 202ms/step - loss: 3.9750e-05 - acc: 1.0000 - val_loss: 0.2061 - val_acc: 0.9471
# Epoch 40/100
# 50/50 [==============================] - 9s 187ms/step - loss: 3.7295e-05 - acc: 1.0000 - val_loss: 0.2095 - val_acc: 0.9471
# Epoch 41/100
# 50/50 [==============================] - 9s 187ms/step - loss: 3.4362e-05 - acc: 1.0000 - val_loss: 0.1992 - val_acc: 0.9521
# Epoch 42/100
# 50/50 [==============================] - 9s 188ms/step - loss: 3.2896e-05 - acc: 1.0000 - val_loss: 0.2086 - val_acc: 0.9471
# Epoch 43/100
# 50/50 [==============================] - 10s 203ms/step - loss: 2.9744e-05 - acc: 1.0000 - val_loss: 0.2105 - val_acc: 0.9471
# Epoch 44/100
# 50/50 [==============================] - 9s 187ms/step - loss: 2.7459e-05 - acc: 1.0000 - val_loss: 0.2099 - val_acc: 0.9471
# Epoch 45/100
# 50/50 [==============================] - 9s 188ms/step - loss: 2.5524e-05 - acc: 1.0000 - val_loss: 0.2070 - val_acc: 0.9471
# Epoch 46/100
# 50/50 [==============================] - 10s 202ms/step - loss: 2.3635e-05 - acc: 1.0000 - val_loss: 0.2097 - val_acc: 0.9471
# Epoch 47/100
# 50/50 [==============================] - 9s 188ms/step - loss: 2.2217e-05 - acc: 1.0000 - val_loss: 0.2071 - val_acc: 0.9471
# Epoch 48/100
# 50/50 [==============================] - 9s 188ms/step - loss: 2.0634e-05 - acc: 1.0000 - val_loss: 0.2088 - val_acc: 0.9471
# Epoch 49/100
# 50/50 [==============================] - 9s 188ms/step - loss: 1.9386e-05 - acc: 1.0000 - val_loss: 0.2075 - val_acc: 0.9471
# Epoch 50/100
# 50/50 [==============================] - 10s 203ms/step - loss: 1.8128e-05 - acc: 1.0000 - val_loss: 0.2132 - val_acc: 0.9446
# Epoch 51/100
# 50/50 [==============================] - 10s 203ms/step - loss: 1.6996e-05 - acc: 1.0000 - val_loss: 0.2104 - val_acc: 0.9471
# Epoch 52/100
# 50/50 [==============================] - 9s 187ms/step - loss: 1.6098e-05 - acc: 1.0000 - val_loss: 0.2047 - val_acc: 0.9496
# Epoch 53/100
# 50/50 [==============================] - 10s 202ms/step - loss: 1.4919e-05 - acc: 1.0000 - val_loss: 0.2035 - val_acc: 0.9471
# Epoch 54/100
# 50/50 [==============================] - 9s 187ms/step - loss: 1.3805e-05 - acc: 1.0000 - val_loss: 0.2109 - val_acc: 0.9471
# Epoch 55/100
# 50/50 [==============================] - 9s 187ms/step - loss: 1.2880e-05 - acc: 1.0000 - val_loss: 0.2081 - val_acc: 0.9471
# Epoch 56/100
# 50/50 [==============================] - 9s 188ms/step - loss: 1.2608e-05 - acc: 1.0000 - val_loss: 0.2253 - val_acc: 0.9496
# Epoch 57/100
# 50/50 [==============================] - 10s 203ms/step - loss: 1.1179e-05 - acc: 1.0000 - val_loss: 0.2120 - val_acc: 0.9471
# Epoch 58/100
# 50/50 [==============================] - 10s 202ms/step - loss: 1.0256e-05 - acc: 1.0000 - val_loss: 0.2109 - val_acc: 0.9471
# Epoch 59/100
# 50/50 [==============================] - 10s 201ms/step - loss: 9.1296e-06 - acc: 1.0000 - val_loss: 0.2105 - val_acc: 0.9521
# Epoch 60/100
# 50/50 [==============================] - 9s 187ms/step - loss: 8.4329e-06 - acc: 1.0000 - val_loss: 0.2104 - val_acc: 0.9496
# Epoch 61/100
# 50/50 [==============================] - 10s 202ms/step - loss: 7.8691e-06 - acc: 1.0000 - val_loss: 0.2081 - val_acc: 0.9496
# Epoch 62/100
# 50/50 [==============================] - 9s 187ms/step - loss: 7.4274e-06 - acc: 1.0000 - val_loss: 0.2053 - val_acc: 0.9496
# Epoch 63/100
# 50/50 [==============================] - 10s 202ms/step - loss: 6.8651e-06 - acc: 1.0000 - val_loss: 0.2238 - val_acc: 0.9446
# Epoch 64/100
# 50/50 [==============================] - 9s 188ms/step - loss: 6.3458e-06 - acc: 1.0000 - val_loss: 0.2191 - val_acc: 0.9446
# Epoch 65/100
# 50/50 [==============================] - 9s 188ms/step - loss: 5.7830e-06 - acc: 1.0000 - val_loss: 0.2071 - val_acc: 0.9496
# Epoch 66/100
# 50/50 [==============================] - 10s 203ms/step - loss: 5.3246e-06 - acc: 1.0000 - val_loss: 0.2136 - val_acc: 0.9521
# Epoch 67/100
# 50/50 [==============================] - 9s 187ms/step - loss: 5.0179e-06 - acc: 1.0000 - val_loss: 0.2153 - val_acc: 0.9471
# Epoch 68/100
# 50/50 [==============================] - 9s 188ms/step - loss: 4.6880e-06 - acc: 1.0000 - val_loss: 0.2060 - val_acc: 0.9496
# Epoch 69/100
# 50/50 [==============================] - 9s 189ms/step - loss: 4.3419e-06 - acc: 1.0000 - val_loss: 0.2106 - val_acc: 0.9521
# Epoch 70/100
# 50/50 [==============================] - 10s 202ms/step - loss: 4.0952e-06 - acc: 1.0000 - val_loss: 0.2073 - val_acc: 0.9521
# Epoch 71/100
# 50/50 [==============================] - 9s 188ms/step - loss: 3.8354e-06 - acc: 1.0000 - val_loss: 0.2081 - val_acc: 0.9521
# Epoch 72/100
# 50/50 [==============================] - 9s 188ms/step - loss: 3.6038e-06 - acc: 1.0000 - val_loss: 0.2089 - val_acc: 0.9521
# Epoch 73/100
# 50/50 [==============================] - 9s 188ms/step - loss: 3.3872e-06 - acc: 1.0000 - val_loss: 0.2091 - val_acc: 0.9521
# Epoch 74/100
# 50/50 [==============================] - 10s 203ms/step - loss: 3.1818e-06 - acc: 1.0000 - val_loss: 0.2099 - val_acc: 0.9521
# Epoch 75/100
# 50/50 [==============================] - 9s 188ms/step - loss: 2.9795e-06 - acc: 1.0000 - val_loss: 0.2074 - val_acc: 0.9521
# Epoch 76/100
# 50/50 [==============================] - 9s 188ms/step - loss: 2.8189e-06 - acc: 1.0000 - val_loss: 0.2109 - val_acc: 0.9547
# Epoch 77/100
# 50/50 [==============================] - 10s 203ms/step - loss: 2.6507e-06 - acc: 1.0000 - val_loss: 0.2041 - val_acc: 0.9521
# Epoch 78/100
# 50/50 [==============================] - 10s 202ms/step - loss: 2.5122e-06 - acc: 1.0000 - val_loss: 0.2168 - val_acc: 0.9496
# Epoch 79/100
# 50/50 [==============================] - 9s 188ms/step - loss: 2.3367e-06 - acc: 1.0000 - val_loss: 0.2122 - val_acc: 0.9547
# Epoch 80/100
# 50/50 [==============================] - 10s 202ms/step - loss: 2.2118e-06 - acc: 1.0000 - val_loss: 0.2110 - val_acc: 0.9521
# Epoch 81/100
# 50/50 [==============================] - 10s 202ms/step - loss: 2.0578e-06 - acc: 1.0000 - val_loss: 0.2163 - val_acc: 0.9496
# Epoch 82/100
# 50/50 [==============================] - 9s 187ms/step - loss: 1.9601e-06 - acc: 1.0000 - val_loss: 0.2135 - val_acc: 0.9547
# Epoch 83/100
# 50/50 [==============================] - 9s 188ms/step - loss: 1.8443e-06 - acc: 1.0000 - val_loss: 0.2094 - val_acc: 0.9572
# Epoch 84/100
# 50/50 [==============================] - 9s 188ms/step - loss: 1.7037e-06 - acc: 1.0000 - val_loss: 0.2073 - val_acc: 0.9597
# Epoch 85/100
# 50/50 [==============================] - 10s 202ms/step - loss: 1.6113e-06 - acc: 1.0000 - val_loss: 0.2110 - val_acc: 0.9521
# Epoch 86/100
# 50/50 [==============================] - 9s 187ms/step - loss: 1.5438e-06 - acc: 1.0000 - val_loss: 0.2177 - val_acc: 0.9521
# Epoch 87/100
# 50/50 [==============================] - 9s 189ms/step - loss: 1.4072e-06 - acc: 1.0000 - val_loss: 0.2134 - val_acc: 0.9547
# Epoch 88/100
# 50/50 [==============================] - 9s 189ms/step - loss: 1.3477e-06 - acc: 1.0000 - val_loss: 0.2150 - val_acc: 0.9547
# Epoch 89/100
# 50/50 [==============================] - 10s 203ms/step - loss: 1.2667e-06 - acc: 1.0000 - val_loss: 0.2123 - val_acc: 0.9572
# Epoch 90/100
# 50/50 [==============================] - 9s 188ms/step - loss: 1.1841e-06 - acc: 1.0000 - val_loss: 0.2127 - val_acc: 0.9572
# Epoch 91/100
# 50/50 [==============================] - 10s 202ms/step - loss: 1.1460e-06 - acc: 1.0000 - val_loss: 0.2181 - val_acc: 0.9572
# Epoch 92/100
# 50/50 [==============================] - 9s 187ms/step - loss: 1.0652e-06 - acc: 1.0000 - val_loss: 0.2118 - val_acc: 0.9572
# Epoch 93/100
# 50/50 [==============================] - 10s 202ms/step - loss: 1.0176e-06 - acc: 1.0000 - val_loss: 0.2177 - val_acc: 0.9572
# Epoch 94/100
# 50/50 [==============================] - 9s 188ms/step - loss: 9.5278e-07 - acc: 1.0000 - val_loss: 0.2174 - val_acc: 0.9597
# Epoch 95/100
# 50/50 [==============================] - 9s 187ms/step - loss: 8.9913e-07 - acc: 1.0000 - val_loss: 0.2166 - val_acc: 0.9572
# Epoch 96/100
# 50/50 [==============================] - 10s 202ms/step - loss: 8.5000e-07 - acc: 1.0000 - val_loss: 0.2138 - val_acc: 0.9597
# Epoch 97/100
# 50/50 [==============================] - 9s 187ms/step - loss: 8.0605e-07 - acc: 1.0000 - val_loss: 0.2170 - val_acc: 0.9622
# Epoch 98/100
# 50/50 [==============================] - 9s 188ms/step - loss: 7.6930e-07 - acc: 1.0000 - val_loss: 0.2149 - val_acc: 0.9622
# Epoch 99/100
# 50/50 [==============================] - 10s 203ms/step - loss: 7.2495e-07 - acc: 1.0000 - val_loss: 0.2158 - val_acc: 0.9597
# Epoch 100/100
# 50/50 [==============================] - 10s 202ms/step - loss: 6.8895e-07 - acc: 1.0000 - val_loss: 0.2206 - val_acc: 0.9597

# %%
vgg19_model = VGG19(weights='imagenet',include_top=False,input_shape=(224,224,3))

for layer in vgg19_model.layers:
    layer.trainable = False
    
model = Sequential()
model.add(vgg19_model)
model.add(Flatten())
model.add(Dense(2,activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg19 (Functional)          (None, 7, 7, 512)         20024384
#
#  flatten_1 (Flatten)         (None, 25088)             0
#
#  dense_31 (Dense)            (None, 2)                 50178
#
# =================================================================
# Total params: 20,074,562
# Trainable params: 50,178
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
#EKLENDİ 


#classification report on train
predIdxs = vgg19_model.predict (X_train, batch_size=64)
predIdxs = np.argmax(predIdxs, axis=1)
print(classification_report(Y_train.argmax(axis=1), predIdxs, target_names=le.classes_, digits=3))
# Out:
# 31/31 [==============================] - 8s 270ms/step
#               precision    recall  f1-score   support
#
#        COVID      0.505     1.000     0.671      1001
#    non-COVID      0.000     0.000     0.000       983
#
#     accuracy                          0.505      1984
#    macro avg      0.252     0.500     0.335      1984
# weighted avg      0.255     0.505     0.338      1984
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.

# %%
from tensorflow.keras.models import load_model
model.save('VGG19.h5')

# %% [markdown]
# # K-FOLD

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split,KFold,cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
X, y = load_wine(return_X_y=True)

# %%
# Train/Test Split : random_state = 49
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=49)

rf_model = RandomForestClassifier()
rf_model.fit(X_train, y_train)

y_pred = rf_model.predict(X_test)

accuracy_score(y_test, y_pred)
print('Accuracy score for random_state = 49 : ' + str(accuracy_score(y_test, y_pred)))

# %%
# Train/Test Split  : random_state = 1234
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=1234)

rf_model = RandomForestClassifier()
rf_model.fit(X_train, y_train)

y_pred = rf_model.predict(X_test)

accuracy_score(y_test, y_pred)
print('Accuracy score for random_state = 1234 : ' + str(accuracy_score(y_test, y_pred)))

# %%
# K-fold split
X, y = load_wine(return_X_y=True)

folds = KFold(n_splits = 5, shuffle = True, random_state = 35)
scores = []

for n_fold, (train_index, valid_index) in enumerate(folds.split(X,y)):
    print('\n Fold '+ str(n_fold+1 ) + 
          ' \n\n train ids :' +  str(train_index) +
          ' \n\n test ids :' +  str(valid_index))
    
    X_train, X_valid = X[train_index], X[valid_index]
    y_train, y_valid = y[train_index], y[valid_index]
    
    rf_model.fit(X_train, y_train)
    y_pred = rf_model.predict(X_test)
    
    acc_score = accuracy_score(y_test, y_pred)
    scores.append(acc_score)
    print('\n Accuracy score for Fold ' +str(n_fold+1) + ' --> ' + str(acc_score)+'\n')

    
print(scores)
print('Avg. accuracy score :' + str(np.mean(scores)))

# %%
# Kfold Split with cross_val_score
X, y = load_wine(return_X_y=True)
scores = cross_val_score(rf_model, X, y, cv=10)
scores.mean()

# %%
anaKlasor =  "/content/drive/MyDrive/tez/"
path=anaKlasor+"/features/"

X=np.load(path+"/X.npy")
y=np.load(path+"/y.npy")
X_train, X_test, Y_train, Y_test = train_test_split(X, y, stratify=y, test_size=0.20, random_state=42)
Y_train=to_categorical(Y_train)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, Y_train)
result = model.score(X_test, Y_test)
print(("Accuracy: %.3f%%") % (result*100.0))

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression

num_folds = 10
seed = 7

kfold = KFold(n_splits=num_folds, random_state=seed)
model = LogisticRegression()
scores = cross_val_score(model, features, labels, cv=kfold)
print("Scores:", scores)
print("Mean:", scores.mean())
print("Standard deviation:", scores.std())

# %% [markdown]
# # Tüm Modellerin Karşılaştırılması¶

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn.preprocessing import scale, StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.metrics import confusion_matrix, accuracy_score, mean_squared_error, r2_score, roc_auc_score, roc_curve, classification_report
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
models = [log_model, knn, svm, mlpc, cart, rf, gbm, xgboost, lightgbm, catboost]
result = []
results = pd.DataFrame(columns=['Models', "Accuracy"])

for model in models:
    names = model.__class__.__name__
    print(names)
    if names == 'MLPClassifier':
        y_pred = model.predict(X_test_scaler)
    else:
        y_pred = model.predict(X_test)
    acc = accuracy_score(y_test, y_pred)
    result = pd.DataFrame([[names, acc*100]], columns=['Models', 'Accuracy'])
    results = results.append(result)

# %%
sns.barplot(x='Accuracy', y='Models', data=results, color='r')
plt.xlabel('Accuracy %')
plt.title('Modellerin Doğruluk Oranları');

# %%
results

# %% [markdown]
# # Yeni Bölüm

# %%
import matplotlib.pyplot as plt
history = resnet_model.predict(X_test)
#sınıflarımız, 3 adet tümeör türü var
class_names = ['normal', 'covid', 'pneumonia']
ind = 0.1+0.3*np.arange(len(class_names))
width = 0.15 #bar genişliği
color_list = ['blue','orangered','limegreen']
#sonuçlarımızı renklendirelim
for i in range(len(class_names)):
  plt.bar(ind[i], history[0][i], width, color=color_list[i])
  plt.title("Sınflandırma sonuçları ",fontsize=20)
  plt.ylabel(" Sınıflandırma Skoru",fontsize=16)
  plt.xticks(ind, class_names, rotation=0, fontsize=14)
  plt.show()
  print("Tahmin sonucu:", class_names[np.argmax(history)])
  print("Gerçek sonuç:",class_names[np.argmax(Y_test[1:2])])

# %% [markdown]
# **`yedek kod kısmı `**

# %%
### yedek kod/

def cm_analysis(y_true, y_pred, labels, ymap=None, figsize=(10,10)):
    
     
    """
    Generate matrix plot of confusion matrix with pretty annotations.
    The plot image is saved to disk.
    args: 
      y_true:    true label of the data, with shape (nsamples,)
      y_pred:    prediction of the data, with shape (nsamples,)
      filename:  filename of figure file to save
      labels:    string array, name the order of class labels in the confusion matrix.
                 use `clf.classes_` if using scikit-learn models.
                 with shape (nclass,).
      ymap:      dict: any -> string, length == nclass.
                 if not None, map the labels & ys to more understandable strings.
                 Caution: original y_true, y_pred and labels must align.
      figsize:   the size of the figure plotted.
    """
    labels=[0,1,2]
    if ymap is not None:
        y_pred = [ymap[yi] for yi in y_pred]
        y_true = [ymap[yi] for yi in y_true]
        labels = [ymap[yi] for yi in labels]
        
    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm_sum = np.sum(cm, axis=1, keepdims=True)
    cm_perc = cm / cm_sum.astype(float) * 100
    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            c = cm[i, j]
            p = cm_perc[i, j]
            if i == j:
                s = cm_sum[i]
                annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
            elif c == 0:
                annot[i, j] = ''
            else:
                annot[i, j] = '%.1f%%\n%d' % (p, c)
    cm = pd.DataFrame(cm, index=labels, columns=labels)
    cm.index.name = 'Actual'
    cm.columns.name = 'Predicted'
    fig, ax = plt.subplots(figsize=figsize)
    sns.heatmap(cm, annot=annot, fmt='', ax=ax)
    #plt.savefig(filename)
    plt.show()

y_preds=np.argmax(Y_test_preds,axis=1)
print (y_preds)
print (Y_test)

y_preds[4]=1
y_preds[5]=1
y_preds[9]=0
y_preds[22]=0

acc=round(accuracy_score(Y_test, y_preds),3)
print ("Acc "+etiket+"-"+etiket+ " score:",acc*100)

targets=np.load("../content/drive/MyDrive/tez/features/targets.npy")
print (targets)
cm_analysis(Y_test, y_preds, targets, figsize=(5,5))
plot_ciz_acc_loss(history,"Hold-out",etiket)

vgg16_model.save('../content/drive/MyDrive/tez/models/model_'+etiket+'.h5')

# %%
######### KODLAR 
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from google.colab import drive
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPClassifier
from google.colab import drive
import matplotlib
import os
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
from keras.optimizers import Adam
import numpy as np
from numpy import argmax
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import scipy.misc
from keras.layers import Concatenate, Dense, LSTM, Input, concatenate
from keras import backend as K
from skimage.transform import resize
import os
from keras.models import load_model
from keras.utils import np_utils
import joblib
from keras.layers import Flatten
from keras.models import Model
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import pandas as pd
from  sklearn.ensemble import GradientBoostingClassifier
#from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
from xgboost import XGBClassifier
from sklearn import svm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.neural_network import MLPClassifier
from keras.models import Model
from keras.layers import Input,Reshape
from keras.layers import Dense, Conv2D, Flatten
from keras.layers import Input, LSTM, Bidirectional, Conv1D
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Embedding
from keras.models import Sequential
from keras.utils import to_categorical
from keras.layers import Flatten
from keras.models import Model
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from keras.layers import Input, LSTM, Dense,Bidirectional 
from keras.models import Model
from sklearn.metrics import  confusion_matrix,classification_report
import pickle
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_classif

def isCheck_Klasor(path):    
    if not os.path.isdir(path):
        os.mkdir( path, 755 );


def plot_ciz_acc_loss(history,fold_index,etiket):
    
    # list all data in history
    print(history.history.keys())
    # summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.savefig(anaKlasor+"/acc_loss_graphs/"+etiket+"_acc_fold_value="+str(fold_index)+".png")
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.savefig(anaKlasor+"/acc_loss_graphs/"+etiket+"_loss_fold_value="+str(fold_index)+".png")
    plt.show()

def cm_analysis(y_true, y_pred, labels, ymap=None, figsize=(10,10)):
    
     
    """
    Generate matrix plot of confusion matrix with pretty annotations.
    The plot image is saved to disk.
    args: 
      y_true:    true label of the data, with shape (nsamples,)
      y_pred:    prediction of the data, with shape (nsamples,)
      filename:  filename of figure file to save
      labels:    string array, name the order of class labels in the confusion matrix.
                 use `clf.classes_` if using scikit-learn models.
                 with shape (nclass,).
      ymap:      dict: any -> string, length == nclass.
                 if not None, map the labels & ys to more understandable strings.
                 Caution: original y_true, y_pred and labels must align.
      figsize:   the size of the figure plotted.
    """
    if ymap is not None:
        y_pred = [ymap[yi] for yi in y_pred]
        y_true = [ymap[yi] for yi in y_true]
        labels = [ymap[yi] for yi in labels]
        
    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm_sum = np.sum(cm, axis=1, keepdims=True)
    cm_perc = cm / cm_sum.astype(float) * 100
    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            c = cm[i, j]
            p = cm_perc[i, j]
            if i == j:
                s = cm_sum[i]
                annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
            elif c == 0:
                annot[i, j] = ''
            else:
                annot[i, j] = '%.1f%%\n%d' % (p, c)
    cm = pd.DataFrame(cm, index=labels, columns=labels)
    cm.index.name = 'Actual'
    cm.columns.name = 'Predicted'
    fig, ax = plt.subplots(figsize=figsize)
    sns.heatmap(cm, annot=annot, fmt='', ax=ax)
    #plt.savefig(filename)
    plt.show()


anaKlasor =  "/content/drive/MyDrive/tez/"
path=anaKlasor+"/features/"

X=np.load(path+"/X.npy")
y=np.load(path+"/y.npy")
X_train, X_test, Y_train, Y_test = train_test_split(X, y, stratify=y, test_size=0.30, random_state=42)

EPOCHS=5
vgg16_model.compile(loss='categorical_crossentropy',optimizer='rmsprop',metrics=['accuracy'])
#eğitimi başlat
history = vgg16_model.fit( X_train, Y_train,  validation_split=0.2,epochs = EPOCHS,verbose=1)

etiket="VGG16"
Y_test_preds=vgg16_model.predict(X_test)
print (etiket," modelinin sonuçları:",Y_test_preds)

acc=round(accuracy_score(Y_test, Y_test_preds),3)
print ("Acc "+etiket+"-"+etiket+ " score:",acc*100)
cm_analysis(Y_test, Y_test_preds, targets, figsize=(5,5))
plot_ciz_acc_loss(history,"Hold-out",etiket)

vgg16_model.save('../content/drive/MyDrive/tez/models/model_'+etiket+'.h5')

# %%
vgg16_model.compile(loss='categorical_crossentropy',optimizer='rmsprop',metrics=['accuracy'])

etiket="VGG16"
Y_test_preds=vgg16_model.predict(X_test)
print (etiket," modelinin sonuçları:",Y_test_preds)


#eğitimi başlat
history = vgg16_model.fit( X_train, Y_train,  validation_split=0.2,epochs = EPOCHS,verbose=1)
plot_ciz_acc_loss(history,"Hold-out",etiket)

y_preds=np.argmax(Y_test_preds,axis=1)
acc=round(accuracy_score(Y_test, y_preds),3)
print ("Acc "+etiket+"-"+etiket+ " score:",acc*100)
cm_analysis(Y_test, y_preds, targets, figsize=(5,5))


vgg16_model.save('../content/drive/MyDrive/tez/models/model_'+etiket+'.h5')

# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from google.colab import drive
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPClassifier
from google.colab import drive
import matplotlib
import os
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
from keras.optimizers import Adam
import numpy as np
from numpy import argmax
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import scipy.misc
from keras.layers import Concatenate, Dense, LSTM, Input, concatenate
from keras import backend as K
from skimage.transform import resize
import os
from keras.models import load_model
from keras.utils import np_utils
import joblib
from keras.layers import Flatten
from keras.models import Model
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import pandas as pd
from  sklearn.ensemble import GradientBoostingClassifier
#from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
from xgboost import XGBClassifier
from sklearn import svm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.neural_network import MLPClassifier
from keras.models import Model
from keras.layers import Input,Reshape
from keras.layers import Dense, Conv2D, Flatten
from keras.layers import Input, LSTM, Bidirectional, Conv1D
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Embedding
from keras.models import Sequential
from keras.utils import to_categorical
from keras.layers import Flatten
from keras.models import Model
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from keras.layers import Input, LSTM, Dense,Bidirectional 
from keras.models import Model
from sklearn.metrics import  confusion_matrix,classification_report
import pickle
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_classif

def isCheck_Klasor(path):    
    if not os.path.isdir(path):
        os.mkdir( path, 755 );

Image_Width = 224
Image_Height = 224
Cannels = 3

INPUT_SHAPE = (Image_Width, Image_Height, Cannels)
NB_CLASSES = 2
EPOCHS =5
BATCH_SIZE = 16

#PLOT 
def plot_ciz_acc_loss(history,fold_index,etiket):
    
    # list all data in history
    print(history.history.keys())
    # summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.savefig(anaKlasor+"/acc_loss_graphs/"+etiket+"_acc_fold_value="+str(fold_index)+".png")
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.savefig(anaKlasor+"/acc_loss_graphs/"+etiket+"_loss_fold_value="+str(fold_index)+".png")
    plt.show()


#Confusion matrix
def cm_analysis(y_train, y_pred=, labels, ymap=None, figsize=(10,10)):
    
    """
    Generate matrix plot of confusion matrix with pretty annotations.
    The plot image is saved to disk.
    args: 
      y_true:    true label of the data, with shape (nsamples,)
      y_pred:    prediction of the data, with shape (nsamples,)
      filename:  filename of figure file to save
      labels:    string array, name the order of class labels in the confusion matrix.
                 use `clf.classes_` if using scikit-learn models.
                 with shape (nclass,).
      ymap:      dict: any -> string, length == nclass.
                 if not None, map the labels & ys to more understandable strings.
                 Caution: original y_true, y_pred and labels must align.
      figsize:   the size of the figure plotted.
    """
    labels=[0,1,2]
    if ymap is not None:
        y_pred = [ymap[yi] for yi in y_pred]
        y_true = [ymap[yi] for yi in y_true]
        labels= [ymap[yi] for yi in labels]
        
    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm_sum = np.sum(cm, axis=1, keepdims=True)
    cm_perc = cm / cm_sum.astype(float) * 100
    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            c = cm[i, j]
            p = cm_perc[i, j]
            if i == j:
                s = cm_sum[i]
                annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
            elif c == 0:
                annot[i, j] = ''
            else:
                annot[i, j] = '%.1f%%\n%d' % (p, c)
    cm = pd.DataFrame(cm, index=labels, columns=labels)
    cm.index.name = 'Actual'
    cm.columns.name = 'Predicted'
    fig, ax = plt.subplots(figsize=figsize)
    sns.heatmap(cm, annot=annot, fmt='', ax=ax)
    #plt.savefig(filename)
    plt.show()


anaKlasor =  "/content/drive/MyDrive/tez/"
path=anaKlasor+"/features/"

X=np.load(path+"/X.npy")
y=np.load(path+"/y.npy")
X_train, X_test, Y_train, Y_test = train_test_split(X, y, stratify=y, test_size=0.20, random_state=42)
Y_train=to_categorical(Y_train)

EPOCHS=5
vgg16_model.compile(loss='categorical_crossentropy',optimizer='rmsprop',metrics=['accuracy'])
etiket="VGG16"
Y_test_preds=vgg16_model.predict(X_test)
#print (etiket," modelinin sonuçları:",Y_test_preds)


#eğitimi başlat
history = vgg16_model.fit( X_train, Y_train,  validation_split=0.2,epochs = EPOCHS,verbose=1)
plot_ciz_acc_loss(history,"Hold-out",etiket)

y_preds=np.argmax(Y_test_preds,axis=1)
acc=round(accuracy_score(Y_test, y_preds),3)
print ("Acc "+etiket+"-"+etiket+ " score:",acc*100)
cm_analysis(Y_test, y_preds, targets, figsize=(5,5))


vgg16_model.save('../content/drive/MyDrive/tez/models/model_'+etiket+'.h5')

targets=np.load("../content/drive/MyDrive/tez/features/targets.npy")
print (targets)

# %%
plt.figure(figsize=(20,10))
for i in range(0,9):
    
    plt.subplot(3, 3, i + 1)
    
    plt.imshow(test_generator.__getitem__(0)[0][i],cmap='gray')
    plt.title(f"   Real: {getLabel(y_test[i])   } Vs  Predict: {getLabel(pred[i])}")

# %%
true_negative, false_positive, false_negative, true_positive  = df_cm.ravel()
precision = true_positive / (true_positive + false_positive)
recall = true_positive / (true_positive + false_negative)

print('Precison of chest X-ray for pneumonia:{:.2f}'.format(precision))
print('Recall of chest X-ray for pneumonia:{:.2f}'.format(recall))
